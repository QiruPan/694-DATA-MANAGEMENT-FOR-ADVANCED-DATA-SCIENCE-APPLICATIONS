# %%
#!pip install pymongo
#!pip install scikit-learn
#!pip install nltk
import nltk
#nltk.download('stopwords')
from pymongo import MongoClient
import pymongo

# %%
import json
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import numpy as np
from datetime import datetime

f = open('/Users/mazinrafi/Downloads/corona-out-3', 'r')

tweets = {}
retweets = {}
replies ={}
texts = {}
users = {}
hashtags = {}

# The specific keys to extract for tweets and users
tweet_keys = ['created_at', 'id_str', 'reply_count', 'retweet_count']
user_keys = ['name', 'screen_name', 'verified', 'followers_count', 'friends_count', 'created_at']

# Iterating over the input file
for line in f:
    if line == '\n':
        continue
    lx = json.loads(line)
    
    # Main extraction only for non-retweets
    if not 'retweeted_status' in lx or len(lx['retweeted_status']) == 0:
        li = dict((k, lx[k]) for k in tweet_keys if k in lx)
        # Store user ID and user screen name
        li['user'] = lx['user']['id']
        li['user_name'] = lx['user']['screen_name']
        
        # In some cases, text is truncated - here, extended_tweet full_text will contain the full version
        # If available, we use that, else the main text field is not truncated so we can use it
        if 'extended_tweet' in lx:    
            thisText = lx['extended_tweet']['full_text']
        else:
            thisText = lx['text']
        
        # Store the text (from whichever source) in both the tweet and the data source for keyword extraction
        li['text'] = thisText
        texts[lx['id']] = thisText
        
        # Identify hashtags using regex
        # The hashtags under entities are built from the main text field, which may have been truncated
        # So that subfield may be inaccurate
        hashtag_set = list(set(part[1:] for part in thisText.split() if part.startswith('#')))
        li['hashtags'] = hashtag_set
        li['hashtag_count'] = len(hashtag_set)
        
        # Track tweet IDs by hashtag, for later mapping
        for hashtag in hashtag_set:
            if hashtag in hashtags.keys():
                hashtags[hashtag].append(lx['id'])
            else:
                hashtags[hashtag] = [lx['id']]
        
        # Store this set of tweet details under this tweet ID
        #Also modify the "created_at" string format to a datetime for easier usage.
        #The range of dates are between 12:21:41 and 14:48:38 on April 25th, 2020
        li['_id'] = lx['id']
        created_at = datetime.strptime(lx['created_at'], '%a %b %d %H:%M:%S +0000 %Y')
        li['created_at'] = created_at
        tweets[lx['id']] = li
        
        # Track replies against their original tweets
        if 'in_reply_to_status_id' in lx:
            if not lx['in_reply_to_status_id'] in replies.keys():
                replies[lx['in_reply_to_status_id']] = 1
            else:
                replies[lx['in_reply_to_status_id']] = replies[lx['in_reply_to_status_id']] + 1
        
        # If this user has not been seen before, add their details into the user list    
        # Along with tagging this tweet to their profile
        # Else add the current tweet to the already existing user profile
        if lx['user']['id'] in users.keys():
            users[lx['user']['id']]['tweets'] = users[lx['user']['id']]['tweets'] + ',' + str(lx['id'])
            users[lx['user']['id']]['tweet_count'] = users[lx['user']['id']]['tweet_count'] + 1
        else:
            this_user = dict((k, lx['user'][k]) for k in user_keys if k in lx['user'])
            this_user['tweets'] = str(lx['id'])
            this_user['id'] = lx['user']['id']
            this_user['tweet_count'] = 1
            users[this_user['id']] = this_user
            
    
    else:
        # If a retweet, track against the original tweet
        orig_id = lx['retweeted_status']['id']
        
        if not orig_id in retweets.keys():
            retweets[orig_id] = 1
        else:
            retweets[orig_id] = retweets[orig_id] + 1
    
    
f.close()

# Map retweets and replies to their original tweets, with counts
for rt in retweets.keys():
    if rt in tweets.keys():
        tweets[rt]['retweet_count'] = retweets[rt]

for rt in replies.keys():
    if rt in tweets.keys():
        tweets[rt]['reply_count'] = replies[rt]


# Extract unigrams, removing stopwords, for all keywords that appear at least 50 times
vectorizer = CountVectorizer(token_pattern=r"(?u)\b[a-z][a-z]+\b", stop_words=stopwords.words('english'), min_df = 50)

X = vectorizer.fit_transform(texts.values())

# The list of IDs and keywords used in the vectorizer
key_list = [*texts.keys()]
word_list = [*vectorizer.get_feature_names_out()]

# Track the number of keywords mapped to each ID, and store the count with the tweet details
x1 = X.toarray()

x2 = dict((key_list[w], len([word_list[t] for t in np.where(x1[w]>0)[0]])) for w in range(len(x1)))

for key_id in x2.keys():
    if key_id in tweets.keys():
        tweets[key_id]['keyword_count'] = x2[key_id]

# Track the IDs associated with each keyword, and store the mapping
X = np.transpose(X)

x1 = X.toarray()

x2 = dict((word_list[w], [key_list[t] for t in np.where(x1[w]>0)[0]]) for w in range(len(x1)))


with open("/Users/mazinrafi/Downloads/hashtag_tdm.json", "w") as outfile:
    json.dump(hashtags, outfile, indent=2)

    
keywords = dict((k, {'_id': k, 'tweets': v}) for k, v in x2.items())

hashtags = dict((k, {'_id': k, 'tweets': v}) for k, v in hashtags.items())


# upload tweets, keywords to mongodb, users to mysql

# s1 = [sum(i>0) for i in x1]

# s1 = [np.log(i) for i in s1]

# from matplotlib import pyplot as plt

# fig, ax = plt.subplots(figsize =(10, 7))
# ax.hist(s1)

# %%
users
# Out:
# {804046791348015107: {'name': 'Bi Sex Uau',
#   'screen_name': 'B_King69',
#   'verified': False,
#   'followers_count': 89,
#   'friends_count': 173,
#   'created_at': 'Wed Nov 30 19:37:48 +0000 2016',
#   'tweets': '1254022770679320576',
#   'id': 804046791348015107,
#   'tweet_count': 1},
#  2242948745: {'name': 'Thomas Krause',
#   'screen_name': 'tho1965',
#   'verified': False,
#   'followers_count': 173,
#   'friends_count': 685,
#   'created_at': 'Wed Dec 25 09:13:33 +0000 2013',
#   'tweets': '1254022770746372096',
#   'id': 2242948745,
#   'tweet_count': 1},
#  2929344220: {'name': 'Ralf Schmitz',
#   'screen_name': 'RusticusArat',
#   'verified': False,
#   'followers_count': 778,
#   'friends_count': 733,
#   'created_at': 'Thu Dec 18 10:19:26 +0000 2014',
#   'tweets': '1254022772575043586',
#   'id': 2929344220,
#   'tweet_count': 1},
#  1091660129894838272: {'name': 'Milli teknoloji',
#   'screen_name': 'milliteknoloj',
#   'verified': False,
#   'followers_count': 2294,
#   'friends_count': 6709,
#   'created_at': 'Sat Feb 02 11:30:31 +0000 2019',
#   'tweets': '1254022773598572544,1254023153204035586,1254034070620823552,1254034130221834241,1254034353396555777,1254034628777783296,1254034874337579008,1254034931753406464,1254050509360697350,1254050612544757760',
#   'id': 1091660129894838272,
#   'tweet_count': 10},
#  375777294: {'name': 'TeéLaneeë🌺',
#   'screen_name': 'TWD40_',
#   'verified': False,
#   'followers_count': 637,
#   'friends_count': 408,
#   'created_at': 'Sun Sep 18 18:25:43 +0000 2011',
#   'tweets': '1254022776094105602',
#   'id': 375777294,
#   'tweet_count': 1},
#  865733987561381888: {'name': 'ANH',
#   'screen_name': 'BritishKatieKim',
#   'verified': False,
#   'followers_count': 142,
#   'friends_count': 881,
#   'created_at': 'Sat May 20 01:00:42 +0000 2017',
#   'tweets': '1254022776207429633',
#   'id': 865733987561381888,
#   'tweet_count': 1},
#  1132273796138905600: {'name': 'Terri Kamp',
#   'screen_name': 'RampTheresa',
#   'verified': False,
#   'followers_count': 1522,
#   'friends_count': 256,
#   'created_at': 'Sat May 25 13:14:44 +0000 2019',
#   'tweets': '1254022776752615430',
#   'id': 1132273796138905600,
#   'tweet_count': 1},
#  301470336: {'name': 'BABA ALI',
#   'screen_name': '_FreshAA',
#   'verified': False,
#   'followers_count': 9406,
#   'friends_count': 1870,
#   'created_at': 'Thu May 19 14:38:22 +0000 2011',
#   'tweets': '1254022778371571712',
#   'id': 301470336,
#   'tweet_count': 1},
#  1035107587006648320: {'name': 'Satya Hindi',
#   'screen_name': 'SatyaHindi',
#   'verified': False,
#   'followers_count': 11576,
#   'friends_count': 20,
#   'created_at': 'Thu Aug 30 10:10:54 +0000 2018',
#   'tweets': '1254022779608891393,1254023668264505344,1254024059446267905,1254025602375602178',
#   'id': 1035107587006648320,
#   'tweet_count': 4},
#  923169415054680064: {'name': 'Quantum',
#   'screen_name': 'QuantumAspect',
#   'verified': False,
#   'followers_count': 3196,
#   'friends_count': 1001,
#   'created_at': 'Wed Oct 25 12:48:35 +0000 2017',
#   'tweets': '1254022780695252993',
#   'id': 923169415054680064,
#   'tweet_count': 1},
#  1120761000561606656: {'name': '🌸',
#   'screen_name': 'cloudseokjinie',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 17,
#   'created_at': 'Tue Apr 23 18:47:00 +0000 2019',
#   'tweets': '1254022781710274566,1254024117621227520,1254024186382729217,1254024370974076928,1254029535978405888,1254029773929668608,1254029886848712704,1254030441188929539,1254030530846306309,1254032610696876032,1254034278993793024,1254034871133052931,1254035453369618432,1254036560653299718,1254037797176061953,1254040092349542402,1254041053142888449,1254041097296322561,1254041159141412864,1254041481331032066,1254042965133217794',
#   'id': 1120761000561606656,
#   'tweet_count': 21},
#  847489262018641921: {'name': 'Dr. Yousuf Majeed',
#   'screen_name': 'dr_yousufmajeed',
#   'verified': False,
#   'followers_count': 25,
#   'friends_count': 45,
#   'created_at': 'Thu Mar 30 16:42:40 +0000 2017',
#   'tweets': '1254022783249637376,1254023012736806912',
#   'id': 847489262018641921,
#   'tweet_count': 2},
#  567891167: {'name': 'St.polat',
#   'screen_name': 'StPolat',
#   'verified': False,
#   'followers_count': 12,
#   'friends_count': 273,
#   'created_at': 'Tue May 01 05:36:13 +0000 2012',
#   'tweets': '1254022784193363969',
#   'id': 567891167,
#   'tweet_count': 1},
#  1151073083836502016: {'name': 'Asian Narratives',
#   'screen_name': 'AsianNarratives',
#   'verified': False,
#   'followers_count': 13,
#   'friends_count': 65,
#   'created_at': 'Tue Jul 16 10:16:23 +0000 2019',
#   'tweets': '1254022784122003457',
#   'id': 1151073083836502016,
#   'tweet_count': 1},
#  1215289012551741443: {'name': 'TopInfo',
#   'screen_name': 'topinfo_id',
#   'verified': False,
#   'followers_count': 169,
#   'friends_count': 183,
#   'created_at': 'Thu Jan 09 15:07:42 +0000 2020',
#   'tweets': '1254022784851861504,1254023581253668865,1254024607696388096,1254027247964520448,1254033181050880000,1254040162868367363,1254045890328887296,1254046952020480002,1254049112976175105,1254049499300990977,1254052902617915399',
#   'id': 1215289012551741443,
#   'tweet_count': 11},
#  1213865493951438849: {'name': 'Jonnieka Farr',
#   'screen_name': 'Farrfor9',
#   'verified': False,
#   'followers_count': 21,
#   'friends_count': 38,
#   'created_at': 'Sun Jan 05 16:51:43 +0000 2020',
#   'tweets': '1254022784646291456',
#   'id': 1213865493951438849,
#   'tweet_count': 1},
#  852883926: {'name': 'Joseph Andrew',
#   'screen_name': 'sam195027',
#   'verified': False,
#   'followers_count': 6,
#   'friends_count': 97,
#   'created_at': 'Sat Sep 29 13:35:54 +0000 2012',
#   'tweets': '1254022785547923457',
#   'id': 852883926,
#   'tweet_count': 1},
#  240950393: {'name': 'Δ',
#   'screen_name': 'icanbgstbgt',
#   'verified': False,
#   'followers_count': 12701,
#   'friends_count': 1070,
#   'created_at': 'Fri Jan 21 03:13:15 +0000 2011',
#   'tweets': '1254022786588131328',
#   'id': 240950393,
#   'tweet_count': 1},
#  2930195686: {'name': 'Malte bleibt da Heimbächer 🇪🇺',
#   'screen_name': 'MHeimbaecher',
#   'verified': False,
#   'followers_count': 339,
#   'friends_count': 545,
#   'created_at': 'Thu Dec 18 17:57:07 +0000 2014',
#   'tweets': '1254022787729174528',
#   'id': 2930195686,
#   'tweet_count': 1},
#  620106850: {'name': 'You’re a Daisy If You Do',
#   'screen_name': 'LibertyLoud',
#   'verified': False,
#   'followers_count': 911,
#   'friends_count': 1167,
#   'created_at': 'Wed Jun 27 15:43:35 +0000 2012',
#   'tweets': '1254022788370833408,1254038617640652802',
#   'id': 620106850,
#   'tweet_count': 2},
#  479687857: {'name': 'Mike Lorenz',
#   'screen_name': 'rancorousvolfan',
#   'verified': False,
#   'followers_count': 155,
#   'friends_count': 406,
#   'created_at': 'Tue Jan 31 17:15:29 +0000 2012',
#   'tweets': '1254022790333771778',
#   'id': 479687857,
#   'tweet_count': 1},
#  1162422360122777601: {'name': 'Saudi 24 News',
#   'screen_name': 'Saudi24N',
#   'verified': False,
#   'followers_count': 773,
#   'friends_count': 2,
#   'created_at': 'Fri Aug 16 17:54:32 +0000 2019',
#   'tweets': '1254022793148141569,1254023875526037504,1254024661094055936,1254025602547568641,1254028721457180674,1254029043281862662,1254030539503423489,1254030806940561408,1254031060909854722,1254034122307231744,1254034610071232513,1254034773091246080,1254035809453379584,1254036120289017858,1254036769516945408,1254037157758500870,1254038788189433857,1254041736164368384,1254043546572787719,1254044067186593792,1254046176770285568,1254046817811120130,1254051875504168974,1254053391807983618,1254053958764683265,1254054393881792512,1254057920918106113,1254058032033660928',
#   'id': 1162422360122777601,
#   'tweet_count': 28},
#  303113303: {'name': 'Elke Billstein/Autorin',
#   'screen_name': 'ElkeBillstein',
#   'verified': False,
#   'followers_count': 156,
#   'friends_count': 406,
#   'created_at': 'Sun May 22 09:48:14 +0000 2011',
#   'tweets': '1254022797376061441',
#   'id': 303113303,
#   'tweet_count': 1},
#  161194531: {'name': 'Fatman',
#   'screen_name': 'DeddyHasan_',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 25,
#   'created_at': 'Wed Jun 30 06:30:49 +0000 2010',
#   'tweets': '1254022798139437057',
#   'id': 161194531,
#   'tweet_count': 1},
#  1246109039483707392: {'name': 'Ranveer Sharma',
#   'screen_name': 'RanveerLawyer',
#   'verified': False,
#   'followers_count': 3,
#   'friends_count': 31,
#   'created_at': 'Fri Apr 03 16:15:35 +0000 2020',
#   'tweets': '1254022799661948928,1254022837637132288,1254022893853462530,1254022957057429504,1254023001970020359,1254023035646074881,1254023070169419776,1254023126050131969,1254023158191067137,1254023189816127491,1254023372553490433,1254023419622014981,1254023466203873280,1254023515826774016,1254023574609973249,1254023792344645632,1254023873898610688,1254023913157341184,1254023967565910016,1254024024583294977,1254047005850173441,1254047194853842944,1254047557577248773,1254047618512142342,1254047712892334080,1254047776041766912,1254047948381569024,1254047986277105664,1254049808538574848,1254049897898299397,1254049933415649282,1254050110696116227,1254050141935292417,1254050207572078592,1254050278216777730,1254050322496081921,1254050350342029313,1254050485297991682,1254050849598382082,1254050950848880641,1254050984277524481,1254051015713869825,1254051055723261953,1254051145187762177,1254051181799911424,1254051259197337606,1254051304592334854,1254051481902354432,1254051624177238017',
#   'id': 1246109039483707392,
#   'tweet_count': 49},
#  2246077632: {'name': 'Chantelle Fabian',
#   'screen_name': 'tellfabian',
#   'verified': False,
#   'followers_count': 205,
#   'friends_count': 958,
#   'created_at': 'Sat Dec 14 20:00:05 +0000 2013',
#   'tweets': '1254022800618242048',
#   'id': 2246077632,
#   'tweet_count': 1},
#  2186147385: {'name': 'Chesco Gwivaha',
#   'screen_name': 'chescogwivaha',
#   'verified': False,
#   'followers_count': 14,
#   'friends_count': 65,
#   'created_at': 'Mon Nov 18 16:13:08 +0000 2013',
#   'tweets': '1254022801318707201,1254036847086493696,1254042279783755783',
#   'id': 2186147385,
#   'tweet_count': 3},
#  1173211287339192320: {'name': 'Mas-mas bucinnya Salshabilla Adriani!',
#   'screen_name': 'dailyofbucin',
#   'verified': False,
#   'followers_count': 159,
#   'friends_count': 69,
#   'created_at': 'Sun Sep 15 12:25:59 +0000 2019',
#   'tweets': '1254022801683443712',
#   'id': 1173211287339192320,
#   'tweet_count': 1},
#  1245599601807114245: {'name': 'coronacrazy',
#   'screen_name': 'Kirb00339581',
#   'verified': False,
#   'followers_count': 1,
#   'friends_count': 9,
#   'created_at': 'Thu Apr 02 06:31:14 +0000 2020',
#   'tweets': '1254022801750659073',
#   'id': 1245599601807114245,
#   'tweet_count': 1},
#  866129731: {'name': 'Prof. Roti Gulung',
#   'screen_name': 'profrotigulung',
#   'verified': False,
#   'followers_count': 4497,
#   'friends_count': 3150,
#   'created_at': 'Sun Oct 07 10:38:48 +0000 2012',
#   'tweets': '1254022801951879169',
#   'id': 866129731,
#   'tweet_count': 1},
#  1074021304179875847: {'name': 'FIBRO BOXER💪🏻🥊',
#   'screen_name': 'fibromyalgiaAmy',
#   'verified': False,
#   'followers_count': 6359,
#   'friends_count': 6302,
#   'created_at': 'Sat Dec 15 19:20:08 +0000 2018',
#   'tweets': '1254022803986112513',
#   'id': 1074021304179875847,
#   'tweet_count': 1},
#  1247639399845814277: {'name': 'Correa dentada',
#   'screen_name': 'cthaistressada',
#   'verified': False,
#   'followers_count': 23,
#   'friends_count': 42,
#   'created_at': 'Tue Apr 07 21:36:41 +0000 2020',
#   'tweets': '1254022804397338626',
#   'id': 1247639399845814277,
#   'tweet_count': 1},
#  730576596: {'name': 'Sivapriyan E.T.B',
#   'screen_name': 'sivaetb',
#   'verified': True,
#   'followers_count': 4337,
#   'friends_count': 324,
#   'created_at': 'Wed Aug 01 12:16:51 +0000 2012',
#   'tweets': '1254022804346777601,1254027211109101568,1254027915869564928,1254028781418803200,1254029865579237376',
#   'id': 730576596,
#   'tweet_count': 5},
#  746734977232998400: {'name': 'Moya Salsabila',
#   'screen_name': 'moyaslsbl',
#   'verified': False,
#   'followers_count': 2045,
#   'friends_count': 1683,
#   'created_at': 'Sat Jun 25 16:01:07 +0000 2016',
#   'tweets': '1254022805827366913',
#   'id': 746734977232998400,
#   'tweet_count': 1},
#  2545415011: {'name': 'amna khan',
#   'screen_name': 'amnafzal2',
#   'verified': False,
#   'followers_count': 372,
#   'friends_count': 92,
#   'created_at': 'Wed Jun 04 06:39:08 +0000 2014',
#   'tweets': '1254022808490909697,1254031702852321280',
#   'id': 2545415011,
#   'tweet_count': 2},
#  140831067: {'name': 'Rabella Wiersma - de Faria 🚜',
#   'screen_name': 'Rabellamaria',
#   'verified': False,
#   'followers_count': 1437,
#   'friends_count': 2570,
#   'created_at': 'Thu May 06 13:35:34 +0000 2010',
#   'tweets': '1254022809552138240',
#   'id': 140831067,
#   'tweet_count': 1},
#  1070251994428948481: {'name': 'Jalala University KABUDI effect',
#   'screen_name': 'MakuruRobert',
#   'verified': False,
#   'followers_count': 9109,
#   'friends_count': 167,
#   'created_at': 'Wed Dec 05 09:42:14 +0000 2018',
#   'tweets': '1254022810990596097,1254035641052037121',
#   'id': 1070251994428948481,
#   'tweet_count': 2},
#  1125741605342908416: {'name': 'owencocoefc',
#   'screen_name': 'owencocoefc',
#   'verified': False,
#   'followers_count': 1822,
#   'friends_count': 3748,
#   'created_at': 'Tue May 07 12:38:08 +0000 2019',
#   'tweets': '1254022812202864640',
#   'id': 1125741605342908416,
#   'tweet_count': 1},
#  1068560551297642497: {'name': 'Meister Becker',
#   'screen_name': 'becker_meister',
#   'verified': False,
#   'followers_count': 343,
#   'friends_count': 670,
#   'created_at': 'Fri Nov 30 17:41:03 +0000 2018',
#   'tweets': '1254022814669119495',
#   'id': 1068560551297642497,
#   'tweet_count': 1},
#  1171940166447116288: {'name': '𝖒𝖎𝖘𝖆𝖐𝖎⛓',
#   'screen_name': 'jisungeyess',
#   'verified': False,
#   'followers_count': 2631,
#   'friends_count': 2655,
#   'created_at': 'Thu Sep 12 00:14:58 +0000 2019',
#   'tweets': '1254022814782423046,1254026235006660608',
#   'id': 1171940166447116288,
#   'tweet_count': 2},
#  242422673: {'name': 'Siri Isaksson',
#   'screen_name': 'dorotheafrenkel',
#   'verified': False,
#   'followers_count': 1702,
#   'friends_count': 3163,
#   'created_at': 'Mon Jan 24 19:09:15 +0000 2011',
#   'tweets': '1254022816846024704',
#   'id': 242422673,
#   'tweet_count': 1},
#  1244250628764971008: {'name': 'Marcela Matimbe',
#   'screen_name': 'marcela_matimbe',
#   'verified': False,
#   'followers_count': 8,
#   'friends_count': 47,
#   'created_at': 'Sun Mar 29 13:10:57 +0000 2020',
#   'tweets': '1254022817399681024',
#   'id': 1244250628764971008,
#   'tweet_count': 1},
#  771379560629665792: {'name': 'South African Traveller',
#   'screen_name': 'African_Odyzzee',
#   'verified': False,
#   'followers_count': 14903,
#   'friends_count': 13870,
#   'created_at': 'Thu Sep 01 16:09:53 +0000 2016',
#   'tweets': '1254022817424662531',
#   'id': 771379560629665792,
#   'tweet_count': 1},
#  283365151: {'name': 'Vignesh',
#   'screen_name': 'AustinVignesh',
#   'verified': False,
#   'followers_count': 12,
#   'friends_count': 9,
#   'created_at': 'Sun Apr 17 04:30:40 +0000 2011',
#   'tweets': '1254022818192334849',
#   'id': 283365151,
#   'tweet_count': 1},
#  83474160: {'name': 'Johannes Steiniger',
#   'screen_name': 'JoSteiniger',
#   'verified': True,
#   'followers_count': 3524,
#   'friends_count': 1266,
#   'created_at': 'Sun Oct 18 23:38:01 +0000 2009',
#   'tweets': '1254022819249184774',
#   'id': 83474160,
#   'tweet_count': 1},
#  101756062: {'name': 'RTtheBEST',
#   'screen_name': 'RTtheBEST',
#   'verified': False,
#   'followers_count': 418294,
#   'friends_count': 407418,
#   'created_at': 'Mon Jan 04 13:20:47 +0000 2010',
#   'tweets': '1254022820507549696',
#   'id': 101756062,
#   'tweet_count': 1},
#  818242179084627970: {'name': 'Bobi Darmawan',
#   'screen_name': 'bobidrmwn',
#   'verified': False,
#   'followers_count': 10,
#   'friends_count': 39,
#   'created_at': 'Sun Jan 08 23:45:12 +0000 2017',
#   'tweets': '1254022821728055296',
#   'id': 818242179084627970,
#   'tweet_count': 1},
#  224572743: {'name': 'Bas Belder',
#   'screen_name': 'BasBelderMEP',
#   'verified': True,
#   'followers_count': 4715,
#   'friends_count': 403,
#   'created_at': 'Thu Dec 09 10:00:45 +0000 2010',
#   'tweets': '1254022824529924096',
#   'id': 224572743,
#   'tweet_count': 1},
#  889119868074823680: {'name': 'Mathieu RWIYEREKA',
#   'screen_name': 'RealMathieuRW',
#   'verified': False,
#   'followers_count': 112,
#   'friends_count': 256,
#   'created_at': 'Sun Jul 23 13:47:50 +0000 2017',
#   'tweets': '1254022826484531204',
#   'id': 889119868074823680,
#   'tweet_count': 1},
#  86841762: {'name': 'Ei pow',
#   'screen_name': 'ThalesMeelo',
#   'verified': False,
#   'followers_count': 542,
#   'friends_count': 268,
#   'created_at': 'Mon Nov 02 01:05:34 +0000 2009',
#   'tweets': '1254022827826692097',
#   'id': 86841762,
#   'tweet_count': 1},
#  284926179: {'name': 'piapee',
#   'screen_name': 'itspiaromualdo',
#   'verified': False,
#   'followers_count': 1439,
#   'friends_count': 1435,
#   'created_at': 'Wed Apr 20 06:33:27 +0000 2011',
#   'tweets': '1254022828069801988',
#   'id': 284926179,
#   'tweet_count': 1},
#  3347588774: {'name': 'UttarPradesh.ORG News',
#   'screen_name': 'WeUttarPradesh',
#   'verified': True,
#   'followers_count': 78749,
#   'friends_count': 0,
#   'created_at': 'Wed Aug 26 10:51:40 +0000 2015',
#   'tweets': '1254022828791398402',
#   'id': 3347588774,
#   'tweet_count': 1},
#  3081185375: {'name': 'Adv Layak Shaikh',
#   'screen_name': 'slayakali93',
#   'verified': False,
#   'followers_count': 8,
#   'friends_count': 92,
#   'created_at': 'Mon Mar 09 08:34:34 +0000 2015',
#   'tweets': '1254022828984279041',
#   'id': 3081185375,
#   'tweet_count': 1},
#  2199357115: {'name': 'prof. Mohd Anisur Rahman Forazy',
#   'screen_name': 'forazyanis',
#   'verified': False,
#   'followers_count': 8,
#   'friends_count': 32,
#   'created_at': 'Sun Nov 17 11:19:32 +0000 2013',
#   'tweets': '1254022829609152513',
#   'id': 2199357115,
#   'tweet_count': 1},
#  1241625899532836866: {'name': 'inder minhas',
#   'screen_name': 'inderminhas7',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 5,
#   'created_at': 'Sun Mar 22 07:21:07 +0000 2020',
#   'tweets': '1254022829642833921',
#   'id': 1241625899532836866,
#   'tweet_count': 1},
#  592628773: {'name': 'Julian Mockert',
#   'screen_name': 'jmockert',
#   'verified': False,
#   'followers_count': 54,
#   'friends_count': 532,
#   'created_at': 'Mon May 28 11:02:56 +0000 2012',
#   'tweets': '1254022832696299522',
#   'id': 592628773,
#   'tweet_count': 1},
#  952890382362316800: {'name': 'Inani اِنانی',
#   'screen_name': 'Inani_yes',
#   'verified': False,
#   'followers_count': 98,
#   'friends_count': 379,
#   'created_at': 'Mon Jan 15 13:09:05 +0000 2018',
#   'tweets': '1254022835720171521,1254049259357270016',
#   'id': 952890382362316800,
#   'tweet_count': 2},
#  3438152645: {'name': 'selim sırrı feroğlu',
#   'screen_name': 'sirriferoglu',
#   'verified': False,
#   'followers_count': 173,
#   'friends_count': 166,
#   'created_at': 'Mon Aug 24 16:27:46 +0000 2015',
#   'tweets': '1254022838387867648',
#   'id': 3438152645,
#   'tweet_count': 1},
#  176965438: {'name': 'sv Ommoord',
#   'screen_name': 'svommoord',
#   'verified': False,
#   'followers_count': 356,
#   'friends_count': 1,
#   'created_at': 'Tue Aug 10 22:32:04 +0000 2010',
#   'tweets': '1254022838903808000',
#   'id': 176965438,
#   'tweet_count': 1},
#  952226761797984257: {'name': 'the man',
#   'screen_name': 'theman55254601',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 23,
#   'created_at': 'Sat Jan 13 17:12:06 +0000 2018',
#   'tweets': '1254022840417804288',
#   'id': 952226761797984257,
#   'tweet_count': 1},
#  1253153659115970560: {'name': '1%hooman',
#   'screen_name': 'emanggadaahlak',
#   'verified': False,
#   'followers_count': 39,
#   'friends_count': 127,
#   'created_at': 'Thu Apr 23 02:48:18 +0000 2020',
#   'tweets': '1254022842993324034',
#   'id': 1253153659115970560,
#   'tweet_count': 1},
#  22926365: {'name': 'Tagesspiegel',
#   'screen_name': 'Tagesspiegel',
#   'verified': True,
#   'followers_count': 404590,
#   'friends_count': 1449,
#   'created_at': 'Thu Mar 05 14:47:03 +0000 2009',
#   'tweets': '1254022843672690689,1254053366461849600,1254056791098392576',
#   'id': 22926365,
#   'tweet_count': 3},
#  1190845316779499522: {'name': 'Kashinath',
#   'screen_name': 'Kashina93479752',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 41,
#   'created_at': 'Sun Nov 03 04:17:18 +0000 2019',
#   'tweets': '1254022844956237825',
#   'id': 1190845316779499522,
#   'tweet_count': 1},
#  1117554533964689415: {'name': 'yaø',
#   'screen_name': 'shapebrainnn',
#   'verified': False,
#   'followers_count': 205,
#   'friends_count': 237,
#   'created_at': 'Sun Apr 14 22:25:38 +0000 2019',
#   'tweets': '1254022845014978561',
#   'id': 1117554533964689415,
#   'tweet_count': 1},
#  811123127166140416: {'name': 'Denise Bloggermum Blog 🏡',
#   'screen_name': 'bloggermumthree',
#   'verified': False,
#   'followers_count': 259,
#   'friends_count': 322,
#   'created_at': 'Tue Dec 20 08:16:38 +0000 2016',
#   'tweets': '1254022845551841280,1254031214257803266',
#   'id': 811123127166140416,
#   'tweet_count': 2},
#  2207400312: {'name': 'Chandan Tandon 🇮🇳',
#   'screen_name': 'Chandan_tndn',
#   'verified': False,
#   'followers_count': 1354,
#   'friends_count': 526,
#   'created_at': 'Thu Nov 21 15:54:47 +0000 2013',
#   'tweets': '1254022845673455617',
#   'id': 2207400312,
#   'tweet_count': 1},
#  569621295: {'name': 'Nugroho Eko',
#   'screen_name': 'NugrohoEkoRav',
#   'verified': False,
#   'followers_count': 346,
#   'friends_count': 1439,
#   'created_at': 'Thu May 03 00:17:17 +0000 2012',
#   'tweets': '1254022845996265472',
#   'id': 569621295,
#   'tweet_count': 1},
#  801962894107627520: {'name': 'RD',
#   'screen_name': '24X7RD',
#   'verified': False,
#   'followers_count': 21,
#   'friends_count': 92,
#   'created_at': 'Fri Nov 25 01:37:08 +0000 2016',
#   'tweets': '1254022846436630528',
#   'id': 801962894107627520,
#   'tweet_count': 1},
#  53075530: {'name': 'buten un binnen',
#   'screen_name': 'butenunbinnen',
#   'verified': True,
#   'followers_count': 34493,
#   'friends_count': 1951,
#   'created_at': 'Thu Jul 02 14:22:52 +0000 2009',
#   'tweets': '1254022846629720064,1254035087861133312',
#   'id': 53075530,
#   'tweet_count': 2},
#  1019932376737038337: {'name': 'Rini Syafri',
#   'screen_name': 'Dr_rinisyafri',
#   'verified': False,
#   'followers_count': 1577,
#   'friends_count': 164,
#   'created_at': 'Thu Jul 19 13:10:02 +0000 2018',
#   'tweets': '1254022847346827266',
#   'id': 1019932376737038337,
#   'tweet_count': 1},
#  1078783576576061441: {'name': '𝖉𝖆𝖓 ៹',
#   'screen_name': 'hzlltai',
#   'verified': False,
#   'followers_count': 840,
#   'friends_count': 807,
#   'created_at': 'Fri Dec 28 22:43:42 +0000 2018',
#   'tweets': '1254022848559165441,1254025154004467712',
#   'id': 1078783576576061441,
#   'tweet_count': 2},
#  722979256867930112: {'name': 'tiberius_ndr',
#   'screen_name': 'tiberius_ndr',
#   'verified': False,
#   'followers_count': 50,
#   'friends_count': 126,
#   'created_at': 'Thu Apr 21 02:44:21 +0000 2016',
#   'tweets': '1254022849657884674',
#   'id': 722979256867930112,
#   'tweet_count': 1},
#  723300496891473920: {'name': '♕𝓢𝓱𝓸𝓷𝓷🕊',
#   'screen_name': 'Satya_Cabello',
#   'verified': False,
#   'followers_count': 61,
#   'friends_count': 337,
#   'created_at': 'Fri Apr 22 00:00:51 +0000 2016',
#   'tweets': '1254022850027163648',
#   'id': 723300496891473920,
#   'tweet_count': 1},
#  3322703139: {'name': 'beca',
#   'screen_name': 'cfcbeca',
#   'verified': False,
#   'followers_count': 519,
#   'friends_count': 414,
#   'created_at': 'Sat Jun 13 10:06:48 +0000 2015',
#   'tweets': '1254022850215915523',
#   'id': 3322703139,
#   'tweet_count': 1},
#  3606360503: {'name': 'Frank Hemicker',
#   'screen_name': 'stb_hemicker',
#   'verified': False,
#   'followers_count': 28,
#   'friends_count': 3,
#   'created_at': 'Thu Sep 10 06:27:07 +0000 2015',
#   'tweets': '1254022850702434304',
#   'id': 3606360503,
#   'tweet_count': 1},
#  17007292: {'name': 'Jannis Schakarian 🇪🇺',
#   'screen_name': 'netzfeuilleton',
#   'verified': True,
#   'followers_count': 4265,
#   'friends_count': 1141,
#   'created_at': 'Mon Oct 27 21:11:32 +0000 2008',
#   'tweets': '1254022851193114624',
#   'id': 17007292,
#   'tweet_count': 1},
#  1465726471: {'name': 'Nándor Hulverscheidt',
#   'screen_name': 'nanhul',
#   'verified': False,
#   'followers_count': 379,
#   'friends_count': 1167,
#   'created_at': 'Tue May 28 21:16:53 +0000 2013',
#   'tweets': '1254022851054764034',
#   'id': 1465726471,
#   'tweet_count': 1},
#  1251068478066290689: {'name': 'Musk_b',
#   'screen_name': 'Muskb7',
#   'verified': False,
#   'followers_count': 16,
#   'friends_count': 190,
#   'created_at': 'Fri Apr 17 08:42:36 +0000 2020',
#   'tweets': '1254022851901788160',
#   'id': 1251068478066290689,
#   'tweet_count': 1},
#  1219653177051697158: {'name': 'محمد المضياني ابو ثامر',
#   'screen_name': 'Abuthamer1211',
#   'verified': False,
#   'followers_count': 152,
#   'friends_count': 371,
#   'created_at': 'Tue Jan 21 16:09:30 +0000 2020',
#   'tweets': '1254022851885240322,1254024041536651264',
#   'id': 1219653177051697158,
#   'tweet_count': 2},
#  1189058443539169282: {'name': 'Erni Yulianti',
#   'screen_name': 'viieeeee_',
#   'verified': False,
#   'followers_count': 14,
#   'friends_count': 46,
#   'created_at': 'Tue Oct 29 05:56:52 +0000 2019',
#   'tweets': '1254022854300987393',
#   'id': 1189058443539169282,
#   'tweet_count': 1},
#  1244144923911356417: {'name': 'Robert2',
#   'screen_name': 'Robert253305291',
#   'verified': False,
#   'followers_count': 3,
#   'friends_count': 80,
#   'created_at': 'Sun Mar 29 06:10:57 +0000 2020',
#   'tweets': '1254022854670237696',
#   'id': 1244144923911356417,
#   'tweet_count': 1},
#  2201175573: {'name': 'Dokuzuncu Köy 🇹🇷',
#   'screen_name': 'dokuzuncu_koy',
#   'verified': False,
#   'followers_count': 2325,
#   'friends_count': 2169,
#   'created_at': 'Sat Nov 30 02:02:04 +0000 2013',
#   'tweets': '1254022836928360450,1254032663553478656,1254037534524522496',
#   'id': 2201175573,
#   'tweet_count': 3},
#  1147063974594306048: {'name': '𝖘𝖔𝖚𝖟𝖆😷',
#   'screen_name': '_souxz',
#   'verified': False,
#   'followers_count': 41,
#   'friends_count': 223,
#   'created_at': 'Fri Jul 05 08:45:37 +0000 2019',
#   'tweets': '1254022852241743873',
#   'id': 1147063974594306048,
#   'tweet_count': 1},
#  1119479264561127424: {'name': 'Khudori Yudhoprawiro',
#   'screen_name': 'MuhamadKhudor18',
#   'verified': False,
#   'followers_count': 62,
#   'friends_count': 672,
#   'created_at': 'Sat Apr 20 05:53:50 +0000 2019',
#   'tweets': '1254022856159014913',
#   'id': 1119479264561127424,
#   'tweet_count': 1},
#  1228183815576682497: {'name': 'HASHTAG UNKNOWN',
#   'screen_name': '890Unknown',
#   'verified': False,
#   'followers_count': 52,
#   'friends_count': 679,
#   'created_at': 'Fri Feb 14 05:07:07 +0000 2020',
#   'tweets': '1254022856721104896,1254029955949899777',
#   'id': 1228183815576682497,
#   'tweet_count': 2},
#  827835348688453632: {'name': 'مانی ب',
#   'screen_name': 'ManisElecti',
#   'verified': False,
#   'followers_count': 364,
#   'friends_count': 92,
#   'created_at': 'Sat Feb 04 11:05:02 +0000 2017',
#   'tweets': '1254022858789052417',
#   'id': 827835348688453632,
#   'tweet_count': 1},
#  33308499: {'name': 'Leila Khan',
#   'screen_name': 'leilakhan',
#   'verified': False,
#   'followers_count': 13157,
#   'friends_count': 791,
#   'created_at': 'Sun Apr 19 20:47:24 +0000 2009',
#   'tweets': '1254022859342712832',
#   'id': 33308499,
#   'tweet_count': 1},
#  751839411403386880: {'name': 'RAM X pro',
#   'screen_name': 'DrRamx',
#   'verified': False,
#   'followers_count': 56,
#   'friends_count': 306,
#   'created_at': 'Sat Jul 09 18:04:18 +0000 2016',
#   'tweets': '1254022859405565957',
#   'id': 751839411403386880,
#   'tweet_count': 1},
#  1210913329381703680: {'name': 'Rahul kumar',
#   'screen_name': 'Rahulku55193241',
#   'verified': False,
#   'followers_count': 4,
#   'friends_count': 45,
#   'created_at': 'Sat Dec 28 13:20:31 +0000 2019',
#   'tweets': '1254022859409637377',
#   'id': 1210913329381703680,
#   'tweet_count': 1},
#  73118798: {'name': 'Alexander Pytlik',
#   'screen_name': 'padrealex',
#   'verified': False,
#   'followers_count': 946,
#   'friends_count': 1975,
#   'created_at': 'Thu Sep 10 13:42:41 +0000 2009',
#   'tweets': '1254022860403879937',
#   'id': 73118798,
#   'tweet_count': 1},
#  1220337048760016896: {'name': 'Tarım Orman Haber',
#   'screen_name': 'tarim_orman',
#   'verified': False,
#   'followers_count': 772,
#   'friends_count': 988,
#   'created_at': 'Thu Jan 23 13:27:00 +0000 2020',
#   'tweets': '1254022861926400003',
#   'id': 1220337048760016896,
#   'tweet_count': 1},
#  562137994: {'name': 'Sert',
#   'screen_name': 'oflu_1461',
#   'verified': False,
#   'followers_count': 745,
#   'friends_count': 131,
#   'created_at': 'Tue Apr 24 16:01:10 +0000 2012',
#   'tweets': '1254022862089990145',
#   'id': 562137994,
#   'tweet_count': 1},
#  2850003644: {'name': 'Tosin Falusi',
#   'screen_name': 'FalusiTosin',
#   'verified': False,
#   'followers_count': 870,
#   'friends_count': 826,
#   'created_at': 'Fri Oct 10 09:13:53 +0000 2014',
#   'tweets': '1254022862811402245',
#   'id': 2850003644,
#   'tweet_count': 1},
#  1040995742448381952: {'name': '👻',
#   'screen_name': 'rejexxion',
#   'verified': False,
#   'followers_count': 94,
#   'friends_count': 179,
#   'created_at': 'Sat Sep 15 16:08:20 +0000 2018',
#   'tweets': '1254022863293763591',
#   'id': 1040995742448381952,
#   'tweet_count': 1},
#  474696583: {'name': 'D.white',
#   'screen_name': 'SirPuffAlot_JLR',
#   'verified': False,
#   'followers_count': 1440,
#   'friends_count': 776,
#   'created_at': 'Thu Jan 26 07:50:47 +0000 2012',
#   'tweets': '1254022866636550144',
#   'id': 474696583,
#   'tweet_count': 1},
#  550082685: {'name': 'Bang Gondrong',
#   'screen_name': 'g_siahaan',
#   'verified': False,
#   'followers_count': 397,
#   'friends_count': 316,
#   'created_at': 'Tue Apr 10 10:39:34 +0000 2012',
#   'tweets': '1254022867634786305',
#   'id': 550082685,
#   'tweet_count': 1},
#  1114663173376888838: {'name': 'Big Boy♟',
#   'screen_name': 'smartkayc',
#   'verified': False,
#   'followers_count': 15051,
#   'friends_count': 12891,
#   'created_at': 'Sat Apr 06 22:56:24 +0000 2019',
#   'tweets': '1254022867185999872',
#   'id': 1114663173376888838,
#   'tweet_count': 1},
#  338209836: {'name': 'Mohit Jain मोहित जैन 🇮🇳',
#   'screen_name': 'INCMohitJain',
#   'verified': False,
#   'followers_count': 11262,
#   'friends_count': 2075,
#   'created_at': 'Tue Jul 19 07:09:01 +0000 2011',
#   'tweets': '1254022866976342018',
#   'id': 338209836,
#   'tweet_count': 1},
#  1226538140770242565: {'name': 'ON na',
#   'screen_name': 'ronna_ov',
#   'verified': False,
#   'followers_count': 16,
#   'friends_count': 20,
#   'created_at': 'Sun Feb 09 16:07:52 +0000 2020',
#   'tweets': '1254022868318318594',
#   'id': 1226538140770242565,
#   'tweet_count': 1},
#  941413892680552453: {'name': 'Rıdvan Günen',
#   'screen_name': 'cizrefirat',
#   'verified': False,
#   'followers_count': 194,
#   'friends_count': 194,
#   'created_at': 'Thu Dec 14 21:05:37 +0000 2017',
#   'tweets': '1254022874727436291',
#   'id': 941413892680552453,
#   'tweet_count': 1},
#  197875474: {'name': 'ᴎiv',
#   'screen_name': 'RealGuy_Vindict',
#   'verified': False,
#   'followers_count': 2912,
#   'friends_count': 918,
#   'created_at': 'Sat Oct 02 18:12:47 +0000 2010',
#   'tweets': '1254022875067101186',
#   'id': 197875474,
#   'tweet_count': 1},
#  540605819: {'name': 'Wolf Sanders',
#   'screen_name': 'SandersWolf',
#   'verified': False,
#   'followers_count': 58,
#   'friends_count': 117,
#   'created_at': 'Fri Mar 30 07:14:57 +0000 2012',
#   'tweets': '1254022878334521345',
#   'id': 540605819,
#   'tweet_count': 1},
#  1213832464176541697: {'name': 'Kavanozdaki Adam',
#   'screen_name': 'kaan_saman',
#   'verified': False,
#   'followers_count': 3000,
#   'friends_count': 4314,
#   'created_at': 'Sun Jan 05 14:40:00 +0000 2020',
#   'tweets': '1254022878862901250,1254030563809406976',
#   'id': 1213832464176541697,
#   'tweet_count': 2},
#  2429190292: {'name': 'Kh khalid Farooq',
#   'screen_name': 'Kkf50',
#   'verified': False,
#   'followers_count': 6011,
#   'friends_count': 747,
#   'created_at': 'Sat Mar 22 16:31:00 +0000 2014',
#   'tweets': '1254022879412473856',
#   'id': 2429190292,
#   'tweet_count': 1},
#  1347429816: {'name': 'Mehmet Sabri UĞURBAŞ🇹🇷',
#   'screen_name': 'msugurbas',
#   'verified': False,
#   'followers_count': 19111,
#   'friends_count': 553,
#   'created_at': 'Fri Apr 12 18:23:52 +0000 2013',
#   'tweets': '1254022879701807106',
#   'id': 1347429816,
#   'tweet_count': 1},
#  78466452: {'name': 'Lira Belacqua',
#   'screen_name': 'KarolMndes',
#   'verified': False,
#   'followers_count': 333,
#   'friends_count': 403,
#   'created_at': 'Wed Sep 30 00:47:03 +0000 2009',
#   'tweets': '1254022881601781765',
#   'id': 78466452,
#   'tweet_count': 1},
#  1111438128: {'name': 'javid',
#   'screen_name': 'javedansarija',
#   'verified': False,
#   'followers_count': 19,
#   'friends_count': 772,
#   'created_at': 'Tue Jan 22 12:44:40 +0000 2013',
#   'tweets': '1254022881731895297',
#   'id': 1111438128,
#   'tweet_count': 1},
#  1095560435753934849: {'name': 'AIADMK Salem',
#   'screen_name': 'ADMK_Salem',
#   'verified': True,
#   'followers_count': 1128,
#   'friends_count': 73,
#   'created_at': 'Wed Feb 13 05:48:57 +0000 2019',
#   'tweets': '1254022882042228737',
#   'id': 1095560435753934849,
#   'tweet_count': 1},
#  331780166: {'name': 'C’dreamz',
#   'screen_name': 'emmyside',
#   'verified': False,
#   'followers_count': 136,
#   'friends_count': 146,
#   'created_at': 'Fri Jul 08 18:11:54 +0000 2011',
#   'tweets': '1254022882876952576',
#   'id': 331780166,
#   'tweet_count': 1},
#  1226029057055195136: {'name': 'Chintan',
#   'screen_name': 'ChintanMajithia',
#   'verified': False,
#   'followers_count': 60,
#   'friends_count': 273,
#   'created_at': 'Sat Feb 08 06:24:53 +0000 2020',
#   'tweets': '1254022885217370114',
#   'id': 1226029057055195136,
#   'tweet_count': 1},
#  1136644779259731968: {'name': 'NewsFirst Kannada',
#   'screen_name': 'NewsFirstKan',
#   'verified': False,
#   'followers_count': 903,
#   'friends_count': 215,
#   'created_at': 'Thu Jun 06 14:43:28 +0000 2019',
#   'tweets': '1254022885355614210,1254031403236257792,1254044727982219264,1254052671704580099,1254053428277346304',
#   'id': 1136644779259731968,
#   'tweet_count': 5},
#  926518122: {'name': 'DANS',
#   'screen_name': 'Danyw1jaya',
#   'verified': False,
#   'followers_count': 460,
#   'friends_count': 239,
#   'created_at': 'Mon Nov 05 00:50:14 +0000 2012',
#   'tweets': '1254022886328696832',
#   'id': 926518122,
#   'tweet_count': 1},
#  1173330666957824001: {'name': 'V. Martini Shaken not Stirred 🧑\u200d⚕️👨🏻\u200d⚕️🥼🙏🩺',
#   'screen_name': 'martinielegante',
#   'verified': False,
#   'followers_count': 361,
#   'friends_count': 506,
#   'created_at': 'Sun Sep 15 20:21:08 +0000 2019',
#   'tweets': '1254022886916001792',
#   'id': 1173330666957824001,
#   'tweet_count': 1},
#  392773603: {'name': 'Paresh Rawal fan',
#   'screen_name': 'Babu_Bhaiyaa',
#   'verified': False,
#   'followers_count': 1144521,
#   'friends_count': 461,
#   'created_at': 'Mon Oct 17 15:09:02 +0000 2011',
#   'tweets': '1254022887297576960',
#   'id': 392773603,
#   'tweet_count': 1},
#  159449407: {'name': '💛🖤Naks💛🖤',
#   'screen_name': 'Naki_Nobi',
#   'verified': False,
#   'followers_count': 1186,
#   'friends_count': 448,
#   'created_at': 'Fri Jun 25 11:57:30 +0000 2010',
#   'tweets': '1254022888774144001',
#   'id': 159449407,
#   'tweet_count': 1},
#  1192200350268379136: {'name': 'thais',
#   'screen_name': 'thaisffsilva',
#   'verified': False,
#   'followers_count': 27,
#   'friends_count': 180,
#   'created_at': 'Wed Nov 06 22:01:44 +0000 2019',
#   'tweets': '1254022888841195527',
#   'id': 1192200350268379136,
#   'tweet_count': 1},
#  1194467040532324352: {'name': '𝙲𝙾𝙼𝙿𝙻𝙸𝙲𝙰𝙳𝙰',
#   'screen_name': 'AmandaMayaratls',
#   'verified': False,
#   'followers_count': 53,
#   'friends_count': 94,
#   'created_at': 'Wed Nov 13 04:08:42 +0000 2019',
#   'tweets': '1254022889067753472',
#   'id': 1194467040532324352,
#   'tweet_count': 1},
#  1969018100: {'name': '👌🌟Fan',
#   'screen_name': 'SUNDERWww',
#   'verified': False,
#   'followers_count': 541,
#   'friends_count': 638,
#   'created_at': 'Fri Oct 18 14:47:17 +0000 2013',
#   'tweets': '1254022889013235713',
#   'id': 1969018100,
#   'tweet_count': 1},
#  1159027698070511616: {'name': 'rejekionowae',
#   'screen_name': 'rrrizkyaditya',
#   'verified': False,
#   'followers_count': 15,
#   'friends_count': 30,
#   'created_at': 'Wed Aug 07 09:05:11 +0000 2019',
#   'tweets': '1254022890216816641',
#   'id': 1159027698070511616,
#   'tweet_count': 1},
#  150228451: {'name': 'Ganadhipan',
#   'screen_name': 'ganadhipan',
#   'verified': False,
#   'followers_count': 724,
#   'friends_count': 207,
#   'created_at': 'Mon May 31 12:09:13 +0000 2010',
#   'tweets': '1254022892993552386,1254024876203085825,1254025947948466177,1254028159948918789,1254041001838227456,1254047280006606849',
#   'id': 150228451,
#   'tweet_count': 6},
#  1210204414239289345: {'name': 'Ingeborg',
#   'screen_name': 'Ingebor86819518',
#   'verified': False,
#   'followers_count': 361,
#   'friends_count': 182,
#   'created_at': 'Thu Dec 26 14:23:54 +0000 2019',
#   'tweets': '1254022894155431936,1254027988674510850',
#   'id': 1210204414239289345,
#   'tweet_count': 2},
#  253535350: {'name': 'Victor',
#   'screen_name': 'vikturA',
#   'verified': False,
#   'followers_count': 517,
#   'friends_count': 376,
#   'created_at': 'Thu Feb 17 12:54:35 +0000 2011',
#   'tweets': '1254022894537056258',
#   'id': 253535350,
#   'tweet_count': 1},
#  1250540638841516032: {'name': 'João pedro',
#   'screen_name': 'Joopedr41115454',
#   'verified': False,
#   'followers_count': 1,
#   'friends_count': 61,
#   'created_at': 'Wed Apr 15 21:45:11 +0000 2020',
#   'tweets': '1254022894528708608',
#   'id': 1250540638841516032,
#   'tweet_count': 1},
#  186055378: {'name': 'Remy®️',
#   'screen_name': 'RemyGoedhart',
#   'verified': False,
#   'followers_count': 449,
#   'friends_count': 222,
#   'created_at': 'Thu Sep 02 13:49:59 +0000 2010',
#   'tweets': '1254022895061393408',
#   'id': 186055378,
#   'tweet_count': 1},
#  321727900: {'name': 'pleasepleaseplsssss',
#   'screen_name': 'thouarttryingme',
#   'verified': False,
#   'followers_count': 847,
#   'friends_count': 545,
#   'created_at': 'Wed Jun 22 01:32:45 +0000 2011',
#   'tweets': '1254022895522717696',
#   'id': 321727900,
#   'tweet_count': 1},
#  1237447743020335104: {'name': 'Coşkun ama coşmayan ✌',
#   'screen_name': 'costurancoskuns',
#   'verified': False,
#   'followers_count': 25,
#   'friends_count': 159,
#   'created_at': 'Tue Mar 10 18:38:41 +0000 2020',
#   'tweets': '1254022894730051585',
#   'id': 1237447743020335104,
#   'tweet_count': 1},
#  896593505383964673: {'name': 'Satish Kumar Garg',
#   'screen_name': 'satishgarg53',
#   'verified': False,
#   'followers_count': 338,
#   'friends_count': 568,
#   'created_at': 'Sun Aug 13 04:45:24 +0000 2017',
#   'tweets': '1254022897120579586',
#   'id': 896593505383964673,
#   'tweet_count': 1},
#  4152020367: {'name': 'Cymrawes',
#   'screen_name': 'cymrawes',
#   'verified': False,
#   'followers_count': 12,
#   'friends_count': 62,
#   'created_at': 'Mon Nov 09 22:03:03 +0000 2015',
#   'tweets': '1254022898752290821',
#   'id': 4152020367,
#   'tweet_count': 1},
#  1247734499590279169: {'name': 'mustikatan',
#   'screen_name': 'mustikatan1',
#   'verified': False,
#   'followers_count': 40,
#   'friends_count': 133,
#   'created_at': 'Wed Apr 08 03:54:40 +0000 2020',
#   'tweets': '1254022899406495745',
#   'id': 1247734499590279169,
#   'tweet_count': 1},
#  1154620161434910720: {'name': 'Sadam',
#   'screen_name': 'Sdmhsn15',
#   'verified': False,
#   'followers_count': 77,
#   'friends_count': 140,
#   'created_at': 'Fri Jul 26 05:11:13 +0000 2019',
#   'tweets': '1254022901088440321',
#   'id': 1154620161434910720,
#   'tweet_count': 1},
#  1206636740372353028: {'name': 'Kim.',
#   'screen_name': 'MinisterKim_',
#   'verified': False,
#   'followers_count': 1309,
#   'friends_count': 1357,
#   'created_at': 'Mon Dec 16 18:06:37 +0000 2019',
#   'tweets': '1254022901675642880,1254059014729674759',
#   'id': 1206636740372353028,
#   'tweet_count': 2},
#  1146827099522699265: {'name': 'Raijin - O Quase come CU',
#   'screen_name': 'OppressionGod',
#   'verified': False,
#   'followers_count': 1706,
#   'friends_count': 504,
#   'created_at': 'Thu Jul 04 17:04:22 +0000 2019',
#   'tweets': '1254022901952585728',
#   'id': 1146827099522699265,
#   'tweet_count': 1},
#  706548939173064704: {'name': 'Altro giornale',
#   'screen_name': 'laltrogiornale1',
#   'verified': False,
#   'followers_count': 1666,
#   'friends_count': 4924,
#   'created_at': 'Sun Mar 06 18:36:08 +0000 2016',
#   'tweets': '1254022902640521224',
#   'id': 706548939173064704,
#   'tweet_count': 1},
#  1214950543: {'name': 'naresh',
#   'screen_name': 'mlsharma72',
#   'verified': False,
#   'followers_count': 9,
#   'friends_count': 72,
#   'created_at': 'Sun Feb 24 09:02:01 +0000 2013',
#   'tweets': '1254022903869272065',
#   'id': 1214950543,
#   'tweet_count': 1},
#  838018569732501508: {'name': 'Einzelfallinfos',
#   'screen_name': 'Einzelfallinfos',
#   'verified': False,
#   'followers_count': 16793,
#   'friends_count': 1,
#   'created_at': 'Sat Mar 04 13:29:31 +0000 2017',
#   'tweets': '1254022905735897089',
#   'id': 838018569732501508,
#   'tweet_count': 1},
#  1241421458661732355: {'name': 'Shah Darshan',
#   'screen_name': 'Shahdarshan1190',
#   'verified': False,
#   'followers_count': 46,
#   'friends_count': 138,
#   'created_at': 'Sat Mar 21 17:49:01 +0000 2020',
#   'tweets': '1254022906172059649,1254023526018879488,1254028959374852096,1254031076021940226,1254031634506100737,1254032006213763072,1254032056776040449,1254032352759644161,1254032413472239616,1254032459349594112,1254032501187772417,1254033319295102976,1254033377914748928,1254040182661296129,1254040237740867587,1254040664255447040,1254040896556982272,1254041062567485446,1254043569683345409,1254043684687040513,1254043797392166914,1254044692678938624,1254044731182645248,1254045257546727425,1254045319584677889,1254045599172829186,1254053231379968000,1254053329543393281,1254053456899260416',
#   'id': 1241421458661732355,
#   'tweet_count': 29},
#  1198197024471937024: {'name': 'Dayak Borneo',
#   'screen_name': 'Anskan7',
#   'verified': False,
#   'followers_count': 244,
#   'friends_count': 916,
#   'created_at': 'Sat Nov 23 11:10:39 +0000 2019',
#   'tweets': '1254022907887382530',
#   'id': 1198197024471937024,
#   'tweet_count': 1},
#  1249396085379854336: {'name': 'Nilesh Mehta',
#   'screen_name': 'NileshM68137778',
#   'verified': False,
#   'followers_count': 2,
#   'friends_count': 11,
#   'created_at': 'Sun Apr 12 17:57:09 +0000 2020',
#   'tweets': '1254022908604792832,1254038336915857408',
#   'id': 1249396085379854336,
#   'tweet_count': 2},
#  313753106: {'name': 'Mas-mas biasa',
#   'screen_name': 'nauval_12',
#   'verified': False,
#   'followers_count': 791,
#   'friends_count': 858,
#   'created_at': 'Thu Jun 09 04:48:06 +0000 2011',
#   'tweets': '1254022909032411136',
#   'id': 313753106,
#   'tweet_count': 1},
#  1177927993315991552: {'name': 'Baris Karagoz',
#   'screen_name': 'baris_karagoz10',
#   'verified': False,
#   'followers_count': 7,
#   'friends_count': 48,
#   'created_at': 'Sat Sep 28 12:48:27 +0000 2019',
#   'tweets': '1254022911129726977',
#   'id': 1177927993315991552,
#   'tweet_count': 1},
#  208151263: {'name': 'jolijn koevoets',
#   'screen_name': 'jolijnk',
#   'verified': False,
#   'followers_count': 49,
#   'friends_count': 253,
#   'created_at': 'Tue Oct 26 18:48:20 +0000 2010',
#   'tweets': '1254022911549210624',
#   'id': 208151263,
#   'tweet_count': 1},
#  332441933: {'name': 'Masish',
#   'screen_name': 'JMasish',
#   'verified': False,
#   'followers_count': 1255,
#   'friends_count': 4997,
#   'created_at': 'Sat Jul 09 20:26:09 +0000 2011',
#   'tweets': '1254022911377244160',
#   'id': 332441933,
#   'tweet_count': 1},
#  48979575: {'name': 'Ron Ogletree ⭐️⭐️⭐️ #QVArmy',
#   'screen_name': 'Sabre3611',
#   'verified': False,
#   'followers_count': 2214,
#   'friends_count': 2438,
#   'created_at': 'Sat Jun 20 10:53:11 +0000 2009',
#   'tweets': '1254022911788269568',
#   'id': 48979575,
#   'tweet_count': 1},
#  720309273536897024: {'name': 'Rawda',
#   'screen_name': 'rraeitis',
#   'verified': False,
#   'followers_count': 412,
#   'friends_count': 541,
#   'created_at': 'Wed Apr 13 17:54:48 +0000 2016',
#   'tweets': '1254022914552270849',
#   'id': 720309273536897024,
#   'tweet_count': 1},
#  1198338608421359617: {'name': 'Guilherme Ramos, o Bonito',
#   'screen_name': '__gholden',
#   'verified': False,
#   'followers_count': 89,
#   'friends_count': 227,
#   'created_at': 'Sat Nov 23 20:32:51 +0000 2019',
#   'tweets': '1254022916859199494',
#   'id': 1198338608421359617,
#   'tweet_count': 1},
#  1228974423266316289: {'name': 'MR.HOMES',
#   'screen_name': '_well_predictor',
#   'verified': False,
#   'followers_count': 72,
#   'friends_count': 197,
#   'created_at': 'Sun Feb 16 09:28:37 +0000 2020',
#   'tweets': '1254022918570475520',
#   'id': 1228974423266316289,
#   'tweet_count': 1},
#  1170214231712718850: {'name': 'Okoro Johnharrison',
#   'screen_name': 'OJohnharrison',
#   'verified': False,
#   'followers_count': 41,
#   'friends_count': 409,
#   'created_at': 'Sat Sep 07 05:56:50 +0000 2019',
#   'tweets': '1254022919786807302',
#   'id': 1170214231712718850,
#   'tweet_count': 1},
#  1217083010308362242: {'name': 'FI Nathan Drake',
#   'screen_name': 'drake_fi',
#   'verified': False,
#   'followers_count': 269,
#   'friends_count': 310,
#   'created_at': 'Tue Jan 14 13:57:21 +0000 2020',
#   'tweets': '1254022922458587138',
#   'id': 1217083010308362242,
#   'tweet_count': 1},
#  843145990613950464: {'name': 'Baha Kirlidokme',
#   'screen_name': 'bahakirlidokme',
#   'verified': False,
#   'followers_count': 365,
#   'friends_count': 2541,
#   'created_at': 'Sat Mar 18 17:04:03 +0000 2017',
#   'tweets': '1254022923637194752',
#   'id': 843145990613950464,
#   'tweet_count': 1},
#  18605926: {'name': 'Unankiê',
#   'screen_name': 'FelixZiul',
#   'verified': False,
#   'followers_count': 35945,
#   'friends_count': 18593,
#   'created_at': 'Sun Jan 04 17:12:32 +0000 2009',
#   'tweets': '1254022925939859457',
#   'id': 18605926,
#   'tweet_count': 1},
#  3387191189: {'name': 'Ranking 😘',
#   'screen_name': 'kolaranking1',
#   'verified': False,
#   'followers_count': 83,
#   'friends_count': 235,
#   'created_at': 'Wed Jul 22 12:03:23 +0000 2015',
#   'tweets': '1254022926388670469,1254024161552449537',
#   'id': 3387191189,
#   'tweet_count': 2},
#  177281538: {'name': 'Anil Jain',
#   'screen_name': 'Anil_Kumar_Jain',
#   'verified': False,
#   'followers_count': 42,
#   'friends_count': 93,
#   'created_at': 'Wed Aug 11 18:46:32 +0000 2010',
#   'tweets': '1254022929643302913,1254025500067983365',
#   'id': 177281538,
#   'tweet_count': 2},
#  847104006388375553: {'name': 'பாமக_கீச்சுகள் 🔥🇷🇴',
#   'screen_name': 'PMK_Tweets',
#   'verified': False,
#   'followers_count': 2391,
#   'friends_count': 7,
#   'created_at': 'Wed Mar 29 15:11:48 +0000 2017',
#   'tweets': '1254022929731301379,1254030104721682433',
#   'id': 847104006388375553,
#   'tweet_count': 2},
#  2185132458: {'name': 'Bhopal Samachar',
#   'screen_name': 'BhopalSamachar',
#   'verified': False,
#   'followers_count': 21056,
#   'friends_count': 58,
#   'created_at': 'Sat Nov 09 22:16:46 +0000 2013',
#   'tweets': '1254022930947702785,1254045235048407040',
#   'id': 2185132458,
#   'tweet_count': 2},
#  1654027975: {'name': 'FKR. FarhaT KhaN RaeeS',
#   'screen_name': 'Fahtsjohndavid',
#   'verified': False,
#   'followers_count': 8,
#   'friends_count': 54,
#   'created_at': 'Wed Aug 07 22:23:02 +0000 2013',
#   'tweets': '1254022931761561600',
#   'id': 1654027975,
#   'tweet_count': 1},
#  1253671996606447616: {'name': 'Ashukumar',
#   'screen_name': 'Ashukum30408584',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 62,
#   'created_at': 'Fri Apr 24 13:08:14 +0000 2020',
#   'tweets': '1254022931690258432',
#   'id': 1253671996606447616,
#   'tweet_count': 1},
#  854069653869670400: {'name': 'avrxx',
#   'screen_name': 'anvrxx',
#   'verified': False,
#   'followers_count': 358,
#   'friends_count': 201,
#   'created_at': 'Mon Apr 17 20:30:48 +0000 2017',
#   'tweets': '1254022931858030593',
#   'id': 854069653869670400,
#   'tweet_count': 1},
#  976426253635997702: {'name': 'Julia',
#   'screen_name': 'CcNnBbCc',
#   'verified': False,
#   'followers_count': 1922,
#   'friends_count': 997,
#   'created_at': 'Wed Mar 21 11:52:14 +0000 2018',
#   'tweets': '1254022932390711297',
#   'id': 976426253635997702,
#   'tweet_count': 1},
#  134135559: {'name': 'Agnes Crawford',
#   'screen_name': 'understandrome',
#   'verified': False,
#   'followers_count': 7025,
#   'friends_count': 1511,
#   'created_at': 'Sat Apr 17 15:00:40 +0000 2010',
#   'tweets': '1254022933565054976',
#   'id': 134135559,
#   'tweet_count': 1},
#  1235265381901750274: {'name': 'Corona Scanner',
#   'screen_name': 'CoronaScanner',
#   'verified': False,
#   'followers_count': 8413,
#   'friends_count': 89,
#   'created_at': 'Wed Mar 04 18:06:54 +0000 2020',
# ...
#   'tweets': '1254023773931495425,1254024215025467396',
#   'id': 927461821509910528,
#   'tweet_count': 2},
#  403693431: {'name': 'Versiliatoday.it',
#   'screen_name': 'Versiliatoday',
#   'verified': False,
#   'followers_count': 9025,
#   'friends_count': 365,
#   'created_at': 'Wed Nov 02 21:29:28 +0000 2011',
#   'tweets': '1254023773617086464',
#   'id': 403693431,
#   'tweet_count': 1},
#  946607770937147392: {'name': 'LEYK',
#   'screen_name': 'firstleyk',
#   'verified': False,
#   'followers_count': 61,
#   'friends_count': 97,
#   'created_at': 'Fri Dec 29 05:04:14 +0000 2017',
#   'tweets': '1254023774673924101',
#   'id': 946607770937147392,
#   'tweet_count': 1},
#  308489343: {'name': 'Chaukidar Devinder Mandlaus',
#   'screen_name': 'DMandlaus',
#   'verified': False,
#   'followers_count': 6,
#   'friends_count': 44,
#   'created_at': 'Tue May 31 14:08:48 +0000 2011',
#   'tweets': '1254023775856648192',
#   'id': 308489343,
#   'tweet_count': 1},
#  1219929673439891456: {'name': 'DAN TANA',
#   'screen_name': 'DANTANA08351683',
#   'verified': False,
#   'followers_count': 6,
#   'friends_count': 38,
#   'created_at': 'Wed Jan 22 10:28:05 +0000 2020',
#   'tweets': '1254023776645320709',
#   'id': 1219929673439891456,
#   'tweet_count': 1},
#  1894385114: {'name': 'murali',
#   'screen_name': 'muralidharanPK',
#   'verified': False,
#   'followers_count': 105,
#   'friends_count': 293,
#   'created_at': 'Sun Sep 22 16:52:53 +0000 2013',
#   'tweets': '1254023776393519105',
#   'id': 1894385114,
#   'tweet_count': 1},
#  2351707399: {'name': 'Thiago de Oliveira',
#   'screen_name': 'troliveira13',
#   'verified': False,
#   'followers_count': 26,
#   'friends_count': 69,
#   'created_at': 'Wed Feb 19 13:35:26 +0000 2014',
#   'tweets': '1254023776792182788',
#   'id': 2351707399,
#   'tweet_count': 1},
#  1859986032: {'name': 'Senco Gold & Diamonds',
#   'screen_name': 'sencogoldindia',
#   'verified': False,
#   'followers_count': 1755,
#   'friends_count': 91,
#   'created_at': 'Fri Sep 13 09:14:20 +0000 2013',
#   'tweets': '1254023776737476611',
#   'id': 1859986032,
#   'tweet_count': 1},
#  837898363139940352: {'name': 'Shuvankar Mandi (বাড়িতে থাকুন, সুস্থ থাকুন)',
#   'screen_name': 'Shuvankar1997',
#   'verified': False,
#   'followers_count': 801,
#   'friends_count': 3019,
#   'created_at': 'Sat Mar 04 05:31:51 +0000 2017',
#   'tweets': '1254023779342303234',
#   'id': 837898363139940352,
#   'tweet_count': 1},
#  1075316462565363712: {'name': 'Motion',
#   'screen_name': 'RealMotionG',
#   'verified': False,
#   'followers_count': 1406,
#   'friends_count': 478,
#   'created_at': 'Wed Dec 19 09:06:37 +0000 2018',
#   'tweets': '1254023782110572546',
#   'id': 1075316462565363712,
#   'tweet_count': 1},
#  595999229: {'name': 'Nikhil Joshi',
#   'screen_name': 'joshi_nikku',
#   'verified': False,
#   'followers_count': 11,
#   'friends_count': 92,
#   'created_at': 'Fri Jun 01 01:28:18 +0000 2012',
#   'tweets': '1254023784367095808',
#   'id': 595999229,
#   'tweet_count': 1},
#  1053732677868634112: {'name': 'Kishore P',
#   'screen_name': 'IndianCitizen34',
#   'verified': False,
#   'followers_count': 4,
#   'friends_count': 31,
#   'created_at': 'Sat Oct 20 19:40:22 +0000 2018',
#   'tweets': '1254023785612632064,1254025997873057792,1254028353083830272,1254028702196719617,1254029160416043008,1254030053714714624,1254031076764217344,1254032400134225922',
#   'id': 1053732677868634112,
#   'tweet_count': 8},
#  1536965822: {'name': 'Yusuf Turan',
#   'screen_name': 'TuranyusufTuran',
#   'verified': False,
#   'followers_count': 7287,
#   'friends_count': 7962,
#   'created_at': 'Fri Jun 21 17:21:45 +0000 2013',
#   'tweets': '1254023786258739200',
#   'id': 1536965822,
#   'tweet_count': 1},
#  1127241005680537601: {'name': 'Noch ein Hans',
#   'screen_name': 'hinterhofposter',
#   'verified': False,
#   'followers_count': 62,
#   'friends_count': 401,
#   'created_at': 'Sat May 11 15:56:13 +0000 2019',
#   'tweets': '1254023786309050368,1254049231452737537',
#   'id': 1127241005680537601,
#   'tweet_count': 2},
#  260573833: {'name': 'SnailMan',
#   'screen_name': 'laurentdarl',
#   'verified': False,
#   'followers_count': 12707,
#   'friends_count': 9927,
#   'created_at': 'Fri Mar 04 04:10:07 +0000 2011',
#   'tweets': '1254023789031108613',
#   'id': 260573833,
#   'tweet_count': 1},
#  53040660: {'name': 'Rutger Storm',
#   'screen_name': 'Rutix',
#   'verified': False,
#   'followers_count': 84,
#   'friends_count': 327,
#   'created_at': 'Thu Jul 02 11:48:08 +0000 2009',
#   'tweets': '1254023789991600129',
#   'id': 53040660,
#   'tweet_count': 1},
#  957934431062327297: {'name': 'Korso Na Gyimi🦁🦋🍃🌚',
#   'screen_name': 'KorSoNagyimi',
#   'verified': False,
#   'followers_count': 7886,
#   'friends_count': 7740,
#   'created_at': 'Mon Jan 29 11:12:20 +0000 2018',
#   'tweets': '1254023792722132992',
#   'id': 957934431062327297,
#   'tweet_count': 1},
#  555315539: {'name': 'DENİZCAN',
#   'screen_name': 'mehmetdenizcan',
#   'verified': False,
#   'followers_count': 699,
#   'friends_count': 732,
#   'created_at': 'Mon Apr 16 18:15:52 +0000 2012',
#   'tweets': '1254023794861248514',
#   'id': 555315539,
#   'tweet_count': 1},
#  2391765882: {'name': 'KenFM.de',
#   'screen_name': 'TeamKenFM',
#   'verified': False,
#   'followers_count': 32835,
#   'friends_count': 440,
#   'created_at': 'Sat Mar 15 23:39:28 +0000 2014',
#   'tweets': '1254023796098506755',
#   'id': 2391765882,
#   'tweet_count': 1},
#  89570511: {'name': 'OparaNews',
#   'screen_name': 'Site_OparaNews',
#   'verified': False,
#   'followers_count': 119,
#   'friends_count': 12,
#   'created_at': 'Thu Nov 12 23:30:29 +0000 2009',
#   'tweets': '1254023797340020738',
#   'id': 89570511,
#   'tweet_count': 1},
#  772033309: {'name': 'david williams',
#   'screen_name': 'davidwi53239790',
#   'verified': False,
#   'followers_count': 26,
#   'friends_count': 88,
#   'created_at': 'Tue Aug 21 18:38:53 +0000 2012',
#   'tweets': '1254023797616902145',
#   'id': 772033309,
#   'tweet_count': 1},
#  2661670559: {'name': 'atasoy',
#   'screen_name': 'serkan_atasoy54',
#   'verified': False,
#   'followers_count': 61,
#   'friends_count': 99,
#   'created_at': 'Tue Jul 01 22:37:00 +0000 2014',
#   'tweets': '1254023799508553730',
#   'id': 2661670559,
#   'tweet_count': 1},
#  2331120405: {'name': 'Bustero',
#   'screen_name': 'NoRivalsProd',
#   'verified': False,
#   'followers_count': 47,
#   'friends_count': 19,
#   'created_at': 'Sat Feb 08 00:56:05 +0000 2014',
#   'tweets': '1254023800854843393',
#   'id': 2331120405,
#   'tweet_count': 1},
#  1242350589150810113: {'name': 'Join Swadeshi',
#   'screen_name': 'JoinSwadeshi',
#   'verified': False,
#   'followers_count': 46,
#   'friends_count': 8,
#   'created_at': 'Tue Mar 24 07:21:20 +0000 2020',
#   'tweets': '1254023803274883073,1254034443712499718',
#   'id': 1242350589150810113,
#   'tweet_count': 2},
#  1130971142372507648: {'name': 'raaaa',
#   'screen_name': 'raaasyy',
#   'verified': False,
#   'followers_count': 3323,
#   'friends_count': 2784,
#   'created_at': 'Tue May 21 22:58:27 +0000 2019',
#   'tweets': '1254023807238434816',
#   'id': 1130971142372507648,
#   'tweet_count': 1},
#  843836217523421184: {'name': 'Frank Gladisch',
#   'screen_name': 'FrankGladisch',
#   'verified': False,
#   'followers_count': 434,
#   'friends_count': 490,
#   'created_at': 'Mon Mar 20 14:46:46 +0000 2017',
#   'tweets': '1254023808979218433,1254046748860964867',
#   'id': 843836217523421184,
#   'tweet_count': 2},
#  951088826692374528: {'name': 'helliausstuggi',
#   'screen_name': 'helliausstuggi',
#   'verified': False,
#   'followers_count': 109,
#   'friends_count': 164,
#   'created_at': 'Wed Jan 10 13:50:21 +0000 2018',
#   'tweets': '1254023809176424448',
#   'id': 951088826692374528,
#   'tweet_count': 1},
#  758657324: {'name': 'One Love',
#   'screen_name': 'abbausmanUK',
#   'verified': False,
#   'followers_count': 5054,
#   'friends_count': 4786,
#   'created_at': 'Wed Aug 15 05:35:55 +0000 2012',
#   'tweets': '1254023809373474817,1254034478252675073',
#   'id': 758657324,
#   'tweet_count': 2},
#  1105749849864060934: {'name': 'Barbie Pâtissière 🥐🇨🇲',
#   'screen_name': 'Angie_Choucake',
#   'verified': False,
#   'followers_count': 5512,
#   'friends_count': 4190,
#   'created_at': 'Wed Mar 13 08:38:02 +0000 2019',
#   'tweets': '1254023809658761223',
#   'id': 1105749849864060934,
#   'tweet_count': 1},
#  343329140: {'name': 'Gastro',
#   'screen_name': 'Gastro_o',
#   'verified': False,
#   'followers_count': 6086,
#   'friends_count': 718,
#   'created_at': 'Wed Jul 27 12:03:39 +0000 2011',
#   'tweets': '1254023810447060992',
#   'id': 343329140,
#   'tweet_count': 1},
#  1215503769128980482: {'name': 'Grey 💜',
#   'screen_name': 'greyvyyy',
#   'verified': False,
#   'followers_count': 11,
#   'friends_count': 40,
#   'created_at': 'Fri Jan 10 05:21:06 +0000 2020',
#   'tweets': '1254023810916868097',
#   'id': 1215503769128980482,
#   'tweet_count': 1},
#  712556834: {'name': 'Sydney Mitchell - Reshan 888',
#   'screen_name': 'Reshan888',
#   'verified': False,
#   'followers_count': 33,
#   'friends_count': 42,
#   'created_at': 'Mon Jul 23 14:57:57 +0000 2012',
#   'tweets': '1254023811500040192',
#   'id': 712556834,
#   'tweet_count': 1},
#  888957181307047936: {'name': 'bela',
#   'screen_name': 'Rareselii',
#   'verified': False,
#   'followers_count': 425,
#   'friends_count': 677,
#   'created_at': 'Sun Jul 23 03:01:22 +0000 2017',
#   'tweets': '1254023812028522496',
#   'id': 888957181307047936,
#   'tweet_count': 1},
#  1251805044464369664: {'name': 'Raj',
#   'screen_name': 'Raj60087975',
#   'verified': False,
#   'followers_count': 1,
#   'friends_count': 36,
#   'created_at': 'Sun Apr 19 09:29:25 +0000 2020',
#   'tweets': '1254023813462982656',
#   'id': 1251805044464369664,
#   'tweet_count': 1},
#  185402933: {'name': 'Budimuly▲',
#   'screen_name': 'ordersofheavens',
#   'verified': False,
#   'followers_count': 1328,
#   'friends_count': 487,
#   'created_at': 'Tue Aug 31 22:26:03 +0000 2010',
#   'tweets': '1254023814444232704',
#   'id': 185402933,
#   'tweet_count': 1},
#  719406413416501248: {'name': 'Newstrack',
#   'screen_name': 'newstrackmedia',
#   'verified': False,
#   'followers_count': 3545,
#   'friends_count': 67,
#   'created_at': 'Mon Apr 11 06:07:09 +0000 2016',
#   'tweets': '1254023816591716353,1254047508147376128',
#   'id': 719406413416501248,
#   'tweet_count': 2},
#  1155280773647351809: {'name': 'ダニエラ🐞',
#   'screen_name': 'Daniisantos2005',
#   'verified': False,
#   'followers_count': 183,
#   'friends_count': 246,
#   'created_at': 'Sun Jul 28 00:56:15 +0000 2019',
#   'tweets': '1254023818395488256,1254024081235685378,1254024539597611010',
#   'id': 1155280773647351809,
#   'tweet_count': 3},
#  1050430920: {'name': '🇮🇳Ankur Rai 💙',
#   'screen_name': 'Ankur3366RAi',
#   'verified': False,
#   'followers_count': 159,
#   'friends_count': 632,
#   'created_at': 'Mon Dec 31 14:25:09 +0000 2012',
#   'tweets': '1254023820626837504,1254026268305174528',
#   'id': 1050430920,
#   'tweet_count': 2},
#  932051823384436736: {'name': 'மன்னார்குடி கிருஷ்ணன் ஸ்ரீ நிவாஸன் (வயசு 58)',
#   'screen_name': 'sfeksk',
#   'verified': False,
#   'followers_count': 21,
#   'friends_count': 155,
#   'created_at': 'Sun Nov 19 01:04:06 +0000 2017',
#   'tweets': '1254023820903497729',
#   'id': 932051823384436736,
#   'tweet_count': 1},
#  1637113921: {'name': '🍑peachlover🍑',
#   'screen_name': 'andinidaa',
#   'verified': False,
#   'followers_count': 125,
#   'friends_count': 201,
#   'created_at': 'Thu Aug 01 04:12:39 +0000 2013',
#   'tweets': '1254023822224678913',
#   'id': 1637113921,
#   'tweet_count': 1},
#  1254007061475622912: {'name': 'Sunil Kumar',
#   'screen_name': 'SunilKu18915983',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 0,
#   'created_at': 'Sat Apr 25 11:19:42 +0000 2020',
#   'tweets': '1254023823537602560,1254025831338463232,1254028683142221826,1254035424164696064,1254038023693635584,1254039882739187713,1254040755045359617',
#   'id': 1254007061475622912,
#   'tweet_count': 7},
#  774789475998334976: {'name': 'lulu carente',
#   'screen_name': 'witchaysha',
#   'verified': False,
#   'followers_count': 373,
#   'friends_count': 311,
#   'created_at': 'Sun Sep 11 01:59:40 +0000 2016',
#   'tweets': '1254023823793573888',
#   'id': 774789475998334976,
#   'tweet_count': 1},
#  357186448: {'name': 'mônica',
#   'screen_name': 'luantivejolindo',
#   'verified': False,
#   'followers_count': 1197,
#   'friends_count': 1109,
#   'created_at': 'Thu Aug 18 00:07:03 +0000 2011',
#   'tweets': '1254023824129044480',
#   'id': 357186448,
#   'tweet_count': 1},
#  141940558: {'name': 'Rebeca #ChávezVive 🇻🇪',
#   'screen_name': 'dpiloncita',
#   'verified': False,
#   'followers_count': 25313,
#   'friends_count': 20759,
#   'created_at': 'Sun May 09 13:27:33 +0000 2010',
#   'tweets': '1254023823978115072,1254040269424668672,1254044229631905792',
#   'id': 141940558,
#   'tweet_count': 3},
#  1197393964279615489: {'name': 'Aaj Ki Jandhara',
#   'screen_name': 'AJandhara',
#   'verified': False,
#   'followers_count': 131,
#   'friends_count': 3701,
#   'created_at': 'Thu Nov 21 05:59:26 +0000 2019',
#   'tweets': '1254023827320799233,1254025648084905984,1254035690985189379,1254038831419940866,1254042666989309952,1254044659719876608,1254048205815246850',
#   'id': 1197393964279615489,
#   'tweet_count': 7},
#  1006876635549786112: {'name': 'NDTVBengali',
#   'screen_name': 'NDTVBengali',
#   'verified': False,
#   'followers_count': 512,
#   'friends_count': 9,
#   'created_at': 'Wed Jun 13 12:31:11 +0000 2018',
#   'tweets': '1254023827413250049,1254039569869295617,1254057647034249216',
#   'id': 1006876635549786112,
#   'tweet_count': 3},
#  1106414301156380673: {'name': 'Hanif Ullah',
#   'screen_name': 'HanifUl92001729',
#   'verified': False,
#   'followers_count': 729,
#   'friends_count': 732,
#   'created_at': 'Fri Mar 15 04:38:20 +0000 2019',
#   'tweets': '1254023828889645057',
#   'id': 1106414301156380673,
#   'tweet_count': 1},
#  1242197092912828417: {'name': '@sandroricardolima',
#   'screen_name': 'sandroricardol2',
#   'verified': False,
#   'followers_count': 1,
#   'friends_count': 10,
#   'created_at': 'Mon Mar 23 21:12:45 +0000 2020',
#   'tweets': '1254023830055587840',
#   'id': 1242197092912828417,
#   'tweet_count': 1},
#  735773700985749506: {'name': 'VALLÉE Jean-Claude',
#   'screen_name': 'jclvallee1',
#   'verified': False,
#   'followers_count': 514,
#   'friends_count': 193,
#   'created_at': 'Thu May 26 10:04:55 +0000 2016',
#   'tweets': '1254023830038814720',
#   'id': 735773700985749506,
#   'tweet_count': 1},
#  1205588125092909057: {'name': 'a writing ass bitch',
#   'screen_name': 'luckynumba3',
#   'verified': False,
#   'followers_count': 181,
#   'friends_count': 106,
#   'created_at': 'Fri Dec 13 20:40:00 +0000 2019',
#   'tweets': '1254023830475022336',
#   'id': 1205588125092909057,
#   'tweet_count': 1},
#  2785118350: {'name': 'Green Janine',
#   'screen_name': 'JanineSteeger',
#   'verified': False,
#   'followers_count': 1574,
#   'friends_count': 611,
#   'created_at': 'Fri Sep 26 07:34:38 +0000 2014',
#   'tweets': '1254023831355887617',
#   'id': 2785118350,
#   'tweet_count': 1},
#  1238703707379941376: {'name': 'Nabia',
#   'screen_name': 'Nabia28088272',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 3,
#   'created_at': 'Sat Mar 14 05:49:35 +0000 2020',
#   'tweets': '1254023832236670978',
#   'id': 1238703707379941376,
#   'tweet_count': 1},
#  1252233735610658817: {'name': 'Alexej Kravtschenko',
#   'screen_name': 'instantpelmeni',
#   'verified': False,
#   'followers_count': 4,
#   'friends_count': 70,
#   'created_at': 'Mon Apr 20 13:52:50 +0000 2020',
#   'tweets': '1254023834904268800',
#   'id': 1252233735610658817,
#   'tweet_count': 1},
#  1150769815721611264: {'name': '人形町界隈の人',
#   'screen_name': 'ningyocho_info',
#   'verified': False,
#   'followers_count': 56,
#   'friends_count': 37,
#   'created_at': 'Mon Jul 15 14:11:19 +0000 2019',
#   'tweets': '1254023838808985600,1254026047885991936',
#   'id': 1150769815721611264,
#   'tweet_count': 2},
#  490173594: {'name': 'Helen M Netland',
#   'screen_name': 'HelenMNetland',
#   'verified': False,
#   'followers_count': 1705,
#   'friends_count': 1779,
#   'created_at': 'Sun Feb 12 09:03:58 +0000 2012',
#   'tweets': '1254023840524574721',
#   'id': 490173594,
#   'tweet_count': 1},
#  338055417: {'name': 'quarantined.',
#   'screen_name': 'jodyannrene',
#   'verified': False,
#   'followers_count': 280,
#   'friends_count': 272,
#   'created_at': 'Tue Jul 19 00:39:53 +0000 2011',
#   'tweets': '1254023840688193536',
#   'id': 338055417,
#   'tweet_count': 1},
#  ...}

# %%
#Insert the tweets onto MongoDB. 

client = MongoClient("mongodb://localhost:27017/")

db = client['TwitterDB']
collection = db['tweets']

# Insert tweets into collection
#set the id of the tweet to the id_str
for tweet_id, tweet_data in tweets.items():
    collection.insert_one(tweet_data)

# %%
len(tweets)
# Out:
# 40804

# %%
#Creating an index based on the "created_at" time

client = MongoClient("mongodb://localhost:27017/")

# Create a new database
db = client["TwitterDB"]

# Create a new collection
collection = db["tweets"]

#Index-Creation. 1 is for ascending order, -1 is for descending order.
#From what I've gathered, using descending might be preferred to pull tweets in reverse chronological order. 
Index = collection.create_index([("created_at",-1)])

print("Index created successfully")
# Out:
# Index created successfully

# %%
#Uploading the keywords onto MongoDB
client = MongoClient("mongodb://localhost:27017/")

# Create a new database
db = client["TwitterDB"]

# Create a new collection
collection = db["keywords"]


# Insert the data into the collection
for word_id, word_data in keywords.items():
    collection.insert_one(word_data)

# %%
len(keywords)
# Out:
# 1453

# %%
#Upload the Hashtag json onto the server

client = MongoClient("mongodb://localhost:27017/")

#Calls back to the TwitterDB
db = client["TwitterDB"]

# Create a new collection
collection = db["hashtags"]

# Insert the data into the collection
for word_id, word_data in hashtags.items():
    collection.insert_one(word_data)

# %%
len(hashtags)
# Out:
# 11334

# %%
##Inserting the Users into MySQL 

#!pip install mysql-connector-python
#!pip install pytz
from mysql.connector import (connection)
import json
import mysql.connector

# %%
#You can download MySQL here: https://dev.mysql.com/downloads/installer/
#Connect to SQL database "localhost" after installing it.
#Note that the user and password must be defined during installation and re-used here.
#the user is "root" and the password is "gXt,:RsU#U-ws:3"
import mysql.connector

try:
    connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3")
    print("Connected to MySQL server.")
except mysql.connector.Error as error:
    print("Failed to connect to MySQL server: {}".format(error))
# Out:
# Connected to MySQL server.

# %%
# create a new database. This database is called "new_database"

connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3")
cursor = connection1.cursor()
cursor.execute("DROP DATABASE IF EXISTS new_database")
cursor.execute("CREATE DATABASE new_database")
print("Database created successfully!")
# Out:
# Database created successfully!

# %%
#create a new table. This one is called users_table and deletes any pre-existing ones. 
from datetime import datetime

connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3",database="new_database")
cursor = connection1.cursor()

cursor.execute("DROP TABLE IF EXISTS users_table")
cursor.execute("""CREATE TABLE users_table (
    id BIGINT PRIMARY KEY,
    name VARCHAR(255),
    screen_name VARCHAR(255),
    followers_count INT,
    friends_count INT,
    verified BOOLEAN,
    created_at DATETIME, 
    tweet_count INT,
    tweets VARCHAR(8191)
)""")

print("Table created successfully!")
# Out:
# Table created successfully!

# %%
#Insert the users into the Table

from datetime import datetime, timezone

connection1 = mysql.connector.connect(
    host="localhost",
    user="root",
    password="gXt,:RsU#U-ws:3",
    database="new_database"
)
cursor = connection1.cursor()

used = set()


for user_id in users:
    if user_id in used:
        continue
    user_data = users[user_id]
    if 'created_at' not in user_data:
        continue
    created_at_str = user_data['created_at'][:-11] + user_data['created_at'][-5:] #(-5 extracts year, -11 extracts time)
    created_at = datetime.strptime(created_at_str, '%a %b %d %H:%M:%S %Y') #a is weekday, b is month, d is day of month, HMS, and Year
    created_at = created_at.replace(tzinfo=timezone.utc) #timezone imported from datetime module
    created_at_str = created_at.strftime('%Y-%m-%d %H:%M:%S') #converts to "YYYY-MM-DD HH:MM:SS" format
    sql = "INSERT INTO users_table (id, name, screen_name, followers_count, friends_count, verified, created_at, tweet_count, tweets) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"
    values = (user_id, user_data['name'], user_data['screen_name'], user_data['followers_count'], user_data['friends_count'],
              user_data['verified'], created_at_str, user_data['tweet_count'], user_data['tweets'])
    cursor.execute(sql, values)
    connection1.commit()
    used.add(user_id)
    
print("Users inserted successfully!")
# Out:
# Users inserted successfully!

# %%
user_data
# Out:
# {'name': 'Venugopi',
#  'screen_name': 'Venu7630',
#  'verified': False,
#  'followers_count': 3,
#  'friends_count': 35,
#  'created_at': 'Tue Jan 07 03:50:17 +0000 2014',
#  'tweets': '1254059751379361793',
#  'id': 2279976427,
#  'tweet_count': 1}

# %%
#Present some of the users as in a dataframe
import pandas as pd

connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3",database="new_database")

cursor = connection1.cursor()

cursor.execute("USE new_database")

cursor.execute("""
    SELECT id, name, screen_name, followers_count, friends_count
    FROM users_table 
    LIMIT 5
    """)

result = cursor.fetchall()

df = pd.DataFrame(result, columns=['id', 'name', 'screen_name', 'followers_count', 'friends_count'])

df
# Out:
#        id               name   screen_name  followers_count  friends_count
# 0    5242     Ahmed Al Omran         ahmed           149844           1919
# 1   12094  Nicholai Reinseth      Nicholai              277            134
# 2   18703     Bruce Marsland     Kanikoski               79            335
# 3   45763   simone tolomelli  sasakifujika             4412            790
# 4  106053             SPORT1        SPORT1           588715           1881

# %%
#Prints top 10 users based on followers_count

connection1 = mysql.connector.connect(
    host="localhost",
    user="root",
    password="gXt,:RsU#U-ws:3",
    database="new_database"
)
cursor = connection1.cursor()
cursor.execute("USE new_database")

cursor.execute("""
    SELECT id, name, screen_name, followers_count, friends_count  
    FROM users_table 
    ORDER BY followers_count DESC 
    LIMIT 10
""")

result = cursor.fetchall()

df = pd.DataFrame(result, columns=['id', 'name', 'screen_name', 'followers_count', 'friends_count'])

df
# Out:
#           id              name      screen_name  followers_count  \
# 0   69183155          detikcom         detikcom         15927642
# 1   62513246      J.K. Rowling       jk_rowling         14608046
# 2   42606652            AajTak           aajtak          9704885
# 3   39240673          ABP News          ABPNews          9562582
# 4  240649814         TIMES NOW         TimesNow          9499328
# 5   56304605  Rajdeep Sardesai  sardesairajdeep          8947342
# 6   24744541          Le Monde        lemondefr          8808784
# 7   55507370         tvOneNews        tvOneNews          8787649
# 8   23343960        Kompas.com        kompascom          7678178
# 9   15016209               NTV              ntv          7429200
#
#    friends_count
# 0             28
# 1            721
# 2            416
# 3            248
# 4            391
# 5            568
# 6            628
# 7             50
# 8             23
# 9             29

# %%
#Number of users in MySQL + a timing 
import time

start_time = time.time()

connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3",database="new_database")
cursor = connection1.cursor()
cursor.execute("USE new_database")
cursor.execute("SELECT COUNT(*) FROM users_table")
result = cursor.fetchone()
print("Number of users in the table:", result[0])
cursor.close()
connection1.close()

end_time = time.time()
print("Execution time for Code 1:", end_time - start_time, "seconds")
# Out:
# Number of users in the table: 33112
# Execution time for Code 1: 0.06165027618408203 seconds

# %%
#Number of users in MySQL + a timing

import json
import time 
start_time = time.time()


with open('/Users/mazinrafi/Downloads/corona-out-3.json') as f:
   file_data = json.load(f)

unique_users = set()

for i in file_data:
   unique_users.add(i['user']['id'])

num_unique_users = len(unique_users)
print("Number of unique users:", num_unique_users)

end_time = time.time()
print("Execution time for Code 2:", end_time - start_time, "seconds")
# Out:
# Number of unique users: 80943
# Execution time for Code 2: 28.00219202041626 seconds
