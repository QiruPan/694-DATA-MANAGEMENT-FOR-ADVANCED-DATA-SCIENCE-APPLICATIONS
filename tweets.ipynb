# %%
#The following is a visualization of the first 1000 tweets pulled up directly from MongoDB. 

from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")
db = client['TwitterDB']
collection = db['tweets']

tweets = collection.find()

for tweet in tweets:
    print(f"_id: {tweet['_id']}")
    print(f"created_at: {tweet['created_at']}")
    print(f"id_str: {tweet['id_str']}")
    print(f"reply_count: {tweet['reply_count']}")
    print(f"retweet_count: {tweet['retweet_count']}")
    print(f"user: {tweet['user']}")
    print(f"user_name: {tweet['user_name']}")
    print(f"text: {tweet['text']}")
    print(f"hashtags: {tweet['hashtags']}")
    print(f"hashtag_count: {tweet['hashtag_count']}")
    print(f"keyword_count: {tweet['keyword_count']}")
    print("-----------")
# Out:
# _id: 1254022770679320576
# created_at: 2020-04-25 12:21:41
# id_str: 1254022770679320576
# reply_count: 0
# retweet_count: 0
# user: 804046791348015107
# user_name: B_King69
# text: É isto, ou vou morrer sem ar ou com o corona https://t.co/O0Y7B3Koj4
# hashtags: []
# hashtag_count: 0
# keyword_count: 8
# -----------
# _id: 1254022770746372096
# created_at: 2020-04-25 12:21:41
# id_str: 1254022770746372096
# reply_count: 0
# retweet_count: 0
# user: 2242948745
# user_name: tho1965
# text: Schöne Runde mit dem Rennrad ✌️
# #sport #corona https://t.co/Uglj9YJPI1
# hashtags: ['corona', 'sport']
# hashtag_count: 2
# keyword_count: 5
# -----------
# _id: 1254022772575043586
# created_at: 2020-04-25 12:21:42
# id_str: 1254022772575043586
# reply_count: 0
# retweet_count: 0
# user: 2929344220
# user_name: RusticusArat
# ...
