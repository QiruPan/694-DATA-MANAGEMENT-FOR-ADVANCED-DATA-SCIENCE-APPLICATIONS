# %%
# !pip install pymongo
from pymongo import MongoClient
import pymongo
# Out:
# Requirement already satisfied: pymongo in ./miniconda3/lib/python3.10/site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./miniconda3/lib/python3.10/site-packages (from pymongo) (2.3.0)

# %%
#before running the code, please read each code block's intructions carefully. 

#Once you open up MongoDB Compass, copy the connection string below to connect to Compass. 
#Download MongoDB Community Edition to host a local cluster: https://www.mongodb.com/docs/manual/tutorial/install-mongodb-on-windows/ 
#An easy tutorial for Mac users: https://medium.com/create-a-clocking-in-system-on-react/creating-a-local-mongodb-database-and-insert-a-document-c6a4a2102a22
#Once you have MongoDB, be sure you can establish a local connection to Compass using the connection string: "mongodb://localhost:27017/"

client = MongoClient("mongodb://localhost:27017/")

# %%
#Inserting corona-out-3's raw data. This is just to view the all of the raw data.

# %%
#Define the database "my_final_database" and the collection "tweets".

db = client["my_final_database"]
collection_name = db["tweets"]

# %%
#The following code opens the corona-out-3 file and loads it into "parsed_data and writes it onto disk.
#Expect this to take a while. 

#The first part loads the data. 
#Note that due to the nature of the original file, each line must be split as shown below. 
#You should modify the code below with the directory to your "corona-out-3" file

import json

with open('/Users/mazinrafi/Downloads/corona-out-3', 'r') as f:
    parsed_data = []
    for line in f:
        line = line.strip()
        if not line:
            continue
        obj = json.loads(line)
        parsed_data.append(obj)

        
#This second part writes the parsed file as a json file to disk. This file is called corona-out-2.json
#You may modify the file's extension to where you would like. This is saved to my download files. 
with open('/Users/mazinrafi/Downloads/corona-out-3.json', 'w') as f:
    json.dump(parsed_data, f)

# %%
#This will load the json file as "file_data" and uses the MongoDB "insert_many" command to insert the tweets. 
#After running this, the db "my_final_database" and "tweets" collection should be viewable on MongoDB Compass. 

#First we read the newly created json file from disk. As expected, this should take a while. 

import json
with open('/Users/mazinrafi/Downloads/corona-out-3.json') as f:
    file_data = json.load(f)
#The total number of tweets is 108596 if you run collection_name.insert_many(file_data). But is that actually true?
    
    
#The actual number of tweets with a unique ID is 108594, meaning 2 documents don't
#have a document id associated with it
We see this here: 
for item in file_data:
    # Insert or update the document in the collection using the "id" field as the unique identifier
    collection_name.replace_one({'id': item['id']}, item, upsert=True)

# %%
#!pip install scikit-learn
#!pip install nltk
#import nltk
#nltk.download('stopwords')

# %%
#Main setup for the App. This uses the TDM Creation code:

import json
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import numpy as np

f= open('/Users/mazinrafi/Downloads/corona-out-3','r')

tweets = {}
texts = {}
users = {}
hashtags = {}

#aside: we might choose to see if verified=True too if you would like
tweet_keys = ['created_at', 'id_str', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count']
user_keys = ['name', 'screen_name', 'verified', 'followers_count', 'friends_count', 'created_at']

for line in f:
    if line == '\n':
        continue
    lx = json.loads(line)
    li = dict((k, lx[k]) for k in tweet_keys if k in lx)
    li['user'] = lx['user']['id']
    
    if not 'retweeted_status' in lx or len(lx['retweeted_status']) == 0:
        li['retweet'] = False
        if 'extended_tweet' in lx:    
            thisText = lx['extended_tweet']['full_text']
        else:
            thisText = lx['text']
        li['text'] = thisText
        texts[lx['id']] = thisText
        hashtag_set = list(set(part[1:] for part in thisText.split() if part.startswith('#')))
        li['hashtags'] = hashtag_set
        for hashtag in hashtag_set:
            if hashtag in hashtags.keys():
                hashtags[hashtag].append(lx['id'])
            else:
                hashtags[hashtag] = [lx['id']]
    else:
        li['retweet'] = True
        li['original_tweet'] = lx['retweeted_status']['id']
    tweets[lx['id']] = li
    if not lx['user']['id'] in users.keys():
        users[lx['user']['id']] = dict((k, lx['user'][k]) for k in user_keys if k in lx['user'])

f.close()

vectorizer = CountVectorizer(token_pattern=r"(?u)\b[a-z][a-z]+\b", stop_words=stopwords.words('english'), min_df = 500)

X = np.transpose(vectorizer.fit_transform(texts.values()))

key_list = [*texts.keys()]
word_list = [*vectorizer.get_feature_names_out()]

X

x1 = X.toarray()

x2 = dict((word_list[w], [key_list[t] for t in np.where(x1[w]>0)[0]]) for w in range(len(x1)))


with open("/Users/mazinrafi/Downloads/overall_tdm.json", "w") as outfile:
    json.dump(x2, outfile, indent=2)

with open("/Users/mazinrafi/Downloads/hashtag_tdm.json", "w") as outfile:
    json.dump(hashtags, outfile, indent=2)

# upload tweets, x2 to mongodb, users to mysql

# s1 = [sum(i>0) for i in x1]

# s1 = [np.log(i) for i in s1]

# from matplotlib import pyplot as plt

# fig, ax = plt.subplots(figsize =(10, 7))
# ax.hist(s1)

# %%
db = client['TwitterDB']
collection = db['tweets']

# Insert tweets into collection
for tweet_id, tweet_data in tweets.items():
    collection.insert_one(tweet_data)

# %%
tweets
# Out:
# {1254022770679320576: {'created_at': 'Sat Apr 25 12:21:41 +0000 2020',
#   'id_str': '1254022770679320576',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 804046791348015107,
#   'retweet': False,
#   'text': 'É isto, ou vou morrer sem ar ou com o corona https://t.co/O0Y7B3Koj4',
#   'hashtags': [],
#   '_id': ObjectId('6445e392bad0a54fc40499e9')},
#  1254022770746372096: {'created_at': 'Sat Apr 25 12:21:41 +0000 2020',
#   'id_str': '1254022770746372096',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2242948745,
#   'retweet': False,
#   'text': 'Schöne Runde mit dem Rennrad ✌️\n#sport #corona https://t.co/Uglj9YJPI1',
#   'hashtags': ['sport', 'corona'],
#   '_id': ObjectId('6445e393bad0a54fc40499ea')},
#  1254022772558368768: {'created_at': 'Sat Apr 25 12:21:42 +0000 2020',
#   'id_str': '1254022772558368768',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 908326492718764034,
#   'retweet': True,
#   'original_tweet': 1253949413191344128,
#   '_id': ObjectId('6445e393bad0a54fc40499eb')},
#  1254022772575043586: {'created_at': 'Sat Apr 25 12:21:42 +0000 2020',
#   'id_str': '1254022772575043586',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2929344220,
#   'retweet': False,
#   'text': 'Was sollen 150 Euro Computerzuschuss bringen? Wer wartet die Computer in den 427 NRW Kommunen (Schulträger) wer die Server vor Ort. Lernen lebt von Face to Face . Sonst könnten wir die Kinder betreut ( keine teure Lehrkraft) vor 1 Computer setzen &amp;zentral aus Düsseldorf beschulen',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc40499ec')},
#  1254022772877131777: {'created_at': 'Sat Apr 25 12:21:42 +0000 2020',
#   'id_str': '1254022772877131777',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1206650133976408064,
#   'retweet': True,
#   'original_tweet': 1252576316135739392,
#   '_id': ObjectId('6445e393bad0a54fc40499ed')},
#  1254022773149589510: {'created_at': 'Sat Apr 25 12:21:42 +0000 2020',
#   'id_str': '1254022773149589510',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1248123252,
#   'retweet': True,
#   'original_tweet': 1253992905703862272,
#   '_id': ObjectId('6445e393bad0a54fc40499ee')},
#  1254022773858545665: {'created_at': 'Sat Apr 25 12:21:42 +0000 2020',
#   'id_str': '1254022773858545665',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 50993809,
#   'retweet': True,
#   'original_tweet': 1254010851142569984,
#   '_id': ObjectId('6445e393bad0a54fc40499ef')},
#  1254022774521081856: {'created_at': 'Sat Apr 25 12:21:42 +0000 2020',
#   'id_str': '1254022774521081856',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 792325679354417152,
#   'retweet': True,
#   'original_tweet': 1253697983343816706,
#   '_id': ObjectId('6445e393bad0a54fc40499f0')},
#  1254022773598572544: {'created_at': 'Sat Apr 25 12:21:42 +0000 2020',
#   'id_str': '1254022773598572544',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1091660129894838272,
#   'retweet': False,
#   'text': '@VinceMcMahon @TripleH We hereby honor to announce that we have developed a brand new treatment method using UV rays / Laser Ray that might be used effectively for preventing all mankind from infectious virus.\n\n#covid #covid19 #Covid_19 #corona #vascular #endovascular https://t.co/YkVlYtJiGL',
#   'hashtags': ['endovascular',
#    'corona',
#    'Covid_19',
#    'vascular',
#    'covid',
#    'covid19'],
#   '_id': ObjectId('6445e393bad0a54fc40499f1')},
#  1254022776094105602: {'created_at': 'Sat Apr 25 12:21:43 +0000 2020',
#   'id_str': '1254022776094105602',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 375777294,
#   'retweet': False,
#   'text': 'im making 17 a hr doing nothing 😭😭😭😭 i love this corona pay',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc40499f2')},
#  1254022776232394752: {'created_at': 'Sat Apr 25 12:21:43 +0000 2020',
#   'id_str': '1254022776232394752',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 469083492,
#   'retweet': True,
#   'original_tweet': 1254021956246126594,
#   '_id': ObjectId('6445e393bad0a54fc40499f3')},
#  1254022776207429633: {'created_at': 'Sat Apr 25 12:21:43 +0000 2020',
#   'id_str': '1254022776207429633',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 865733987561381888,
#   'retweet': False,
#   'text': '@MichaelTouby @ChinaDaily @RVsmtown @YRFairytales @SupportRV @rvelites @5REDVELVET your president is telling his people to inject bleach into their body as a way to cure Corona...might wanna worry about that first\nhttps://t.co/yd7LOi21fN',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc40499f4')},
#  1254022776752615430: {'created_at': 'Sat Apr 25 12:21:43 +0000 2020',
#   'id_str': '1254022776752615430',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1132273796138905600,
#   'retweet': False,
#   'text': 'Oh brother and he gave the kid his corona typewriter..\n\n Tom Hanks tells bullied boy named Corona, "You got a friend in ME!”  https://t.co/unZI6clWbv',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc40499f5')},
#  1254022777268568064: {'created_at': 'Sat Apr 25 12:21:43 +0000 2020',
#   'id_str': '1254022777268568064',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1044295463267119104,
#   'retweet': True,
#   'original_tweet': 1253972665045565441,
#   '_id': ObjectId('6445e393bad0a54fc40499f6')},
#  1254022778363265024: {'created_at': 'Sat Apr 25 12:21:43 +0000 2020',
#   'id_str': '1254022778363265024',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 109877154,
#   'retweet': True,
#   'original_tweet': 1253986335297359874,
#   '_id': ObjectId('6445e393bad0a54fc40499f7')},
#  1254022778371571712: {'created_at': 'Sat Apr 25 12:21:43 +0000 2020',
#   'id_str': '1254022778371571712',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 301470336,
#   'retweet': False,
#   'text': 'ahap , low cut off merchants',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc40499f8')},
#  1254022779608891393: {'created_at': 'Sat Apr 25 12:21:43 +0000 2020',
#   'id_str': '1254022779608891393',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1035107587006648320,
#   'retweet': False,
#   'text': 'पश्चिम बंगाल सरकार ने पहली बार माना है कि हाल फ़िलहाल जिन 57 लोगों की मौत\xa0हुई हैं, उन्हें कोरोना वायरस का संक्रमण भी था।\n\n@MamataOfficial  #लॉकडाउन #COVIDー19  #कोरोना_वायरस #StayHome #COVID  #coronavirus  #Corona\nhttps://t.co/TgehgrJCtE',
#   'hashtags': ['StayHome',
#    'Corona',
#    'कोरोना_वायरस',
#    'लॉकडाउन',
#    'coronavirus',
#    'COVIDー19',
#    'COVID'],
#   '_id': ObjectId('6445e393bad0a54fc40499f9')},
#  1254022780695252993: {'created_at': 'Sat Apr 25 12:21:44 +0000 2020',
#   'id_str': '1254022780695252993',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 923169415054680064,
#   'retweet': False,
#   'text': "Weekly mortality graphs show in some European countries a huge spike of extra corona deaths, and in others no noticeable difference with other years. We can learn something from the latter countries. It won't surprise me if it is that containment works.\nhttps://t.co/4xekkMMVz1",
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc40499fa')},
#  1254022780980527105: {'created_at': 'Sat Apr 25 12:21:44 +0000 2020',
#   'id_str': '1254022780980527105',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2459721182,
#   'retweet': True,
#   'original_tweet': 1254021777799426048,
#   '_id': ObjectId('6445e393bad0a54fc40499fb')},
#  1254022781093601280: {'created_at': 'Sat Apr 25 12:21:44 +0000 2020',
#   'id_str': '1254022781093601280',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2493849410,
#   'retweet': True,
#   'original_tweet': 1253920043571621890,
#   '_id': ObjectId('6445e393bad0a54fc40499fc')},
#  1254022781722923009: {'created_at': 'Sat Apr 25 12:21:44 +0000 2020',
#   'id_str': '1254022781722923009',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 21400571,
#   'retweet': True,
#   'original_tweet': 1254008193044406272,
#   '_id': ObjectId('6445e393bad0a54fc40499fd')},
#  1254022781873856512: {'created_at': 'Sat Apr 25 12:21:44 +0000 2020',
#   'id_str': '1254022781873856512',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1220425350540382209,
#   'retweet': True,
#   'original_tweet': 1254020578115309579,
#   '_id': ObjectId('6445e393bad0a54fc40499fe')},
#  1254022781710274566: {'created_at': 'Sat Apr 25 12:21:44 +0000 2020',
#   'id_str': '1254022781710274566',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1120761000561606656,
#   'retweet': False,
#   'text': 'tony montana yoongi live #kpop trump bp lisa dance soojin taekook fancam au ateez jennie jisoo twice comeback dream superm sm rt ifb oomf corona virus quarantine ariana grande gay vmin jungkook jimin taehyung drop fancam spam views gain mutuals nct mark  https://t.co/s8XT2YJl7R',
#   'hashtags': ['kpop'],
#   '_id': ObjectId('6445e393bad0a54fc40499ff')},
#  1254022782188261376: {'created_at': 'Sat Apr 25 12:21:44 +0000 2020',
#   'id_str': '1254022782188261376',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1228183815576682497,
#   'retweet': True,
#   'original_tweet': 1254021686850174976,
#   '_id': ObjectId('6445e393bad0a54fc4049a00')},
#  1254022782561718272: {'created_at': 'Sat Apr 25 12:21:44 +0000 2020',
#   'id_str': '1254022782561718272',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2870459221,
#   'retweet': True,
#   'original_tweet': 1254020851877453825,
#   '_id': ObjectId('6445e393bad0a54fc4049a01')},
#  1254022783249637376: {'created_at': 'Sat Apr 25 12:21:44 +0000 2020',
#   'id_str': '1254022783249637376',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 847489262018641921,
#   'retweet': False,
#   'text': '@HealthDeptBlo @jam_kamal https://t.co/lyMFMxQoVm\nTHIS PRESS CONFERENCE IS SLAP ON ALL CREATED STRESS WDOUT PROPER KNOWLEDGE OF CORONA. DEATH RATES INCREASED IN THOSE COUNTRIES BLINDLY FOLLOWING LOCK DOWN BCZ COMMON SLOGAN\n" EARLY DIAGNOSIS &amp; EARLY TREATMENT OF DISEASE" &amp; THIS IS NOT POSSIBLE IN LOCK DOWN',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a02')},
#  1254022783480332288: {'created_at': 'Sat Apr 25 12:21:44 +0000 2020',
#   'id_str': '1254022783480332288',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 94687002,
#   'retweet': True,
#   'original_tweet': 1254004704855629824,
#   '_id': ObjectId('6445e393bad0a54fc4049a03')},
#  1254022784193363969: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022784193363969',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 567891167,
#   'retweet': False,
#   'text': '@realDonaldTrump @TuckerCarlson @FoxNews Reis don’t forget drink a glass of disinfectant every day anti-corona',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a04')},
#  1254022784323252225: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022784323252225',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1080798295,
#   'retweet': True,
#   'original_tweet': 1253917813791690752,
#   '_id': ObjectId('6445e393bad0a54fc4049a05')},
#  1254022784122003457: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022784122003457',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1151073083836502016,
#   'retweet': False,
#   'text': 'Germany confirmed a rise from 2,055 to 152,438 in Corona Cases. https://t.co/JosMgsHhGD https://t.co/s9RGnGhont',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a06')},
#  1254022784851861504: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022784851861504',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1215289012551741443,
#   'retweet': False,
#   'text': 'Mendamaikan Marquez-Rossi Lebih Mudah daripada Hadapi Virus\xa0Corona https://t.co/42vUfXwLyU',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a07')},
#  1254022784646291456: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022784646291456',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1213865493951438849,
#   'retweet': False,
#   'text': 'Good morning! See you guys in a few for a great discussion on FB Live regarding our children and the impact the corona virus is having on their education. @JamesShadd, Richland School Dist 2 and Richland One School Board Commissioner Yolanda Anderson will provide insight. https://t.co/pW2KrWCq3E',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a08')},
#  1254022785547923457: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022785547923457',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 852883926,
#   'retweet': False,
#   'text': '@PARTHIPANG14 @boaperosa @mohandreamer Athu unaya mari pesitu sutravana padam kathu kuduka than corona vanthuruku',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a09')},
#  1254022786454077440: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022786454077440',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 776181606004424706,
#   'retweet': True,
#   'original_tweet': 1253968390148030465,
#   '_id': ObjectId('6445e393bad0a54fc4049a0a')},
#  1254022786449891328: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022786449891328',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 834386400665595904,
#   'retweet': True,
#   'original_tweet': 1253547221389389831,
#   '_id': ObjectId('6445e393bad0a54fc4049a0b')},
#  1254022786508623872: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022786508623872',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1184860086008762369,
#   'retweet': True,
#   'original_tweet': 1253994388100984833,
#   '_id': ObjectId('6445e393bad0a54fc4049a0c')},
#  1254022786588131328: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022786588131328',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 240950393,
#   'retweet': False,
#   'text': 'aduh ak bngung bg mo gmn. km itu slain ikut prkumpulan ritwit rewel trnyta haus atensi jg ya bg. krg2in bacot yg ga jelas konsennya bg, biar ga kliatan bloon. hehe\n\nmff skedar mngingatkan',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a0d')},
#  1254022786789466112: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022786789466112',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1178130261302636545,
#   'retweet': True,
#   'original_tweet': 1253901422334062592,
#   '_id': ObjectId('6445e393bad0a54fc4049a0e')},
#  1254022787196387329: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022787196387329',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 814316767665418248,
#   'retweet': True,
#   'original_tweet': 1254018062694703106,
#   '_id': ObjectId('6445e393bad0a54fc4049a0f')},
#  1254022787729174528: {'created_at': 'Sat Apr 25 12:21:45 +0000 2020',
#   'id_str': '1254022787729174528',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2930195686,
#   'retweet': False,
#   'text': 'Eine App sie zu knechten,\nSie alle zu finden,\nDie Daten zu sammeln\nUnd [erstmal] zu binden.\n\nUm Missverständnisse zu verhindern: bezieht sich nicht auf die App selbst sondern die zentrale Speicherung',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a10')},
#  1254022788337348608: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022788337348608',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1103945573353377792,
#   'retweet': True,
#   'original_tweet': 1253654078216962048,
#   '_id': ObjectId('6445e393bad0a54fc4049a11')},
#  1254022788370833408: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022788370833408',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 620106850,
#   'retweet': False,
#   'text': 'Nursing homes have become the newest front in the coronavirus war | Coronavirus | https://t.co/mz00zu9wfl #michigan #covid19 #corona #virus  https://t.co/31lKM93xrv',
#   'hashtags': ['virus', 'covid19', 'corona', 'michigan'],
#   '_id': ObjectId('6445e393bad0a54fc4049a12')},
#  1254022789754806273: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022789754806273',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 937608589450940416,
#   'retweet': True,
#   'original_tweet': 1253933917859545091,
#   '_id': ObjectId('6445e393bad0a54fc4049a13')},
#  1254022790384156677: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022790384156677',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 54516468,
#   'retweet': True,
#   'original_tweet': 1251437519859781632,
#   '_id': ObjectId('6445e393bad0a54fc4049a14')},
#  1254022790333771778: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022790333771778',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 479687857,
#   'retweet': False,
#   'text': 'Very good question...',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a15')},
#  1254022790971351040: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022790971351040',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 4854018732,
#   'retweet': True,
#   'original_tweet': 1253961575641182208,
#   '_id': ObjectId('6445e393bad0a54fc4049a16')},
#  1254022791428550657: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022791428550657',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1027725065302028288,
#   'retweet': True,
#   'original_tweet': 1254004807339331584,
#   '_id': ObjectId('6445e393bad0a54fc4049a17')},
#  1254022791457837056: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022791457837056',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 282033511,
#   'retweet': True,
#   'original_tweet': 1254018494871502848,
#   '_id': ObjectId('6445e393bad0a54fc4049a18')},
#  1254022791600443393: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022791600443393',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2347091406,
#   'retweet': True,
#   'original_tweet': 1253938652406853633,
#   '_id': ObjectId('6445e393bad0a54fc4049a19')},
#  1254022791818608640: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022791818608640',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1108988856404082688,
#   'retweet': True,
#   'original_tweet': 1254021086284599296,
#   '_id': ObjectId('6445e393bad0a54fc4049a1a')},
#  1254022792137388034: {'created_at': 'Sat Apr 25 12:21:46 +0000 2020',
#   'id_str': '1254022792137388034',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 18388923,
#   'retweet': True,
#   'original_tweet': 1253995363423465473,
#   '_id': ObjectId('6445e393bad0a54fc4049a1b')},
#  1254022792502292481: {'created_at': 'Sat Apr 25 12:21:47 +0000 2020',
#   'id_str': '1254022792502292481',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 593525060,
#   'retweet': True,
#   'original_tweet': 1254022102388289538,
#   '_id': ObjectId('6445e393bad0a54fc4049a1c')},
#  1254022792716013569: {'created_at': 'Sat Apr 25 12:21:47 +0000 2020',
#   'id_str': '1254022792716013569',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1209389404080336896,
#   'retweet': True,
#   'original_tweet': 1253945742403633164,
#   '_id': ObjectId('6445e393bad0a54fc4049a1d')},
#  1254022793064112129: {'created_at': 'Sat Apr 25 12:21:47 +0000 2020',
#   'id_str': '1254022793064112129',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 928245694648819712,
#   'retweet': True,
#   'original_tweet': 1254021819469684739,
#   '_id': ObjectId('6445e393bad0a54fc4049a1e')},
#  1254022793148141569: {'created_at': 'Sat Apr 25 12:21:47 +0000 2020',
#   'id_str': '1254022793148141569',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1162422360122777601,
#   'retweet': False,
#   'text': 'Paris challenges Corona by showing a movie on a\xa0wall https://t.co/O5dF4lkJEc',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a1f')},
#  1254022794217615360: {'created_at': 'Sat Apr 25 12:21:47 +0000 2020',
#   'id_str': '1254022794217615360',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1093103671523577856,
#   'retweet': True,
#   'original_tweet': 1253774740608528384,
#   '_id': ObjectId('6445e393bad0a54fc4049a20')},
#  1254022795975000067: {'created_at': 'Sat Apr 25 12:21:47 +0000 2020',
#   'id_str': '1254022795975000067',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1333490040,
#   'retweet': True,
#   'original_tweet': 1253731216811077634,
#   '_id': ObjectId('6445e393bad0a54fc4049a21')},
#  1254022796814024704: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022796814024704',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 224195336,
#   'retweet': True,
#   'original_tweet': 1253744534078599171,
#   '_id': ObjectId('6445e393bad0a54fc4049a22')},
#  1254022797376061441: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022797376061441',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 303113303,
#   'retweet': False,
#   'text': 'Frage \n\nGibt es eigentlich auch noch Menschen, die wie früher normale Krankheiten bekommen und deshalb ins Krankenhaus müssen oder gibt es nur noch Corona-Kranke? 🤔🤷\u200d♀️',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a23')},
#  1254022798110076934: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022798110076934',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1883364229,
#   'retweet': True,
#   'original_tweet': 1253767809902968832,
#   '_id': ObjectId('6445e393bad0a54fc4049a24')},
#  1254022798139437057: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022798139437057',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 161194531,
#   'retweet': False,
#   'text': 'Semoga 🙏',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a25')},
#  1254022799154458624: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022799154458624',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 761553667,
#   'retweet': True,
#   'original_tweet': 1254014804651651072,
#   '_id': ObjectId('6445e393bad0a54fc4049a26')},
#  1254022799661948928: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022799661948928',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1246109039483707392,
#   'retweet': False,
#   'text': '@BJP4India @BJPLive In J&amp;K, a virus exists since 2015 which is more dangerous than corona &amp; that is, SRO 202.\nIt has mentally attacked the educated youth who burn their blood &amp; night for atleast 30 years in studies &amp; are rewarded SRO 202.\nSRO 202 exists only in J&amp;K &amp; nowhere in India.\nRevoke SRO 202',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a27')},
#  1254022800018464769: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022800018464769',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 22707454,
#   'retweet': True,
#   'original_tweet': 1253999485123993601,
#   '_id': ObjectId('6445e393bad0a54fc4049a28')},
#  1254022800618242048: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022800618242048',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2246077632,
#   'retweet': False,
#   'text': 'Yes president trump lets all drink fucking sanitizer #trump #sanitizer #lol #corona',
#   'hashtags': ['corona', 'sanitizer', 'lol', 'trump'],
#   '_id': ObjectId('6445e393bad0a54fc4049a29')},
#  1254022800584646657: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022800584646657',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 127463744,
#   'retweet': True,
#   'original_tweet': 1254021819469684739,
#   '_id': ObjectId('6445e393bad0a54fc4049a2a')},
#  1254022800660025344: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022800660025344',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 848401934386028544,
#   'retweet': True,
#   'original_tweet': 1253973789454589952,
#   '_id': ObjectId('6445e393bad0a54fc4049a2b')},
#  1254022800848728064: {'created_at': 'Sat Apr 25 12:21:48 +0000 2020',
#   'id_str': '1254022800848728064',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1353476622,
#   'retweet': True,
#   'original_tweet': 1253917813791690752,
#   '_id': ObjectId('6445e393bad0a54fc4049a2c')},
#  1254022800878137344: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022800878137344',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1857739392,
#   'retweet': True,
#   'original_tweet': 1253005249389883392,
#   '_id': ObjectId('6445e393bad0a54fc4049a2d')},
#  1254022800983146498: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022800983146498',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2820001086,
#   'retweet': True,
#   'original_tweet': 1254003379401035776,
#   '_id': ObjectId('6445e393bad0a54fc4049a2e')},
#  1254022801427582977: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022801427582977',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1179351763192664064,
#   'retweet': True,
#   'original_tweet': 1254012358529150977,
#   '_id': ObjectId('6445e393bad0a54fc4049a2f')},
#  1254022801318707201: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022801318707201',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2186147385,
#   'retweet': False,
#   'text': '#Chesco_Gwivaha ~ Kabla ya kuguswa fikiria. Kabla ya kuacha. Jaribu. #UWENDE_LIPWELA_________ Maisha ni pesa #stay_safe_at_your_Job_or_home CORONA ni hatari @ Samora Avenue https://t.co/N0dfXxik1V',
#   'hashtags': ['UWENDE_LIPWELA_________',
#    'stay_safe_at_your_Job_or_home',
#    'Chesco_Gwivaha'],
#   '_id': ObjectId('6445e393bad0a54fc4049a30')},
#  1254022801578590209: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022801578590209',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 968998885,
#   'retweet': True,
#   'original_tweet': 1253899329993158659,
#   '_id': ObjectId('6445e393bad0a54fc4049a31')},
#  1254022801683443712: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022801683443712',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1173211287339192320,
#   'retweet': False,
#   'text': 'setiap hari tambahan orang yg positif corona diatas 350. stay safe teman2 semua, ayo ini kapan berakhir plis gamau lama2 🥺😰',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a32')},
#  1254022801750659073: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022801750659073',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1245599601807114245,
#   'retweet': False,
#   'text': '@id_ndou @ewnupdates I think that was the hope, and was maybe even possible before Corona, but the complete shutdown of the travel industry has killed any hope.',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a33')},
#  1254022801951879169: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022801951879169',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 866129731,
#   'retweet': False,
#   'text': 'Prof jadi paham mengapa para kadrun selalu gunakan isu komunis China utk menyerang pemerintah. Semua kerjaannya mamarika yg mengakibatkan ketat persaingan nyinyir antar kadrun dgn pemerintah😊\n\nKetat! Persaingan Militer AS &amp; China di Balik Vaksin Corona \nhttps://t.co/6UdgTb6QIN',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a34')},
#  1254022802115526657: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022802115526657',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 538000592,
#   'retweet': True,
#   'original_tweet': 1253928159915003904,
#   '_id': ObjectId('6445e393bad0a54fc4049a35')},
#  1254022802841104384: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022802841104384',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 104393674,
#   'retweet': True,
#   'original_tweet': 1253790969696120833,
#   '_id': ObjectId('6445e393bad0a54fc4049a36')},
#  1254022803122200577: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022803122200577',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 22605953,
#   'retweet': True,
#   'original_tweet': 1254015837553508353,
#   '_id': ObjectId('6445e393bad0a54fc4049a37')},
#  1254022803969527808: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022803969527808',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1144699678086139904,
#   'retweet': True,
#   'original_tweet': 1253909528342601729,
#   '_id': ObjectId('6445e393bad0a54fc4049a38')},
#  1254022803986112513: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022803986112513',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1074021304179875847,
#   'retweet': False,
#   'text': '🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a39')},
#  1254022804397338626: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022804397338626',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1247639399845814277,
#   'retweet': False,
#   'text': 'Meu whitepeople problem é que minha boca tá inteira machucada por causa do aparelho e eu ia tirar ele no máximo em maio se não fosse pelo corona vírus',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a3a')},
#  1254022804346777601: {'created_at': 'Sat Apr 25 12:21:49 +0000 2020',
#   'id_str': '1254022804346777601',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 730576596,
#   'retweet': False,
#   'text': 'Several district administrations in #TamilNadu have been using the volunteer network to deliver medicines for the aged, cancer patients, and others who cannot get them in their towns and villages. #CoronaUpdatesInIndia #CoronaWarrior #Covid_19 #Corona \n\nhttps://t.co/qtUMhEDL2U',
#   'hashtags': ['CoronaUpdatesInIndia',
#    'CoronaWarrior',
#    'Corona',
#    'Covid_19',
#    'TamilNadu'],
#   '_id': ObjectId('6445e393bad0a54fc4049a3b')},
#  1254022805324066818: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022805324066818',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1418690310,
#   'retweet': True,
#   'original_tweet': 1253730435957264385,
#   '_id': ObjectId('6445e393bad0a54fc4049a3c')},
#  1254022805982711810: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022805982711810',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 917502565490790400,
#   'retweet': True,
#   'original_tweet': 1253987597795373056,
#   '_id': ObjectId('6445e393bad0a54fc4049a3d')},
#  1254022806385369088: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022806385369088',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1239204446019760128,
#   'retweet': True,
#   'original_tweet': 1253727663124107265,
#   '_id': ObjectId('6445e393bad0a54fc4049a3e')},
#  1254022805827366913: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022805827366913',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 746734977232998400,
#   'retweet': False,
#   'text': 'Gara-gara corona aku jadi punya drama gula pasir😕 https://t.co/Wj661x64FP',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a3f')},
#  1254022806574153728: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022806574153728',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 797829077596012545,
#   'retweet': True,
#   'original_tweet': 1253959009415110657,
#   '_id': ObjectId('6445e393bad0a54fc4049a40')},
#  1254022806712520705: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022806712520705',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 785288949879242753,
#   'retweet': True,
#   'original_tweet': 1253836349293105154,
#   '_id': ObjectId('6445e393bad0a54fc4049a41')},
#  1254022806834221056: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022806834221056',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 999598748228501505,
#   'retweet': True,
#   'original_tweet': 1253704999428747265,
#   '_id': ObjectId('6445e393bad0a54fc4049a42')},
#  1254022806926430208: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022806926430208',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 913433214164729856,
#   'retweet': True,
#   'original_tweet': 1253971355973767170,
#   '_id': ObjectId('6445e393bad0a54fc4049a43')},
#  1254022807358517253: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022807358517253',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1392274176,
#   'retweet': True,
#   'original_tweet': 1253976400283029506,
#   '_id': ObjectId('6445e393bad0a54fc4049a44')},
#  1254022807626960896: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022807626960896',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 887662219,
#   'retweet': True,
#   'original_tweet': 1253977978620518400,
#   '_id': ObjectId('6445e393bad0a54fc4049a45')},
#  1254022808327217152: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022808327217152',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1093103671523577856,
#   'retweet': True,
#   'original_tweet': 1253768914049384449,
#   '_id': ObjectId('6445e393bad0a54fc4049a46')},
#  1254022808398594049: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022808398594049',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 751929355,
#   'retweet': True,
#   'original_tweet': 1253994123100446720,
#   '_id': ObjectId('6445e393bad0a54fc4049a47')},
#  1254022808604114945: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022808604114945',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1065441285798998016,
#   'retweet': True,
#   'original_tweet': 1254015074064191488,
#   '_id': ObjectId('6445e393bad0a54fc4049a48')},
#  1254022808490909697: {'created_at': 'Sat Apr 25 12:21:50 +0000 2020',
#   'id_str': '1254022808490909697',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2545415011,
#   'retweet': False,
#   'text': 'Kitti nasloun kee qubaniyoun se milla . Aye watan tujhay corona kay hutthay nee charnay dein gey . @ImranKhanPTI if takin us 2 suicide , we will resist ..Lockdown we will impose on our selves to help our docs paramedics n our security forces  @OfficialDGISPR',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a49')},
#  1254022809451405312: {'created_at': 'Sat Apr 25 12:21:51 +0000 2020',
#   'id_str': '1254022809451405312',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 971227567595376642,
#   'retweet': True,
#   'original_tweet': 1254021819469684739,
#   '_id': ObjectId('6445e393bad0a54fc4049a4a')},
#  1254022809703112704: {'created_at': 'Sat Apr 25 12:21:51 +0000 2020',
#   'id_str': '1254022809703112704',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1180839562635087872,
#   'retweet': True,
#   'original_tweet': 1253996934626521089,
#   '_id': ObjectId('6445e393bad0a54fc4049a4b')},
#  1254022809552138240: {'created_at': 'Sat Apr 25 12:21:51 +0000 2020',
#   'id_str': '1254022809552138240',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 140831067,
#   'retweet': False,
#   'text': 'Yep...zei ik al vanaf het begin...#groepsimmuniteit nastreven zonder werkzaam medicijn is Russische roulette spelen met je inwoners...zonder testen, zonder mondkapjes...tja...',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a4c')},
#  1254022810810408961: {'created_at': 'Sat Apr 25 12:21:51 +0000 2020',
#   'id_str': '1254022810810408961',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1044480521386975234,
#   'retweet': True,
#   'original_tweet': 1253618006585946113,
#   '_id': ObjectId('6445e393bad0a54fc4049a4d')},
#  1254022810990596097: {'created_at': 'Sat Apr 25 12:21:51 +0000 2020',
#   'id_str': '1254022810990596097',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1070251994428948481,
#   'retweet': False,
#   'text': '@azamtvtz Police ambae atakuja kunikamata namwambia nina viashiria vyote vya corona aje nimbaghaze navyo\nNitamkumbusha kua haviogopi bunduki wala pingu wala hata selo havijawahi kuogopa\n\nNitampa mifano hai ya vigogo wazito waliopata licha ya ubabe wao ikiwemo RWAKATARE',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a4e')},
#  1254022811930198016: {'created_at': 'Sat Apr 25 12:21:51 +0000 2020',
#   'id_str': '1254022811930198016',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 821435447943528448,
#   'retweet': True,
#   'original_tweet': 1254009056517332998,
#   '_id': ObjectId('6445e393bad0a54fc4049a4f')},
#  1254022812202864640: {'created_at': 'Sat Apr 25 12:21:51 +0000 2020',
#   'id_str': '1254022812202864640',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1125741605342908416,
#   'retweet': False,
#   'text': 'Wizz Air to resume flights from Luton Airport on Friday\n\nSomeone should start a Corona Airways Company \nThere Slogan could be\n "We take Corona passengers everywhere"\nwith no checks at all in the UK',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a50')},
#  1254022812563628033: {'created_at': 'Sat Apr 25 12:21:51 +0000 2020',
#   'id_str': '1254022812563628033',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 920075544548597761,
#   'retweet': True,
#   'original_tweet': 1253572501172391936,
#   '_id': ObjectId('6445e393bad0a54fc4049a51')},
#  1254022813687611393: {'created_at': 'Sat Apr 25 12:21:52 +0000 2020',
#   'id_str': '1254022813687611393',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2666107580,
#   'retweet': True,
#   'original_tweet': 1253977978620518400,
#   '_id': ObjectId('6445e393bad0a54fc4049a52')},
#  1254022813712711681: {'created_at': 'Sat Apr 25 12:21:52 +0000 2020',
#   'id_str': '1254022813712711681',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 18236335,
#   'retweet': True,
#   'original_tweet': 1253905360529682432,
#   '_id': ObjectId('6445e393bad0a54fc4049a53')},
#  1254022814669119495: {'created_at': 'Sat Apr 25 12:21:52 +0000 2020',
#   'id_str': '1254022814669119495',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1068560551297642497,
#   'retweet': False,
#   'text': '@Markus_Wojahn Gucks nicht, lege mich gerade wieder notdürftig trocken. Das ist mein Corona- Hit.......\nhttps://t.co/NfE5LqGCcN',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a54')},
#  1254022814782423046: {'created_at': 'Sat Apr 25 12:21:52 +0000 2020',
#   'id_str': '1254022814782423046',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1171940166447116288,
#   'retweet': False,
#   'text': '@lalisaflame corona neah tá fodah',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a55')},
#  1254022815554113536: {'created_at': 'Sat Apr 25 12:21:52 +0000 2020',
#   'id_str': '1254022815554113536',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2579234981,
#   'retweet': True,
#   'original_tweet': 1254016843070799878,
#   '_id': ObjectId('6445e393bad0a54fc4049a56')},
#  1254022816199929856: {'created_at': 'Sat Apr 25 12:21:52 +0000 2020',
#   'id_str': '1254022816199929856',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 488135808,
#   'retweet': True,
#   'original_tweet': 1253977763855298560,
#   '_id': ObjectId('6445e393bad0a54fc4049a57')},
#  1254022816846024704: {'created_at': 'Sat Apr 25 12:21:52 +0000 2020',
#   'id_str': '1254022816846024704',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 242422673,
#   'retweet': False,
#   'text': 'Jag reagerade också på detta, cynismen o bristen av respekt för livet i FHMs kommunikation är extremt beklämmande',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a58')},
#  1254022817399681024: {'created_at': 'Sat Apr 25 12:21:52 +0000 2020',
#   'id_str': '1254022817399681024',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1244250628764971008,
#   'retweet': False,
#   'text': 'Para o bem da minha saúde mental já não controlo o número de casos de Corona vírus.',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a59')},
#  1254022817424662531: {'created_at': 'Sat Apr 25 12:21:52 +0000 2020',
#   'id_str': '1254022817424662531',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 771379560629665792,
#   'retweet': False,
#   'text': '@MirandaSemane They have off-peak specials starting mid-May and I think their prices will be even lower post corona 😊',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a5a')},
#  1254022817768542208: {'created_at': 'Sat Apr 25 12:21:53 +0000 2020',
#   'id_str': '1254022817768542208',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1246765161433595904,
#   'retweet': True,
#   'original_tweet': 1253897418254413824,
#   '_id': ObjectId('6445e393bad0a54fc4049a5b')},
#  1254022818066395141: {'created_at': 'Sat Apr 25 12:21:53 +0000 2020',
#   'id_str': '1254022818066395141',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1061479345384972288,
#   'retweet': True,
#   'original_tweet': 1253995820002586624,
#   '_id': ObjectId('6445e393bad0a54fc4049a5c')},
#  1254022818192334849: {'created_at': 'Sat Apr 25 12:21:53 +0000 2020',
#   'id_str': '1254022818192334849',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 283365151,
#   'retweet': False,
#   'text': '@nask08 @hakeem_sheik Understand jo’s words correctly.. “Hospitals are as important, schools are as important..Lets donate them also”.she says treat hospitals and schools as important as temple.please don’t politicize. If u get corona u go to hospital,not temple. Maintain them equally is d message',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a5d')},
#  1254022818435682304: {'created_at': 'Sat Apr 25 12:21:53 +0000 2020',
#   'id_str': '1254022818435682304',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 966984463598186496,
#   'retweet': True,
#   'original_tweet': 1254021520424402944,
#   '_id': ObjectId('6445e393bad0a54fc4049a5e')},
#  1254022818611724289: {'created_at': 'Sat Apr 25 12:21:53 +0000 2020',
#   'id_str': '1254022818611724289',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 140831067,
#   'retweet': True,
#   'original_tweet': 1253962450975760385,
#   '_id': ObjectId('6445e393bad0a54fc4049a5f')},
#  1254022818460839940: {'created_at': 'Sat Apr 25 12:21:53 +0000 2020',
#   'id_str': '1254022818460839940',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 758670622654337025,
#   'retweet': True,
#   'original_tweet': 1254018635112370176,
#   '_id': ObjectId('6445e393bad0a54fc4049a60')},
#  1254022819249184774: {'created_at': 'Sat Apr 25 12:21:53 +0000 2020',
#   'id_str': '1254022819249184774',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 83474160,
#   'retweet': False,
#   'text': '@BernhardBraunLT @JuliaKloeckner @Wissing @derspiegel @JuliaKloeckner wie kommst du darauf, dass auch die Länder einen finanziellen Beitrag zur Bekämpfung der Corona-Folgen leisten sollten?! ;-)',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a61')},
#  1254022820507549696: {'created_at': 'Sat Apr 25 12:21:53 +0000 2020',
#   'id_str': '1254022820507549696',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 101756062,
#   'retweet': False,
#   'text': '“Live Interview” with #covid_19 This guy is super creative.\n.\n.\n.\n.\n#covid #covid19 #corona #coronavirus #stayhome #staysafe #georgia #florida https://t.co/vC7Zo6kjjr',
#   'hashtags': ['georgia',
#    'stayhome',
#    'corona',
#    'coronavirus',
#    'staysafe',
#    'florida',
#    'covid',
#    'covid_19',
#    'covid19'],
#   '_id': ObjectId('6445e393bad0a54fc4049a62')},
#  1254022821728055296: {'created_at': 'Sat Apr 25 12:21:53 +0000 2020',
#   'id_str': '1254022821728055296',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 818242179084627970,
#   'retweet': False,
#   'text': 'Ramadan ku direnggut corona.',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049a63')},
#  1254022821807824897: {'created_at': 'Sat Apr 25 12:21:53 +0000 2020',
#   'id_str': '1254022821807824897',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
# ...
#   'hashtags': ['CoronaVirusUpdates', 'COVID19SL'],
#   '_id': ObjectId('6445e393bad0a54fc4049da9')},
#  1254023153342390273: {'created_at': 'Sat Apr 25 12:23:13 +0000 2020',
#   'id_str': '1254023153342390273',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 963709670480273408,
#   'retweet': True,
#   'original_tweet': 1253895121831170048,
#   '_id': ObjectId('6445e393bad0a54fc4049daa')},
#  1254023153946329088: {'created_at': 'Sat Apr 25 12:23:13 +0000 2020',
#   'id_str': '1254023153946329088',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1247537297295200256,
#   'retweet': True,
#   'original_tweet': 1253983992719855616,
#   '_id': ObjectId('6445e393bad0a54fc4049dab')},
#  1254023153204035586: {'created_at': 'Sat Apr 25 12:23:13 +0000 2020',
#   'id_str': '1254023153204035586',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1091660129894838272,
#   'retweet': False,
#   'text': '@aleynaakbuluut We hereby honor to announce that we have developed a brand new treatment method using UV rays / Laser Ray that might be used effectively for preventing all mankind from infectious virus.\n\n#covid #covid19 #Covid_19 #corona #vascular #endovascular https://t.co/2kFF0dGgFq',
#   'hashtags': ['endovascular',
#    'corona',
#    'Covid_19',
#    'vascular',
#    'covid',
#    'covid19'],
#   '_id': ObjectId('6445e393bad0a54fc4049dac')},
#  1254023154608955392: {'created_at': 'Sat Apr 25 12:23:13 +0000 2020',
#   'id_str': '1254023154608955392',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1061479345384972288,
#   'retweet': True,
#   'original_tweet': 1253922172545843200,
#   '_id': ObjectId('6445e393bad0a54fc4049dad')},
#  1254023155200462848: {'created_at': 'Sat Apr 25 12:23:13 +0000 2020',
#   'id_str': '1254023155200462848',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1134464145322053632,
#   'retweet': True,
#   'original_tweet': 1254022848559165441,
#   '_id': ObjectId('6445e393bad0a54fc4049dae')},
#  1254023155611361280: {'created_at': 'Sat Apr 25 12:23:13 +0000 2020',
#   'id_str': '1254023155611361280',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 791831262617034753,
#   'retweet': True,
#   'original_tweet': 1254023027190366208,
#   '_id': ObjectId('6445e393bad0a54fc4049daf')},
#  1254023156429291520: {'created_at': 'Sat Apr 25 12:23:13 +0000 2020',
#   'id_str': '1254023156429291520',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1154258912129904645,
#   'retweet': True,
#   'original_tweet': 1254020573782515714,
#   '_id': ObjectId('6445e393bad0a54fc4049db0')},
#  1254023156932636674: {'created_at': 'Sat Apr 25 12:23:13 +0000 2020',
#   'id_str': '1254023156932636674',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 844596523325243392,
#   'retweet': True,
#   'original_tweet': 1253722887782928384,
#   '_id': ObjectId('6445e393bad0a54fc4049db1')},
#  1254023157096177664: {'created_at': 'Sat Apr 25 12:23:13 +0000 2020',
#   'id_str': '1254023157096177664',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 350269572,
#   'retweet': True,
#   'original_tweet': 1254009390874546176,
#   '_id': ObjectId('6445e393bad0a54fc4049db2')},
#  1254023157033377792: {'created_at': 'Sat Apr 25 12:23:13 +0000 2020',
#   'id_str': '1254023157033377792',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 370801221,
#   'retweet': False,
#   'text': 'Missing all the fun of the game. Both on the green fields and on the screen. \n\nWanna hit Corona out of boundaries on the 1st ball of my innings. Like virendersehwag\n\nWanna clean bowl at… https://t.co/oEgfbNkFCi',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049db3')},
#  1254023157469646848: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023157469646848',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1251073273653157888,
#   'retweet': True,
#   'original_tweet': 1253228625459118080,
#   '_id': ObjectId('6445e393bad0a54fc4049db4')},
#  1254023157444419584: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023157444419584',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 182333564,
#   'retweet': False,
#   'text': 'Thomas Carle: !!!NEW!!! Deutsch &amp; English !!! CoVid-19 / "Corona" - recognize the early symptoms: https://t.co/KkOo90FNpL -. Your Securityexpert. 5 rules for Your safety. https://t.co/OkjXD6jzd5 https://t.co/dhD63M7Y1G',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049db5')},
#  1254023158191067137: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023158191067137',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1246109039483707392,
#   'retweet': False,
#   'text': '@BJP4India @BJPLive In J&amp;K, a virus exists since 2015 which is more dangerous than corona &amp; that is, SRO 202.\nIt has mentally attacked the educated youth who burn their blood &amp; night for atleast 30 years in studies &amp; are rewarded SRO 202.\nSRO 202 exists only in J&amp;K &amp; nowhere in India.\nRevoke SRO 202',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049db6')},
#  1254023158572748806: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023158572748806',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2290293589,
#   'retweet': True,
#   'original_tweet': 1253928965812547587,
#   '_id': ObjectId('6445e393bad0a54fc4049db7')},
#  1254023158962610176: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023158962610176',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1242819506294013952,
#   'retweet': True,
#   'original_tweet': 1253901215286452224,
#   '_id': ObjectId('6445e393bad0a54fc4049db8')},
#  1254023160137232385: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023160137232385',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 871736974016749568,
#   'retweet': False,
#   'text': 'When will China really be held accountable for causing this corona-pandemic and its lax handling thereof? Let us not forget where this all started',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049db9')},
#  1254023160216813568: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023160216813568',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1047429276134461440,
#   'retweet': True,
#   'original_tweet': 1254011267871903744,
#   '_id': ObjectId('6445e393bad0a54fc4049dba')},
#  1254023160627974148: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023160627974148',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 3370214007,
#   'retweet': True,
#   'original_tweet': 1254005840459313152,
#   '_id': ObjectId('6445e393bad0a54fc4049dbb')},
#  1254023160686448641: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023160686448641',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1253775080313835521,
#   'retweet': True,
#   'original_tweet': 1253991424577671170,
#   '_id': ObjectId('6445e393bad0a54fc4049dbc')},
#  1254023160837660673: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023160837660673',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 955966935178661889,
#   'retweet': False,
#   'text': 'This is the perfect, common sense piece on a good way to think and move forward in this unsettled environment. A breath of fresh air we all need! Consider it!',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049dbd')},
#  1254023160883748867: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023160883748867',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2548401624,
#   'retweet': False,
#   'text': 'my mom was just diagnosed with corona virus which probably includes me n my brother 🗿',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049dbe')},
#  1254023161202520065: {'created_at': 'Sat Apr 25 12:23:14 +0000 2020',
#   'id_str': '1254023161202520065',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 367192484,
#   'retweet': False,
#   'text': 'Eu quero saber como o Mumuzinho pegou corona vírus, se ele estava dendicasa...  #medo 😔',
#   'hashtags': ['medo'],
#   '_id': ObjectId('6445e393bad0a54fc4049dbf')},
#  1254023161625972736: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023161625972736',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1225447573806145536,
#   'retweet': False,
#   'text': '@CNNSotu @jaketapper Why? Just to listen to BS from Dr. Birx trying hard to justify her boss’ sssstupid suggestions of Miracle Cure for corona virus is it? What a waste of time and money!!!!',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049dc0')},
#  1254023161827463168: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023161827463168',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 2710408399,
#   'retweet': False,
#   'text': 'Das darf durchaus gelesen werden:\nManches Corona-Gejammer ist schwer auszuhalten https://t.co/jqd1lV0n48',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049dc1')},
#  1254023161861017600: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023161861017600',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 3240197969,
#   'retweet': True,
#   'original_tweet': 1254021755829616641,
#   '_id': ObjectId('6445e393bad0a54fc4049dc2')},
#  1254023162410471424: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023162410471424',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 227276321,
#   'retweet': True,
#   'original_tweet': 1253959701835902976,
#   '_id': ObjectId('6445e393bad0a54fc4049dc3')},
#  1254023162754486273: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023162754486273',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 154240448,
#   'retweet': False,
#   'text': 'After 39 days of lockdown, I gained 4KGs !!!!!!!!\nThis is ridiculous !\nAnd with Ramadan I usually gain weight - double the trouble 😭😭\nI HATE THIS CORONA SITUATION',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049dc4')},
#  1254023162859315202: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023162859315202',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 3037436317,
#   'retweet': False,
#   'text': '#شهر_رمضان_المبارك شهر العروض و الخصومات\nhttps://t.co/SZ7j0wdWQQ…\n#برنامج_حسابات #ضريبة_القيمة_المضافة #إقرار #ضرايب #ERP #sap #السعودية #الرياض #جدة #مكة  #المملكةالعربيةالسعودية #الامارات #الكويت #عمان #البحرين #قطر #stayathome  #stayhome #staysafe #corona #online #مداد https://t.co/MZGWvdmlAB',
#   'hashtags': ['corona',
#    'مداد',
#    'ضرايب',
#    'الامارات',
#    'عمان',
#    'قطر',
#    'sap',
#    'stayhome',
#    'الرياض',
#    'staysafe',
#    'ضريبة_القيمة_المضافة',
#    'برنامج_حسابات',
#    'الكويت',
#    'شهر_رمضان_المبارك',
#    'جدة',
#    'ERP',
#    'stayathome',
#    'مكة',
#    'السعودية',
#    'online',
#    'إقرار',
#    'المملكةالعربيةالسعودية',
#    'البحرين'],
#   '_id': ObjectId('6445e393bad0a54fc4049dc5')},
#  1254023163404484608: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023163404484608',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1251322715627302912,
#   'retweet': False,
#   'text': 'Fuck covid19 🖕🏻Erigga done talk am before and i wan talk again fuck you corona virus😂🤣',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049dc6')},
#  1254023163417165824: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023163417165824',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1017118319202177025,
#   'retweet': False,
#   'text': '@W_Knight_5 @SShroud07 He had common sense to call corona a hoax because of console war BS? Damn you xbots are nuclear waste level toxic. 👀 https://t.co/Kn0Rv3B5UV',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049dc7')},
#  1254023164264407040: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023164264407040',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1157606566566100992,
#   'retweet': True,
#   'original_tweet': 1254005998198677505,
#   '_id': ObjectId('6445e393bad0a54fc4049dc8')},
#  1254023164159557634: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023164159557634',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1707755058,
#   'retweet': False,
#   'text': 'Laut Gedacht #170: Linke Randale trotz Corona? https://t.co/11Bo7NojtD',
#   'hashtags': ['170:'],
#   '_id': ObjectId('6445e393bad0a54fc4049dc9')},
#  1254023164692099073: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023164692099073',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 987645579671949313,
#   'retweet': True,
#   'original_tweet': 1254021227057823745,
#   '_id': ObjectId('6445e393bad0a54fc4049dca')},
#  1254023164956495872: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023164956495872',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 851968571022352385,
#   'retweet': False,
#   'text': '@ashokrrai @pinkichaubey भाजपा कोरोना फैलाओ मोर्चा😁😂\n\nhttps://t.co/GSfUED2G8I',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049dcb')},
#  1254023165203939329: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023165203939329',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1591544858,
#   'retweet': True,
#   'original_tweet': 1254005783907446785,
#   '_id': ObjectId('6445e393bad0a54fc4049dcc')},
#  1254023165224812544: {'created_at': 'Sat Apr 25 12:23:15 +0000 2020',
#   'id_str': '1254023165224812544',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 3008700857,
#   'retweet': True,
#   'original_tweet': 1252964430553505793,
#   '_id': ObjectId('6445e393bad0a54fc4049dcd')},
#  1254023166206377984: {'created_at': 'Sat Apr 25 12:23:16 +0000 2020',
#   'id_str': '1254023166206377984',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 891728389182304258,
#   'retweet': True,
#   'original_tweet': 1253986335297359874,
#   '_id': ObjectId('6445e393bad0a54fc4049dce')},
#  1254023166512545792: {'created_at': 'Sat Apr 25 12:23:16 +0000 2020',
#   'id_str': '1254023166512545792',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 892052636719091713,
#   'retweet': False,
#   'text': 'एक दम करवाई होनी चाहिए ये ही सब तो आज भारत में corona महामारी को और भी अधिक बढ़ा दिया है,,',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049dcf')},
#  1254023166684540930: {'created_at': 'Sat Apr 25 12:23:16 +0000 2020',
#   'id_str': '1254023166684540930',
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'user': 1230713748999983105,
#   'retweet': False,
#   'text': 'https://t.co/TUEg4yJavV',
#   'hashtags': [],
#   '_id': ObjectId('6445e393bad0a54fc4049dd0')},
#  ...}

# %%
#Upload the TDM json onto the server

client = MongoClient("mongodb://localhost:27017/")

# Create a new database
db = client["TwitterDB"]

# Create a new collection
collection = db["TDM"]

# Load the data from the JSON file
with open('/Users/mazinrafi/Downloads/overall_tdm.json') as f:
     = json.load(f)

# Insert the data into the collection
collection.insert_one(data)

# %%
#Upload the Hashtag json onto the server

client = MongoClient("mongodb://localhost:27017/")

# Create a new database
db = client["TwitterDB"]

# Create a new collection
collection = db["Hashtags"]

# Load the data from the JSON file
with open('/Users/mazinrafi/Downloads/hashtag_tdm.json') as f:
    data = json.load(f)

# Insert the data into the collection
collection.insert_one(data)

# %%
import pymongo
import json
from pymongo import MongoClient
import pandas as pd

# Perform the query to find the top 10 tweets based on favorite_count. Note that this 
client = MongoClient("mongodb://localhost:27017/")
db = client['TwitterDB']
collection = db['tweets']

top_tweets = db.tweets.find().sort("favorite_count", pymongo.DESCENDING).limit(10)

for tweet in top_tweets:
    if 'text' in tweet:
        print("Text:", tweet['text'])
        print("Favorite count:", tweet['favorite_count'])
        print("Retweet count:", tweet['retweet_count'])
# Out:
# Text: im making 17 a hr doing nothing 😭😭😭😭 i love this corona pay
# Favorite count: 0
# Retweet count: 0
# Text: @VinceMcMahon @TripleH We hereby honor to announce that we have developed a brand new treatment method using UV rays / Laser Ray that might be used effectively for preventing all mankind from infectious virus.
#
# #covid #covid19 #Covid_19 #corona #vascular #endovascular https://t.co/YkVlYtJiGL
# Favorite count: 0
# Retweet count: 0
# Text: É isto, ou vou morrer sem ar ou com o corona https://t.co/O0Y7B3Koj4
# Favorite count: 0
# Retweet count: 0
# Text: Schöne Runde mit dem Rennrad ✌️
# #sport #corona https://t.co/Uglj9YJPI1
# Favorite count: 0
# Retweet count: 0
# Text: Was sollen 150 Euro Computerzuschuss bringen? Wer wartet die Computer in den 427 NRW Kommunen (Schulträger) wer die Server vor Ort. Lernen lebt von Face to Face . Sonst könnten wir die Kinder betreut ( keine teure Lehrkraft) vor 1 Computer setzen &amp;zentral aus Düsseldorf beschulen
# Favorite count: 0
# Retweet count: 0

# %%
##Inserting the Users into MySQL 

# !pip install mysql-connector-python
from mysql.connector import (connection)
import json
import mysql.connector
# Out:
# Requirement already satisfied: mysql-connector-python in ./miniconda3/lib/python3.10/site-packages (8.0.32)
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in ./miniconda3/lib/python3.10/site-packages (from mysql-connector-python) (3.20.3)

# %%
#You can download MySQL here: https://dev.mysql.com/downloads/installer/
#Connect to SQL database "localhost" after installing it.
#Note that the user and password must be defined during installation and re-used here.
#the user is "root" and the password is "gXt,:RsU#U-ws:3"
import mysql.connector

try:
    connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3")
    print("Connected to MySQL server.")
except mysql.connector.Error as error:
    print("Failed to connect to MySQL server: {}".format(error))
# Out:
# Connected to MySQL server.

# %%
# create a new database. This database is called "new_database"

connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3")
cursor = connection1.cursor()
cursor.execute("CREATE DATABASE new_database")
print("Database created successfully!")
# Out:
# Database created successfully!

# %%
#create a new table. This one is called users_table

connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3",database="new_database")
cursor = connection1.cursor()
cursor.execute("CREATE TABLE users_table (id bigint PRIMARY KEY,name VARCHAR(255), screen_name VARCHAR(255), followers_count int)")
print("Table created successfully!")
# Out:
# Table created successfully!

# %%
#Insert the users into the Table
connection1 = mysql.connector.connect(
    host="localhost",
    user="root",
    password="gXt,:RsU#U-ws:3",
    database="new_database"
)
cursor = connection1.cursor()

used = set()

for user_id, user_data in users.items():
    sql = "INSERT INTO users_table (id, name, screen_name, followers_count) VALUES (" + str(user_id) + ",'" + user_data['name'].replace("'", "''") + "','" + user_data['screen_name'] + "'," + str(user_data['followers_count']) + ")"
    if user_id not in used:
        used.add(user_id)
    else:
        continue
    cursor.execute(sql)

connection1.commit()

# %%
#Present some of the users as in a dataframe
import pandas as pd

connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3",database="new_database")

cursor = connection1.cursor()

cursor.execute("USE new_database")

cursor.execute("SELECT * FROM users_table LIMIT 5")

result = cursor.fetchall()

df = pd.DataFrame(result, columns=['id', 'name', 'screen_name', 'followers_count'])

df
# Out:
#       id               name screen_name  followers_count
# 0    767     Xeni Jardin 😷🏠        xeni           152608
# 1   5039              Jrome       jrome              642
# 2   5242     Ahmed Al Omran       ahmed           149844
# 3  11364              Kirti        Kits              922
# 4  12094  Nicholai Reinseth    Nicholai              277

# %%
#Prints top 10 users based on followers_count

connection1 = mysql.connector.connect(
    host="localhost",
    user="root",
    password="gXt,:RsU#U-ws:3",
    database="new_database"
)
cursor = connection1.cursor()
cursor.execute("USE new_database")

cursor.execute("SELECT * FROM users_table ORDER BY followers_count DESC LIMIT 10")

result = cursor.fetchall()

df = pd.DataFrame(result, columns=['id', 'name', 'screen_name', 'followers_count'])

df
# Out:
#           id              name      screen_name  followers_count
# 0   69183155          detikcom         detikcom         15927642
# 1   62513246      J.K. Rowling       jk_rowling         14608046
# 2   42606652            AajTak           aajtak          9704885
# 3   39240673          ABP News          ABPNews          9562582
# 4  240649814         TIMES NOW         TimesNow          9499328
# 5   56304605  Rajdeep Sardesai  sardesairajdeep          8947342
# 6   24744541          Le Monde        lemondefr          8808784
# 7   55507370         tvOneNews        tvOneNews          8787649
# 8   23343960        Kompas.com        kompascom          7678178
# 9   15016209               NTV              ntv          7429223

# %%
#print number of users (likely to be incorrect. Need to verify. Number is 80943): 
connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3",database="new_database")

cursor = connection1.cursor()

# select the database
cursor.execute("USE new_database")

# execute the SQL command to count the number of rows in the table
cursor.execute("SELECT COUNT(*) FROM users_table")

# fetch the result
result = cursor.fetchone()

# print the number of users
print("Number of users in the table:", result[0])

# close the cursor and connection
cursor.close()
connection1.close()
# Out:
# Number of users in the table: 80943

# %%
#Directly from file

import json
with open('/Users/mazinrafi/Downloads/corona-out-3.json') as f:
    file_data = json.load(f)

unique_users = set()

for i in file_data:
    unique_users.add(i['user']['id'])

num_unique_users = len(unique_users)
print("Number of unique users:", num_unique_users)
# Out:
# Number of unique users: 80943

# %%
users
# Out:
# {804046791348015107: {'name': 'Bi Sex Uau',
#   'screen_name': 'B_King69',
#   'verified': False,
#   'followers_count': 89,
#   'friends_count': 173,
#   'created_at': 'Wed Nov 30 19:37:48 +0000 2016'},
#  2242948745: {'name': 'Thomas Krause',
#   'screen_name': 'tho1965',
#   'verified': False,
#   'followers_count': 173,
#   'friends_count': 685,
#   'created_at': 'Wed Dec 25 09:13:33 +0000 2013'},
#  908326492718764034: {'name': 'शचीन्द्र पाण्डेय',
#   'screen_name': 'im_S_pandey',
#   'verified': False,
#   'followers_count': 2362,
#   'friends_count': 202,
#   'created_at': 'Thu Sep 14 13:48:06 +0000 2017'},
#  2929344220: {'name': 'Ralf Schmitz',
#   'screen_name': 'RusticusArat',
#   'verified': False,
#   'followers_count': 778,
#   'friends_count': 733,
#   'created_at': 'Thu Dec 18 10:19:26 +0000 2014'},
#  1206650133976408064: {'name': 'Büşra Öztaş',
#   'screen_name': 'schrodingerk42',
#   'verified': False,
#   'followers_count': 318,
#   'friends_count': 220,
#   'created_at': 'Mon Dec 16 18:59:53 +0000 2019'},
#  1248123252: {'name': 'minhyuk.',
#   'screen_name': 'mizhyuklee',
#   'verified': False,
#   'followers_count': 1194,
#   'friends_count': 538,
#   'created_at': 'Thu Mar 07 07:21:32 +0000 2013'},
#  50993809: {'name': '🇮🇹Henry Whites♥️',
#   'screen_name': 'Enrico_Bianchi',
#   'verified': False,
#   'followers_count': 1165,
#   'friends_count': 1840,
#   'created_at': 'Fri Jun 26 09:37:39 +0000 2009'},
#  792325679354417152: {'name': 'Balu Pspk',
#   'screen_name': 'Balu54368353',
#   'verified': False,
#   'followers_count': 221,
#   'friends_count': 311,
#   'created_at': 'Sat Oct 29 11:22:17 +0000 2016'},
#  1091660129894838272: {'name': 'Milli teknoloji',
#   'screen_name': 'milliteknoloj',
#   'verified': False,
#   'followers_count': 2294,
#   'friends_count': 6709,
#   'created_at': 'Sat Feb 02 11:30:31 +0000 2019'},
#  375777294: {'name': 'TeéLaneeë🌺',
#   'screen_name': 'TWD40_',
#   'verified': False,
#   'followers_count': 637,
#   'friends_count': 408,
#   'created_at': 'Sun Sep 18 18:25:43 +0000 2011'},
#  469083492: {'name': 'J.',
#   'screen_name': 'menggyeuxxxxxx',
#   'verified': False,
#   'followers_count': 916,
#   'friends_count': 3981,
#   'created_at': 'Fri Jan 20 06:39:33 +0000 2012'},
#  865733987561381888: {'name': 'ANH',
#   'screen_name': 'BritishKatieKim',
#   'verified': False,
#   'followers_count': 142,
#   'friends_count': 881,
#   'created_at': 'Sat May 20 01:00:42 +0000 2017'},
#  1132273796138905600: {'name': 'Terri Kamp',
#   'screen_name': 'RampTheresa',
#   'verified': False,
#   'followers_count': 1522,
#   'friends_count': 256,
#   'created_at': 'Sat May 25 13:14:44 +0000 2019'},
#  1044295463267119104: {'name': 'Peter Noß-Kolbe',
#   'screen_name': 'nosskolbe',
#   'verified': False,
#   'followers_count': 311,
#   'friends_count': 455,
#   'created_at': 'Mon Sep 24 18:40:15 +0000 2018'},
#  109877154: {'name': 'MrBelzoni',
#   'screen_name': 'MrBelzoni',
#   'verified': False,
#   'followers_count': 339,
#   'friends_count': 657,
#   'created_at': 'Sat Jan 30 15:23:21 +0000 2010'},
#  301470336: {'name': 'BABA ALI',
#   'screen_name': '_FreshAA',
#   'verified': False,
#   'followers_count': 9406,
#   'friends_count': 1870,
#   'created_at': 'Thu May 19 14:38:22 +0000 2011'},
#  1035107587006648320: {'name': 'Satya Hindi',
#   'screen_name': 'SatyaHindi',
#   'verified': False,
#   'followers_count': 11576,
#   'friends_count': 20,
#   'created_at': 'Thu Aug 30 10:10:54 +0000 2018'},
#  923169415054680064: {'name': 'Quantum',
#   'screen_name': 'QuantumAspect',
#   'verified': False,
#   'followers_count': 3196,
#   'friends_count': 1001,
#   'created_at': 'Wed Oct 25 12:48:35 +0000 2017'},
#  2459721182: {'name': 'M‘kh Pirralha Al Frejd #STAYTHEFUCKHOME ♥️🌍🌻',
#   'screen_name': 'Alfred996',
#   'verified': False,
#   'followers_count': 2022,
#   'friends_count': 4436,
#   'created_at': 'Wed Apr 23 13:15:52 +0000 2014'},
#  2493849410: {'name': 'iwan phitoy',
#   'screen_name': 'nirwansyah122',
#   'verified': False,
#   'followers_count': 239,
#   'friends_count': 579,
#   'created_at': 'Wed May 14 07:59:06 +0000 2014'},
#  21400571: {'name': 'Siegfried Kraemer',
#   'screen_name': 'S_Kraemer',
#   'verified': False,
#   'followers_count': 327,
#   'friends_count': 1397,
#   'created_at': 'Fri Feb 20 14:34:39 +0000 2009'},
#  1220425350540382209: {'name': 'Sad World',
#   'screen_name': 'HumansAreRotten',
#   'verified': False,
#   'followers_count': 14,
#   'friends_count': 89,
#   'created_at': 'Thu Jan 23 19:19:21 +0000 2020'},
#  1120761000561606656: {'name': '🌸',
#   'screen_name': 'cloudseokjinie',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 17,
#   'created_at': 'Tue Apr 23 18:47:00 +0000 2019'},
#  1228183815576682497: {'name': 'HASHTAG UNKNOWN',
#   'screen_name': '890Unknown',
#   'verified': False,
#   'followers_count': 52,
#   'friends_count': 679,
#   'created_at': 'Fri Feb 14 05:07:07 +0000 2020'},
#  2870459221: {'name': 'VICK',
#   'screen_name': 'Vikteneus',
#   'verified': False,
#   'followers_count': 3004,
#   'friends_count': 226,
#   'created_at': 'Wed Oct 22 07:45:48 +0000 2014'},
#  847489262018641921: {'name': 'Dr. Yousuf Majeed',
#   'screen_name': 'dr_yousufmajeed',
#   'verified': False,
#   'followers_count': 25,
#   'friends_count': 45,
#   'created_at': 'Thu Mar 30 16:42:40 +0000 2017'},
#  94687002: {'name': 'denckste',
#   'screen_name': 'denckste',
#   'verified': False,
#   'followers_count': 230,
#   'friends_count': 191,
#   'created_at': 'Sat Dec 05 00:54:15 +0000 2009'},
#  567891167: {'name': 'St.polat',
#   'screen_name': 'StPolat',
#   'verified': False,
#   'followers_count': 12,
#   'friends_count': 273,
#   'created_at': 'Tue May 01 05:36:13 +0000 2012'},
#  1080798295: {'name': 'Edwin',
#   'screen_name': 'pardamean26',
#   'verified': False,
#   'followers_count': 107,
#   'friends_count': 328,
#   'created_at': 'Fri Jan 11 20:04:38 +0000 2013'},
#  1151073083836502016: {'name': 'Asian Narratives',
#   'screen_name': 'AsianNarratives',
#   'verified': False,
#   'followers_count': 13,
#   'friends_count': 65,
#   'created_at': 'Tue Jul 16 10:16:23 +0000 2019'},
#  1215289012551741443: {'name': 'TopInfo',
#   'screen_name': 'topinfo_id',
#   'verified': False,
#   'followers_count': 169,
#   'friends_count': 183,
#   'created_at': 'Thu Jan 09 15:07:42 +0000 2020'},
#  1213865493951438849: {'name': 'Jonnieka Farr',
#   'screen_name': 'Farrfor9',
#   'verified': False,
#   'followers_count': 21,
#   'friends_count': 38,
#   'created_at': 'Sun Jan 05 16:51:43 +0000 2020'},
#  852883926: {'name': 'Joseph Andrew',
#   'screen_name': 'sam195027',
#   'verified': False,
#   'followers_count': 6,
#   'friends_count': 97,
#   'created_at': 'Sat Sep 29 13:35:54 +0000 2012'},
#  776181606004424706: {'name': 'Kwaku ⚡️',
#   'screen_name': 'kwaku_a_b',
#   'verified': False,
#   'followers_count': 373,
#   'friends_count': 336,
#   'created_at': 'Wed Sep 14 22:11:30 +0000 2016'},
#  834386400665595904: {'name': 'Güneşten Ozantürk',
#   'screen_name': 'GOzanturk',
#   'verified': False,
#   'followers_count': 21,
#   'friends_count': 33,
#   'created_at': 'Wed Feb 22 12:56:34 +0000 2017'},
#  1184860086008762369: {'name': 'Rocco_Ricko💪😋',
#   'screen_name': 'ricko_rocco',
#   'verified': False,
#   'followers_count': 32,
#   'friends_count': 156,
#   'created_at': 'Thu Oct 17 15:54:10 +0000 2019'},
#  240950393: {'name': 'Δ',
#   'screen_name': 'icanbgstbgt',
#   'verified': False,
#   'followers_count': 12701,
#   'friends_count': 1070,
#   'created_at': 'Fri Jan 21 03:13:15 +0000 2011'},
#  1178130261302636545: {'name': 'अजित गजानन हळदणकर',
#   'screen_name': 'HaldankarRavi',
#   'verified': False,
#   'followers_count': 45,
#   'friends_count': 222,
#   'created_at': 'Sun Sep 29 02:12:26 +0000 2019'},
#  814316767665418248: {'name': 'gloria thompson',
#   'screen_name': 'globug_resists',
#   'verified': False,
#   'followers_count': 1247,
#   'friends_count': 1382,
#   'created_at': 'Thu Dec 29 03:47:01 +0000 2016'},
#  2930195686: {'name': 'Malte bleibt da Heimbächer 🇪🇺',
#   'screen_name': 'MHeimbaecher',
#   'verified': False,
#   'followers_count': 339,
#   'friends_count': 545,
#   'created_at': 'Thu Dec 18 17:57:07 +0000 2014'},
#  1103945573353377792: {'name': 'I WE AND YOU',
#   'screen_name': 'IWEANDYOU1',
#   'verified': False,
#   'followers_count': 23,
#   'friends_count': 117,
#   'created_at': 'Fri Mar 08 09:08:29 +0000 2019'},
#  620106850: {'name': 'You’re a Daisy If You Do',
#   'screen_name': 'LibertyLoud',
#   'verified': False,
#   'followers_count': 911,
#   'friends_count': 1167,
#   'created_at': 'Wed Jun 27 15:43:35 +0000 2012'},
#  937608589450940416: {'name': 'Poovarasu Navi',
#   'screen_name': 'Poovarasu761473',
#   'verified': False,
#   'followers_count': 106,
#   'friends_count': 1339,
#   'created_at': 'Mon Dec 04 09:04:42 +0000 2017'},
#  54516468: {'name': 'Temmydeeds🇳🇬🇬🇧',
#   'screen_name': 'TemmyDeeds',
#   'verified': False,
#   'followers_count': 6582,
#   'friends_count': 7189,
#   'created_at': 'Tue Jul 07 11:17:22 +0000 2009'},
#  479687857: {'name': 'Mike Lorenz',
#   'screen_name': 'rancorousvolfan',
#   'verified': False,
#   'followers_count': 155,
#   'friends_count': 406,
#   'created_at': 'Tue Jan 31 17:15:29 +0000 2012'},
#  4854018732: {'name': 'Kalyan Upadhyay 🇮🇳',
#   'screen_name': 'UpadhyayKalyan',
#   'verified': False,
#   'followers_count': 112,
#   'friends_count': 172,
#   'created_at': 'Wed Feb 03 12:49:26 +0000 2016'},
#  1027725065302028288: {'name': 'Tigrrrrrrrrrr - Q',
#   'screen_name': 'Eduardo60817885',
#   'verified': False,
#   'followers_count': 47,
#   'friends_count': 208,
#   'created_at': 'Fri Aug 10 01:15:24 +0000 2018'},
#  282033511: {'name': 'Robert Oostinga',
#   'screen_name': 'robertoostinga',
#   'verified': False,
#   'followers_count': 78,
#   'friends_count': 591,
#   'created_at': 'Thu Apr 14 12:37:12 +0000 2011'},
#  2347091406: {'name': 'SplendorSolis 🇮🇹',
#   'screen_name': 'SplendorSolis00',
#   'verified': False,
#   'followers_count': 1558,
#   'friends_count': 553,
#   'created_at': 'Sun Feb 16 16:21:05 +0000 2014'},
#  1108988856404082688: {'name': 'Rajesh Sharma',
#   'screen_name': 'RajeshS54612482',
#   'verified': False,
#   'followers_count': 148,
#   'friends_count': 244,
#   'created_at': 'Fri Mar 22 07:08:42 +0000 2019'},
#  18388923: {'name': 'Area Man',
#   'screen_name': 'lheal',
#   'verified': False,
#   'followers_count': 12541,
#   'friends_count': 3086,
#   'created_at': 'Fri Dec 26 13:35:12 +0000 2008'},
#  593525060: {'name': 'Manuel B.',
#   'screen_name': 'talentfrei92',
#   'verified': False,
#   'followers_count': 883,
#   'friends_count': 731,
#   'created_at': 'Tue May 29 08:57:35 +0000 2012'},
#  1209389404080336896: {'name': 'jaka swara',
#   'screen_name': 'jakaswa65626492',
#   'verified': False,
#   'followers_count': 712,
#   'friends_count': 2000,
#   'created_at': 'Tue Dec 24 08:24:56 +0000 2019'},
#  928245694648819712: {'name': 'vishwadeep Singh',
#   'screen_name': 'vishwadeep3034',
#   'verified': False,
#   'followers_count': 542,
#   'friends_count': 168,
#   'created_at': 'Wed Nov 08 12:59:54 +0000 2017'},
#  1162422360122777601: {'name': 'Saudi 24 News',
#   'screen_name': 'Saudi24N',
#   'verified': False,
#   'followers_count': 773,
#   'friends_count': 2,
#   'created_at': 'Fri Aug 16 17:54:32 +0000 2019'},
#  1093103671523577856: {'name': 'Dhaneswar Yadav',
#   'screen_name': 'DhaneswarYadav1',
#   'verified': False,
#   'followers_count': 33,
#   'friends_count': 168,
#   'created_at': 'Wed Feb 06 11:06:38 +0000 2019'},
#  1333490040: {'name': 'Livability Asia',
#   'screen_name': 'walkabilityasia',
#   'verified': False,
#   'followers_count': 1149,
#   'friends_count': 588,
#   'created_at': 'Sun Apr 07 08:14:39 +0000 2013'},
#  224195336: {'name': 'Eddy Hunger',
#   'screen_name': 'eddy8899ag',
#   'verified': False,
#   'followers_count': 1172,
#   'friends_count': 1448,
#   'created_at': 'Wed Dec 08 11:36:31 +0000 2010'},
#  303113303: {'name': 'Elke Billstein/Autorin',
#   'screen_name': 'ElkeBillstein',
#   'verified': False,
#   'followers_count': 156,
#   'friends_count': 406,
#   'created_at': 'Sun May 22 09:48:14 +0000 2011'},
#  1883364229: {'name': '🌸DieUnfassbare🌺🦄',
#   'screen_name': 'tekilasanreis',
#   'verified': False,
#   'followers_count': 764,
#   'friends_count': 533,
#   'created_at': 'Thu Sep 19 14:29:43 +0000 2013'},
#  161194531: {'name': 'Fatman',
#   'screen_name': 'DeddyHasan_',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 25,
#   'created_at': 'Wed Jun 30 06:30:49 +0000 2010'},
#  761553667: {'name': 'Calvin Tuten',
#   'screen_name': 'DaddleSki',
#   'verified': False,
#   'followers_count': 757,
#   'friends_count': 809,
#   'created_at': 'Thu Aug 16 13:26:08 +0000 2012'},
#  1246109039483707392: {'name': 'Ranveer Sharma',
#   'screen_name': 'RanveerLawyer',
#   'verified': False,
#   'followers_count': 3,
#   'friends_count': 31,
#   'created_at': 'Fri Apr 03 16:15:35 +0000 2020'},
#  22707454: {'name': 'Dawn Johnson 🇳🇴🇺🇸🇬🇧🇩🇰',
#   'screen_name': 'sundene',
#   'verified': False,
#   'followers_count': 5788,
#   'friends_count': 6221,
#   'created_at': 'Wed Mar 04 00:37:26 +0000 2009'},
#  2246077632: {'name': 'Chantelle Fabian',
#   'screen_name': 'tellfabian',
#   'verified': False,
#   'followers_count': 205,
#   'friends_count': 958,
#   'created_at': 'Sat Dec 14 20:00:05 +0000 2013'},
#  127463744: {'name': 'Pradeep Singh Negi',
#   'screen_name': 'pradeepsinghneg',
#   'verified': False,
#   'followers_count': 992,
#   'friends_count': 259,
#   'created_at': 'Mon Mar 29 08:26:54 +0000 2010'},
#  848401934386028544: {'name': '~ K.N.S ~',
#   'screen_name': 'Karunanidhan27',
#   'verified': False,
#   'followers_count': 574,
#   'friends_count': 227,
#   'created_at': 'Sun Apr 02 05:09:18 +0000 2017'},
#  1353476622: {'name': 'ardian.',
#   'screen_name': 'ardi_ann',
#   'verified': False,
#   'followers_count': 399,
#   'friends_count': 1647,
#   'created_at': 'Mon Apr 15 04:56:38 +0000 2013'},
#  1857739392: {'name': 'subramanya bhat',
#   'screen_name': 'subramanyaBB36',
#   'verified': False,
#   'followers_count': 4,
#   'friends_count': 10,
#   'created_at': 'Thu Sep 12 15:55:00 +0000 2013'},
#  2820001086: {'name': 'Chandni',
#   'screen_name': 'ImPancake_',
#   'verified': False,
#   'followers_count': 34,
#   'friends_count': 39,
#   'created_at': 'Fri Sep 19 14:11:08 +0000 2014'},
#  1179351763192664064: {'name': 'Nika🧃',
#   'screen_name': 'Baby_Nikkk',
#   'verified': False,
#   'followers_count': 93,
#   'friends_count': 72,
#   'created_at': 'Wed Oct 02 11:06:37 +0000 2019'},
#  2186147385: {'name': 'Chesco Gwivaha',
#   'screen_name': 'chescogwivaha',
#   'verified': False,
#   'followers_count': 14,
#   'friends_count': 65,
#   'created_at': 'Mon Nov 18 16:13:08 +0000 2013'},
#  968998885: {'name': 'G Weezy 🇨🇦🤘',
#   'screen_name': 'Islands49th',
#   'verified': False,
#   'followers_count': 365,
#   'friends_count': 533,
#   'created_at': 'Sat Nov 24 23:28:18 +0000 2012'},
#  1173211287339192320: {'name': 'Mas-mas bucinnya Salshabilla Adriani!',
#   'screen_name': 'dailyofbucin',
#   'verified': False,
#   'followers_count': 159,
#   'friends_count': 69,
#   'created_at': 'Sun Sep 15 12:25:59 +0000 2019'},
#  1245599601807114245: {'name': 'coronacrazy',
#   'screen_name': 'Kirb00339581',
#   'verified': False,
#   'followers_count': 1,
#   'friends_count': 9,
#   'created_at': 'Thu Apr 02 06:31:14 +0000 2020'},
#  866129731: {'name': 'Prof. Roti Gulung',
#   'screen_name': 'profrotigulung',
#   'verified': False,
#   'followers_count': 4497,
#   'friends_count': 3150,
#   'created_at': 'Sun Oct 07 10:38:48 +0000 2012'},
#  538000592: {'name': 'Aziz مندڼ',
#   'screen_name': 'Azizmandanr',
#   'verified': False,
#   'followers_count': 35,
#   'friends_count': 2166,
#   'created_at': 'Wed Oct 28 12:37:22 +0000 2015'},
#  104393674: {'name': 'DeplorableBadHombre',
#   'screen_name': 'Soulm81',
#   'verified': False,
#   'followers_count': 12904,
#   'friends_count': 12931,
#   'created_at': 'Wed Jan 13 05:41:38 +0000 2010'},
#  22605953: {'name': '\uf8ff Jan Smit Ede',
#   'screen_name': 'jansmitede',
#   'verified': False,
#   'followers_count': 1525,
#   'friends_count': 4324,
#   'created_at': 'Tue Mar 03 09:41:14 +0000 2009'},
#  1144699678086139904: {'name': 'akkians (kk) gujrat',
#   'screen_name': 'Khushalkotak1',
#   'verified': False,
#   'followers_count': 57,
#   'friends_count': 178,
#   'created_at': 'Fri Jun 28 20:10:45 +0000 2019'},
#  1074021304179875847: {'name': 'FIBRO BOXER💪🏻🥊',
#   'screen_name': 'fibromyalgiaAmy',
#   'verified': False,
#   'followers_count': 6359,
#   'friends_count': 6302,
#   'created_at': 'Sat Dec 15 19:20:08 +0000 2018'},
#  1247639399845814277: {'name': 'Correa dentada',
#   'screen_name': 'cthaistressada',
#   'verified': False,
#   'followers_count': 23,
#   'friends_count': 42,
#   'created_at': 'Tue Apr 07 21:36:41 +0000 2020'},
#  730576596: {'name': 'Sivapriyan E.T.B',
#   'screen_name': 'sivaetb',
#   'verified': True,
#   'followers_count': 4337,
#   'friends_count': 324,
#   'created_at': 'Wed Aug 01 12:16:51 +0000 2012'},
#  1418690310: {'name': 'Andie_10',
#   'screen_name': 'sutandidj',
#   'verified': False,
#   'followers_count': 1012,
#   'friends_count': 953,
#   'created_at': 'Fri May 10 17:55:52 +0000 2013'},
#  917502565490790400: {'name': 'PJ',
#   'screen_name': 'Politicals122',
#   'verified': False,
#   'followers_count': 593,
#   'friends_count': 3420,
#   'created_at': 'Mon Oct 09 21:30:32 +0000 2017'},
#  1239204446019760128: {'name': 'thomas ruoff',
#   'screen_name': 'RuoffThomas',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 5,
#   'created_at': 'Sun Mar 15 14:59:12 +0000 2020'},
#  746734977232998400: {'name': 'Moya Salsabila',
#   'screen_name': 'moyaslsbl',
#   'verified': False,
#   'followers_count': 2045,
#   'friends_count': 1683,
#   'created_at': 'Sat Jun 25 16:01:07 +0000 2016'},
#  797829077596012545: {'name': 'Hello Wilmslow',
#   'screen_name': 'HelloWilmslow',
#   'verified': False,
#   'followers_count': 2380,
#   'friends_count': 2532,
#   'created_at': 'Sun Nov 13 15:50:49 +0000 2016'},
#  785288949879242753: {'name': 'yvonne',
#   'screen_name': 'yvonne_erdmann',
#   'verified': False,
#   'followers_count': 5833,
#   'friends_count': 6385,
#   'created_at': 'Mon Oct 10 01:20:50 +0000 2016'},
#  999598748228501505: {'name': 'हिंदु मुकेश',
#   'screen_name': 'U6DDQWhOXbDQsHm',
#   'verified': False,
#   'followers_count': 1275,
#   'friends_count': 4387,
#   'created_at': 'Thu May 24 10:31:28 +0000 2018'},
#  913433214164729856: {'name': 'Aravind',
#   'screen_name': 'aravindrapelli6',
#   'verified': False,
#   'followers_count': 2,
#   'friends_count': 22,
#   'created_at': 'Thu Sep 28 16:00:23 +0000 2017'},
#  1392274176: {'name': 'Stefano💥Cavanna',
#   'screen_name': 'stefano_6000',
#   'verified': False,
#   'followers_count': 1228,
#   'friends_count': 2719,
#   'created_at': 'Tue Apr 30 15:10:47 +0000 2013'},
#  887662219: {'name': 'Rozi lisergica 🇪🇺',
#   'screen_name': 'patyubesu',
#   'verified': False,
#   'followers_count': 1395,
#   'friends_count': 2655,
#   'created_at': 'Wed Oct 17 22:21:27 +0000 2012'},
#  751929355: {'name': 'Durai💙',
#   'screen_name': 'Durai_offcl',
#   'verified': False,
#   'followers_count': 515,
#   'friends_count': 469,
#   'created_at': 'Sat Aug 11 21:23:58 +0000 2012'},
#  1065441285798998016: {'name': 'राजा सिंह चंदेल',
#   'screen_name': 'RajaSinghChand9',
#   'verified': False,
#   'followers_count': 115,
#   'friends_count': 627,
#   'created_at': 'Thu Nov 22 03:06:12 +0000 2018'},
#  2545415011: {'name': 'amna khan',
#   'screen_name': 'amnafzal2',
#   'verified': False,
#   'followers_count': 372,
#   'friends_count': 92,
#   'created_at': 'Wed Jun 04 06:39:08 +0000 2014'},
#  971227567595376642: {'name': 'Jaysharma',
#   'screen_name': 'jaysharmabjp',
#   'verified': False,
#   'followers_count': 1830,
#   'friends_count': 2419,
#   'created_at': 'Wed Mar 07 03:34:31 +0000 2018'},
#  1180839562635087872: {'name': 'LoveBeautyZ',
#   'screen_name': 'LoveBeautyZ1',
#   'verified': False,
#   'followers_count': 253,
#   'friends_count': 1494,
#   'created_at': 'Sun Oct 06 13:38:07 +0000 2019'},
#  140831067: {'name': 'Rabella Wiersma - de Faria 🚜',
#   'screen_name': 'Rabellamaria',
#   'verified': False,
#   'followers_count': 1437,
#   'friends_count': 2570,
#   'created_at': 'Thu May 06 13:35:34 +0000 2010'},
#  1044480521386975234: {'name': 'Kumar Sen',
#   'screen_name': 'KumarSe72338987',
#   'verified': False,
#   'followers_count': 118,
#   'friends_count': 780,
#   'created_at': 'Tue Sep 25 06:55:36 +0000 2018'},
#  1070251994428948481: {'name': 'Jalala University KABUDI effect',
#   'screen_name': 'MakuruRobert',
#   'verified': False,
#   'followers_count': 9109,
#   'friends_count': 167,
#   'created_at': 'Wed Dec 05 09:42:14 +0000 2018'},
#  821435447943528448: {'name': 'Susan Billett',
#   'screen_name': 'BillettSusan',
#   'verified': False,
#   'followers_count': 133,
#   'friends_count': 213,
#   'created_at': 'Tue Jan 17 19:14:07 +0000 2017'},
#  1125741605342908416: {'name': 'owencocoefc',
#   'screen_name': 'owencocoefc',
#   'verified': False,
#   'followers_count': 1822,
#   'friends_count': 3748,
#   'created_at': 'Tue May 07 12:38:08 +0000 2019'},
#  920075544548597761: {'name': 'Hoovy',
#   'screen_name': 'suddysoapbar',
#   'verified': False,
#   'followers_count': 469,
#   'friends_count': 759,
#   'created_at': 'Mon Oct 16 23:54:38 +0000 2017'},
#  2666107580: {'name': 'Luana Lavecchia',
#   'screen_name': 'LuanaLavecchia',
#   'verified': False,
#   'followers_count': 416,
#   'friends_count': 1096,
#   'created_at': 'Mon Jul 21 15:02:44 +0000 2014'},
#  18236335: {'name': 'Anand Chakrapani',
#   'screen_name': 'anandchakrapani',
#   'verified': False,
#   'followers_count': 165,
#   'friends_count': 383,
#   'created_at': 'Fri Dec 19 06:04:06 +0000 2008'},
#  1068560551297642497: {'name': 'Meister Becker',
#   'screen_name': 'becker_meister',
#   'verified': False,
#   'followers_count': 343,
#   'friends_count': 670,
#   'created_at': 'Fri Nov 30 17:41:03 +0000 2018'},
#  1171940166447116288: {'name': '𝖒𝖎𝖘𝖆𝖐𝖎⛓',
#   'screen_name': 'jisungeyess',
#   'verified': False,
#   'followers_count': 2631,
#   'friends_count': 2655,
#   'created_at': 'Thu Sep 12 00:14:58 +0000 2019'},
#  2579234981: {'name': 'Dabrinah',
#   'screen_name': 'DianahAggrey',
#   'verified': False,
#   'followers_count': 2465,
#   'friends_count': 561,
#   'created_at': 'Tue Jun 03 02:59:29 +0000 2014'},
#  488135808: {'name': 'Soumya Das',
#   'screen_name': 'Soumya101011',
#   'verified': False,
#   'followers_count': 263,
#   'friends_count': 767,
#   'created_at': 'Fri Feb 10 03:48:28 +0000 2012'},
#  242422673: {'name': 'Siri Isaksson',
#   'screen_name': 'dorotheafrenkel',
#   'verified': False,
#   'followers_count': 1702,
#   'friends_count': 3163,
#   'created_at': 'Mon Jan 24 19:09:15 +0000 2011'},
#  1244250628764971008: {'name': 'Marcela Matimbe',
#   'screen_name': 'marcela_matimbe',
#   'verified': False,
#   'followers_count': 8,
#   'friends_count': 47,
#   'created_at': 'Sun Mar 29 13:10:57 +0000 2020'},
#  771379560629665792: {'name': 'South African Traveller',
#   'screen_name': 'African_Odyzzee',
#   'verified': False,
#   'followers_count': 14903,
#   'friends_count': 13870,
#   'created_at': 'Thu Sep 01 16:09:53 +0000 2016'},
#  1246765161433595904: {'name': 'Damn.....WeLoveNKRI',
#   'screen_name': 'DwiWarna10',
#   'verified': False,
#   'followers_count': 1228,
#   'friends_count': 1419,
#   'created_at': 'Sun Apr 05 11:42:43 +0000 2020'},
#  1061479345384972288: {'name': 'Bagas',
#   'screen_name': 'Bagas36406270',
#   'verified': False,
#   'followers_count': 1317,
#   'friends_count': 1852,
#   'created_at': 'Sun Nov 11 04:42:52 +0000 2018'},
#  283365151: {'name': 'Vignesh',
#   'screen_name': 'AustinVignesh',
#   'verified': False,
#   'followers_count': 12,
#   'friends_count': 9,
#   'created_at': 'Sun Apr 17 04:30:40 +0000 2011'},
#  966984463598186496: {'name': 'egeli',
#   'screen_name': 'IcdagMetin',
#   'verified': False,
#   'followers_count': 44,
#   'friends_count': 239,
#   'created_at': 'Fri Feb 23 10:33:56 +0000 2018'},
#  758670622654337025: {'name': 'Martina Kiehnle',
#   'screen_name': 'Tinimaus1110',
#   'verified': False,
#   'followers_count': 3188,
#   'friends_count': 4597,
#   'created_at': 'Thu Jul 28 14:29:06 +0000 2016'},
#  83474160: {'name': 'Johannes Steiniger',
#   'screen_name': 'JoSteiniger',
#   'verified': True,
#   'followers_count': 3524,
#   'friends_count': 1266,
#   'created_at': 'Sun Oct 18 23:38:01 +0000 2009'},
#  101756062: {'name': 'RTtheBEST',
#   'screen_name': 'RTtheBEST',
#   'verified': False,
#   'followers_count': 418294,
#   'friends_count': 407418,
#   'created_at': 'Mon Jan 04 13:20:47 +0000 2010'},
#  818242179084627970: {'name': 'Bobi Darmawan',
#   'screen_name': 'bobidrmwn',
#   'verified': False,
#   'followers_count': 10,
#   'friends_count': 39,
#   'created_at': 'Sun Jan 08 23:45:12 +0000 2017'},
#  935546446971133952: {'name': 'Nima Mafi-Gudarzi',
#   'screen_name': 'MafiGudarzi',
#   'verified': False,
#   'followers_count': 240,
#   'friends_count': 399,
#   'created_at': 'Tue Nov 28 16:30:29 +0000 2017'},
#  821085631950557186: {'name': 'Newton Ochieng',
#   'screen_name': 'Kamblossi',
#   'verified': False,
#   'followers_count': 55,
#   'friends_count': 228,
#   'created_at': 'Mon Jan 16 20:04:04 +0000 2017'},
#  627712209: {'name': 'Ragnar Danneskjöld',
#   'screen_name': 'axiom_8',
#   'verified': False,
#   'followers_count': 8215,
#   'friends_count': 8312,
#   'created_at': 'Thu Jul 05 18:52:04 +0000 2012'},
#  1533727471: {'name': 'Revanth Kumar',
#   'screen_name': 'revanth72026457',
#   'verified': False,
#   'followers_count': 14,
#   'friends_count': 24,
#   'created_at': 'Thu Jun 20 11:47:25 +0000 2013'},
#  850740477360058368: {'name': 'Antonio Orciuoli',
#   'screen_name': 'ajkconte',
#   'verified': False,
#   'followers_count': 165,
#   'friends_count': 149,
#   'created_at': 'Sat Apr 08 16:01:50 +0000 2017'},
#  2920179838: {'name': 'Kirsten Engholt',
#   'screen_name': 'kirsten_engholt',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 16,
#   'created_at': 'Sat Dec 13 19:15:51 +0000 2014'},
#  862401439041110016: {'name': 'Rico (BAX)',
#   'screen_name': 'YoungTrader85',
#   'verified': False,
#   'followers_count': 26,
#   'friends_count': 123,
#   'created_at': 'Wed May 10 20:18:20 +0000 2017'},
#  224572743: {'name': 'Bas Belder',
#   'screen_name': 'BasBelderMEP',
#   'verified': True,
#   'followers_count': 4715,
#   'friends_count': 403,
#   'created_at': 'Thu Dec 09 10:00:45 +0000 2010'},
#  205793718: {'name': 'Rakeshwar Pokhriyal',
#   'screen_name': 'hillsay',
#   'verified': False,
#   'followers_count': 213,
#   'friends_count': 208,
#   'created_at': 'Thu Oct 21 16:26:33 +0000 2010'},
#  889119868074823680: {'name': 'Mathieu RWIYEREKA',
#   'screen_name': 'RealMathieuRW',
#   'verified': False,
#   'followers_count': 112,
#   'friends_count': 256,
#   'created_at': 'Sun Jul 23 13:47:50 +0000 2017'},
#  3848973554: {'name': 'アティカ アプリア二',
#   'screen_name': 'atikaapriani20',
#   'verified': False,
#   'followers_count': 1,
#   'friends_count': 9,
#   'created_at': 'Sat Oct 10 15:57:46 +0000 2015'},
#  1244371727515336705: {'name': 'cyber cossack',
#   'screen_name': 'CossackCyber',
#   'verified': False,
#   'followers_count': 49,
#   'friends_count': 203,
#   'created_at': 'Sun Mar 29 21:12:03 +0000 2020'},
#  86841762: {'name': 'Ei pow',
#   'screen_name': 'ThalesMeelo',
#   'verified': False,
#   'followers_count': 542,
#   'friends_count': 268,
#   'created_at': 'Mon Nov 02 01:05:34 +0000 2009'},
#  284926179: {'name': 'piapee',
#   'screen_name': 'itspiaromualdo',
#   'verified': False,
#   'followers_count': 1439,
#   'friends_count': 1435,
#   'created_at': 'Wed Apr 20 06:33:27 +0000 2011'},
#  1193153858312249345: {'name': 'Vikas',
#   'screen_name': 'Vikas787787',
#   'verified': False,
#   'followers_count': 401,
#   'friends_count': 718,
#   'created_at': 'Sat Nov 09 13:10:37 +0000 2019'},
#  262252987: {'name': '😈',
#   'screen_name': 'inotfromearth',
#   'verified': False,
#   'followers_count': 1255,
#   'friends_count': 385,
#   'created_at': 'Mon Mar 07 17:49:59 +0000 2011'},
#  3347588774: {'name': 'UttarPradesh.ORG News',
#   'screen_name': 'WeUttarPradesh',
#   'verified': True,
#   'followers_count': 78749,
#   'friends_count': 0,
#   'created_at': 'Wed Aug 26 10:51:40 +0000 2015'},
#  3081185375: {'name': 'Adv Layak Shaikh',
#   'screen_name': 'slayakali93',
#   'verified': False,
#   'followers_count': 8,
#   'friends_count': 92,
#   'created_at': 'Mon Mar 09 08:34:34 +0000 2015'},
#  959375808: {'name': '™ ꦄꦢꦶꦡꦾꦨꦶꦩ ₂₁♔ 🇮🇩',
#   'screen_name': '21_bima_21',
#   'verified': False,
#   'followers_count': 4979,
#   'friends_count': 4940,
#   'created_at': 'Tue Nov 20 02:49:53 +0000 2012'},
#  2199357115: {'name': 'prof. Mohd Anisur Rahman Forazy',
#   'screen_name': 'forazyanis',
#   'verified': False,
#   'followers_count': 8,
#   'friends_count': 32,
#   'created_at': 'Sun Nov 17 11:19:32 +0000 2013'},
#  1241625899532836866: {'name': 'inder minhas',
#   'screen_name': 'inderminhas7',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 5,
#   'created_at': 'Sun Mar 22 07:21:07 +0000 2020'},
#  514748780: {'name': "Graeme (Don't touch your face) Leggett",
#   'screen_name': 'GrumFromNorwich',
#   'verified': False,
#   'followers_count': 447,
#   'friends_count': 294,
#   'created_at': 'Sun Mar 04 20:45:37 +0000 2012'},
#  16997143: {'name': 'alefalletti',
#   'screen_name': 'alefalletti',
#   'verified': False,
#   'followers_count': 738,
#   'friends_count': 3184,
#   'created_at': 'Mon Oct 27 12:24:58 +0000 2008'},
#  1010600056582492160: {'name': 'Break in the wall.',
#   'screen_name': 'paceinguerra',
#   'verified': False,
#   'followers_count': 233,
#   'friends_count': 165,
#   'created_at': 'Sat Jun 23 19:06:44 +0000 2018'},
#  563703947: {'name': 'Larry Fisherman',
#   'screen_name': 'EmmaWekesa1',
#   'verified': False,
#   'followers_count': 622,
#   'friends_count': 606,
#   'created_at': 'Thu Apr 26 12:59:47 +0000 2012'},
#  930706310861152256: {'name': 'Dr Ankit Raj',
#   'screen_name': 'AnkitRaj6091568',
#   'verified': False,
#   'followers_count': 105,
#   'friends_count': 94,
#   'created_at': 'Wed Nov 15 07:57:31 +0000 2017'},
#  140752137: {'name': '🇮🇳 Hemant Tulpule🇮🇳 🚩🚩🚩',
#   'screen_name': 't_hemant',
#   'verified': False,
#   'followers_count': 828,
#   'friends_count': 930,
#   'created_at': 'Thu May 06 08:51:45 +0000 2010'},
#  592628773: {'name': 'Julian Mockert',
#   'screen_name': 'jmockert',
#   'verified': False,
#   'followers_count': 54,
#   'friends_count': 532,
#   'created_at': 'Mon May 28 11:02:56 +0000 2012'},
#  336718281: {'name': 'Caitlin',
#   'screen_name': '_caitlinmillss',
#   'verified': False,
#   'followers_count': 1316,
#   'friends_count': 604,
#   'created_at': 'Sat Jul 16 19:50:39 +0000 2011'},
#  1632716983: {'name': 'manu1972',
#   'screen_name': 'freyre91',
#   'verified': False,
#   'followers_count': 232,
#   'friends_count': 537,
#   'created_at': 'Tue Jul 30 11:28:59 +0000 2013'},
#  1340408646: {'name': 'Hannesz',
#   'screen_name': 'Hannesz1956',
#   'verified': False,
#   'followers_count': 9917,
#   'friends_count': 10902,
#   'created_at': 'Tue Apr 09 22:53:39 +0000 2013'},
#  1250646693982302208: {'name': 'Phoenix',
#   'screen_name': 'Phoenix43324339',
#   'verified': False,
#   'followers_count': 93,
#   'friends_count': 390,
#   'created_at': 'Thu Apr 16 04:46:39 +0000 2020'},
#  952890382362316800: {'name': 'Inani اِنانی',
#   'screen_name': 'Inani_yes',
#   'verified': False,
#   'followers_count': 98,
#   'friends_count': 379,
#   'created_at': 'Mon Jan 15 13:09:05 +0000 2018'},
#  1094161120133242881: {'name': 'रुद्र',
#   'screen_name': 'im_Rudra11',
#   'verified': False,
#   'followers_count': 365,
#   'friends_count': 334,
#   'created_at': 'Sat Feb 09 09:08:34 +0000 2019'},
#  872411139816267776: {'name': 'lasgidilastborn',
#   'screen_name': 'chydee007',
#   'verified': False,
#   'followers_count': 104,
#   'friends_count': 285,
#   'created_at': 'Wed Jun 07 11:13:19 +0000 2017'},
#  1887225738: {'name': 'Daanaya jose🕊🐝',
#   'screen_name': 'jo_gir',
#   'verified': False,
#   'followers_count': 4436,
#   'friends_count': 3694,
#   'created_at': 'Fri Sep 20 17:37:57 +0000 2013'},
#  3438152645: {'name': 'selim sırrı feroğlu',
#   'screen_name': 'sirriferoglu',
#   'verified': False,
#   'followers_count': 173,
#   'friends_count': 166,
#   'created_at': 'Mon Aug 24 16:27:46 +0000 2015'},
#  1154378084012847104: {'name': 'Ky',
#   'screen_name': 'DPakarti',
#   'verified': False,
#   'followers_count': 16,
#   'friends_count': 21,
#   'created_at': 'Thu Jul 25 13:09:17 +0000 2019'},
#  203604546: {'name': 'prem kumar',
#   'screen_name': 'premit7',
#   'verified': False,
#   'followers_count': 159,
#   'friends_count': 123,
#   'created_at': 'Sat Oct 16 17:18:51 +0000 2010'},
#  176965438: {'name': 'sv Ommoord',
#   'screen_name': 'svommoord',
#   'verified': False,
#   'followers_count': 356,
#   'friends_count': 1,
#   'created_at': 'Tue Aug 10 22:32:04 +0000 2010'},
#  952226761797984257: {'name': 'the man',
#   'screen_name': 'theman55254601',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 23,
#   'created_at': 'Sat Jan 13 17:12:06 +0000 2018'},
#  106336012: {'name': 'panjeee',
#   'screen_name': 'shittycomrade_',
#   'verified': False,
#   'followers_count': 399,
#   'friends_count': 511,
#   'created_at': 'Tue Jan 19 06:41:47 +0000 2010'},
#  1124784255698112513: {'name': 'lili 😙✌🏾',
#   'screen_name': 'lily_crh',
#   'verified': False,
#   'followers_count': 437,
#   'friends_count': 486,
#   'created_at': 'Sat May 04 21:13:58 +0000 2019'},
#  998545436620214272: {'name': 'Aurora Dilireba',
#   'screen_name': '0O1972419',
#   'verified': False,
#   'followers_count': 8177,
#   'friends_count': 3120,
#   'created_at': 'Mon May 21 12:45:58 +0000 2018'},
#  1253153659115970560: {'name': '1%hooman',
#   'screen_name': 'emanggadaahlak',
#   'verified': False,
#   'followers_count': 39,
#   'friends_count': 127,
#   'created_at': 'Thu Apr 23 02:48:18 +0000 2020'},
#  22926365: {'name': 'Tagesspiegel',
#   'screen_name': 'Tagesspiegel',
#   'verified': True,
#   'followers_count': 404590,
#   'friends_count': 1449,
#   'created_at': 'Thu Mar 05 14:47:03 +0000 2009'},
#  953746712836952064: {'name': 'Ron',
#   'screen_name': 'Ron1872',
#   'verified': False,
#   'followers_count': 1018,
#   'friends_count': 1750,
#   'created_at': 'Wed Jan 17 21:51:50 +0000 2018'},
#  1190845316779499522: {'name': 'Kashinath',
#   'screen_name': 'Kashina93479752',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 41,
#   'created_at': 'Sun Nov 03 04:17:18 +0000 2019'},
#  1117554533964689415: {'name': 'yaø',
#   'screen_name': 'shapebrainnn',
#   'verified': False,
#   'followers_count': 205,
#   'friends_count': 237,
#   'created_at': 'Sun Apr 14 22:25:38 +0000 2019'},
#  823464443778650112: {'name': 'Gajendra Prajapati (गजेन्द्र कुमार)',
#   'screen_name': 'Gajendra_D_P',
#   'verified': False,
#   'followers_count': 632,
#   'friends_count': 915,
#   'created_at': 'Mon Jan 23 09:36:37 +0000 2017'},
#  807640520646217728: {'name': 'V.de Poorter🚜',
#   'screen_name': 'Tweelingetje2V',
#   'verified': False,
#   'followers_count': 670,
#   'friends_count': 415,
#   'created_at': 'Sat Dec 10 17:38:00 +0000 2016'},
#  811123127166140416: {'name': 'Denise Bloggermum Blog 🏡',
#   'screen_name': 'bloggermumthree',
#   'verified': False,
#   'followers_count': 259,
#   'friends_count': 322,
#   'created_at': 'Tue Dec 20 08:16:38 +0000 2016'},
#  220371373: {'name': 'FORBIDDEN1990',
#   'screen_name': 'Februariii',
#   'verified': False,
#   'followers_count': 528,
#   'friends_count': 1824,
#   'created_at': 'Sat Nov 27 15:53:50 +0000 2010'},
#  2207400312: {'name': 'Chandan Tandon 🇮🇳',
#   'screen_name': 'Chandan_tndn',
#   'verified': False,
#   'followers_count': 1354,
#   'friends_count': 526,
#   'created_at': 'Thu Nov 21 15:54:47 +0000 2013'},
#  569621295: {'name': 'Nugroho Eko',
#   'screen_name': 'NugrohoEkoRav',
#   'verified': False,
#   'followers_count': 346,
#   'friends_count': 1439,
#   'created_at': 'Thu May 03 00:17:17 +0000 2012'},
#  801962894107627520: {'name': 'RD',
#   'screen_name': '24X7RD',
#   'verified': False,
#   'followers_count': 21,
#   'friends_count': 92,
#   'created_at': 'Fri Nov 25 01:37:08 +0000 2016'},
#  53075530: {'name': 'buten un binnen',
#   'screen_name': 'butenunbinnen',
#   'verified': True,
#   'followers_count': 34493,
#   'friends_count': 1951,
#   'created_at': 'Thu Jul 02 14:22:52 +0000 2009'},
#  213616677: {'name': 'OLUWAFEMI◽',
#   'screen_name': 'Luckyflows',
#   'verified': False,
#   'followers_count': 25479,
#   'friends_count': 15641,
#   'created_at': 'Tue Nov 09 11:08:35 +0000 2010'},
#  1006267924561252355: {'name': 'E.Euri',
#   'screen_name': 'DeltaEcoEco',
#   'verified': False,
#   'followers_count': 50,
#   'friends_count': 240,
#   'created_at': 'Mon Jun 11 20:12:23 +0000 2018'},
#  1019932376737038337: {'name': 'Rini Syafri',
#   'screen_name': 'Dr_rinisyafri',
#   'verified': False,
#   'followers_count': 1577,
#   'friends_count': 164,
#   'created_at': 'Thu Jul 19 13:10:02 +0000 2018'},
#  86846500: {'name': 'Jesús Escobar Tovar',
#   'screen_name': 'jet1403',
#   'verified': False,
#   'followers_count': 6522,
#   'friends_count': 1006,
#   'created_at': 'Mon Nov 02 01:35:54 +0000 2009'},
#  1241643613664071681: {'name': 'ManviSINGH Shakya',
#   'screen_name': 'ManviSINGHShak1',
#   'verified': False,
#   'followers_count': 136,
#   'friends_count': 579,
#   'created_at': 'Sun Mar 22 08:31:35 +0000 2020'},
#  1078783576576061441: {'name': '𝖉𝖆𝖓 ៹',
#   'screen_name': 'hzlltai',
#   'verified': False,
#   'followers_count': 840,
#   'friends_count': 807,
#   'created_at': 'Fri Dec 28 22:43:42 +0000 2018'},
#  1242525755013304320: {'name': 'Sulphur-3',
#   'screen_name': '3_sulphur',
#   'verified': False,
#   'followers_count': 610,
#   'friends_count': 2332,
#   'created_at': 'Tue Mar 24 18:57:22 +0000 2020'},
#  722979256867930112: {'name': 'tiberius_ndr',
#   'screen_name': 'tiberius_ndr',
#   'verified': False,
#   'followers_count': 50,
#   'friends_count': 126,
#   'created_at': 'Thu Apr 21 02:44:21 +0000 2016'},
#  1042058251813232640: {'name': 'Thekla4715',
#   'screen_name': 'Thekla47151',
#   'verified': False,
#   'followers_count': 395,
#   'friends_count': 1500,
#   'created_at': 'Tue Sep 18 14:30:22 +0000 2018'},
#  723300496891473920: {'name': '♕𝓢𝓱𝓸𝓷𝓷🕊',
#   'screen_name': 'Satya_Cabello',
#   'verified': False,
#   'followers_count': 61,
#   'friends_count': 337,
#   'created_at': 'Fri Apr 22 00:00:51 +0000 2016'},
#  3322703139: {'name': 'beca',
#   'screen_name': 'cfcbeca',
#   'verified': False,
#   'followers_count': 519,
#   'friends_count': 414,
#   'created_at': 'Sat Jun 13 10:06:48 +0000 2015'},
#  3606360503: {'name': 'Frank Hemicker',
#   'screen_name': 'stb_hemicker',
#   'verified': False,
#   'followers_count': 28,
#   'friends_count': 3,
#   'created_at': 'Thu Sep 10 06:27:07 +0000 2015'},
#  17007292: {'name': 'Jannis Schakarian 🇪🇺',
#   'screen_name': 'netzfeuilleton',
#   'verified': True,
#   'followers_count': 4265,
#   'friends_count': 1141,
#   'created_at': 'Mon Oct 27 21:11:32 +0000 2008'},
#  1465726471: {'name': 'Nándor Hulverscheidt',
#   'screen_name': 'nanhul',
#   'verified': False,
#   'followers_count': 379,
#   'friends_count': 1167,
#   'created_at': 'Tue May 28 21:16:53 +0000 2013'},
#  1251068478066290689: {'name': 'Musk_b',
#   'screen_name': 'Muskb7',
#   'verified': False,
#   'followers_count': 16,
#   'friends_count': 190,
#   'created_at': 'Fri Apr 17 08:42:36 +0000 2020'},
#  1219653177051697158: {'name': 'محمد المضياني ابو ثامر',
#   'screen_name': 'Abuthamer1211',
#   'verified': False,
#   'followers_count': 152,
#   'friends_count': 371,
#   'created_at': 'Tue Jan 21 16:09:30 +0000 2020'},
#  546960359: {'name': '| PePPeS | ✘',
#   'screen_name': 'PePPeS_10',
#   'verified': False,
#   'followers_count': 983,
#   'friends_count': 285,
#   'created_at': 'Fri Apr 06 17:12:25 +0000 2012'},
#  2404931933: {'name': 'Vishal #SakhaParivar',
#   'screen_name': 'VMakadiya',
#   'verified': False,
#   'followers_count': 1147,
#   'friends_count': 1200,
#   'created_at': 'Wed Mar 12 14:08:31 +0000 2014'},
#  1467524396: {'name': 'Kathleen Brenner',
#   'screen_name': 'KathleenBrenne1',
#   'verified': False,
#   'followers_count': 701,
#   'friends_count': 1189,
#   'created_at': 'Wed May 29 15:14:36 +0000 2013'},
#  718743494160949248: {'name': 'Ammara Khalil',
#   'screen_name': 'noturtrash',
#   'verified': False,
#   'followers_count': 11084,
#   'friends_count': 247,
#   'created_at': 'Sat Apr 09 10:12:57 +0000 2016'},
#  1189058443539169282: {'name': 'Erni Yulianti',
#   'screen_name': 'viieeeee_',
#   'verified': False,
#   'followers_count': 14,
#   'friends_count': 46,
#   'created_at': 'Tue Oct 29 05:56:52 +0000 2019'},
#  2482845632: {'name': 'clhinOC',
#   'screen_name': 'cyndeehudson1',
#   'verified': False,
#   'followers_count': 149,
#   'friends_count': 217,
#   'created_at': 'Wed May 07 22:41:11 +0000 2014'},
#  623258004: {'name': 'Rebecca Kovalich',
#   'screen_name': 'beccakova',
#   'verified': False,
#   'followers_count': 214,
#   'friends_count': 139,
#   'created_at': 'Sat Jun 30 22:04:24 +0000 2012'},
#  1244144923911356417: {'name': 'Robert2',
#   'screen_name': 'Robert253305291',
#   'verified': False,
#   'followers_count': 3,
#   'friends_count': 80,
#   'created_at': 'Sun Mar 29 06:10:57 +0000 2020'},
#  2193244912: {'name': 'Gaby Hemeryck ✌️',
#   'screen_name': 'GabyHemeryck',
#   'verified': False,
#   'followers_count': 1558,
#   'friends_count': 664,
#   'created_at': 'Sat Nov 23 20:50:37 +0000 2013'},
#  871295871446650880: {'name': 'Opus 🐝',
#   'screen_name': 'Opuscopus21',
#   'verified': False,
#   'followers_count': 638,
#   'friends_count': 264,
#   'created_at': 'Sun Jun 04 09:21:38 +0000 2017'},
#  852857815941210112: {'name': 'Veronica🐾',
#   'screen_name': 'veronicaaaaaaav',
#   'verified': False,
#   'followers_count': 157,
#   'friends_count': 60,
#   'created_at': 'Fri Apr 14 12:15:23 +0000 2017'},
#  191805985: {'name': 'Yuni Alfiyah.N',
#   'screen_name': 'yuniialfiyah',
#   'verified': False,
#   'followers_count': 262,
#   'friends_count': 146,
#   'created_at': 'Fri Sep 17 12:04:50 +0000 2010'},
#  1188851320104607745: {'name': 'اداره _مملكة_الشمالية _للدعم 👑🌟',
#   'screen_name': 'RSRS098',
#   'verified': False,
#   'followers_count': 499,
#   'friends_count': 118,
#   'created_at': 'Mon Oct 28 16:14:29 +0000 2019'},
#  146019092: {'name': 'Olumide',
#   'screen_name': 'Olu_Clarks',
#   'verified': False,
#   'followers_count': 331,
#   'friends_count': 403,
#   'created_at': 'Thu May 20 12:13:06 +0000 2010'},
#  2201175573: {'name': 'Dokuzuncu Köy 🇹🇷',
#   'screen_name': 'dokuzuncu_koy',
#   'verified': False,
#   'followers_count': 2325,
#   'friends_count': 2169,
#   'created_at': 'Sat Nov 30 02:02:04 +0000 2013'},
#  1147063974594306048: {'name': '𝖘𝖔𝖚𝖟𝖆😷',
#   'screen_name': '_souxz',
#   'verified': False,
#   'followers_count': 41,
#   'friends_count': 223,
#   'created_at': 'Fri Jul 05 08:45:37 +0000 2019'},
#  1020315571018174465: {'name': 'OGA ZIM',
#   'screen_name': 'transferpolicy7',
#   'verified': False,
#   'followers_count': 2573,
#   'friends_count': 4487,
#   'created_at': 'Fri Jul 20 14:32:43 +0000 2018'},
#  1119479264561127424: {'name': 'Khudori Yudhoprawiro',
#   'screen_name': 'MuhamadKhudor18',
#   'verified': False,
#   'followers_count': 62,
#   'friends_count': 672,
#   'created_at': 'Sat Apr 20 05:53:50 +0000 2019'},
#  1238780158766731264: {'name': 'Silvia Zorzetto',
#   'screen_name': 'silvia_zorzetto',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 20,
#   'created_at': 'Sat Mar 14 10:53:13 +0000 2020'},
#  146781802: {'name': 'Servus Pecum',
#   'screen_name': 'ServusPecum',
#   'verified': False,
#   'followers_count': 2152,
#   'friends_count': 1863,
#   'created_at': 'Sat May 22 09:33:15 +0000 2010'},
#  827835348688453632: {'name': 'مانی ب',
#   'screen_name': 'ManisElecti',
#   'verified': False,
#   'followers_count': 364,
#   'friends_count': 92,
#   'created_at': 'Sat Feb 04 11:05:02 +0000 2017'},
#  168584284: {'name': 'DENNIS C KURIAN',
#   'screen_name': 'dennisckurian',
#   'verified': False,
#   'followers_count': 1680,
#   'friends_count': 217,
#   'created_at': 'Tue Jul 20 08:29:23 +0000 2010'},
#  867006133113901057: {'name': 'Bhushan Bobade|ビーウシャン ボバド 💪🤘👊☯️🇮🇳♉💖',
#   'screen_name': 'Married2Martyr',
#   'verified': False,
#   'followers_count': 782,
#   'friends_count': 1619,
#   'created_at': 'Tue May 23 13:15:45 +0000 2017'},
#  33308499: {'name': 'Leila Khan',
#   'screen_name': 'leilakhan',
#   'verified': False,
#   'followers_count': 13157,
#   'friends_count': 791,
#   'created_at': 'Sun Apr 19 20:47:24 +0000 2009'},
#  751839411403386880: {'name': 'RAM X pro',
#   'screen_name': 'DrRamx',
#   'verified': False,
#   'followers_count': 56,
#   'friends_count': 306,
#   'created_at': 'Sat Jul 09 18:04:18 +0000 2016'},
#  1210913329381703680: {'name': 'Rahul kumar',
#   'screen_name': 'Rahulku55193241',
#   'verified': False,
#   'followers_count': 4,
#   'friends_count': 45,
#   'created_at': 'Sat Dec 28 13:20:31 +0000 2019'},
#  73118798: {'name': 'Alexander Pytlik',
#   'screen_name': 'padrealex',
#   'verified': False,
#   'followers_count': 946,
#   'friends_count': 1975,
#   'created_at': 'Thu Sep 10 13:42:41 +0000 2009'},
#  1473354253: {'name': 'Syed Ali',
#   'screen_name': '_syedalii',
#   'verified': False,
#   'followers_count': 145,
#   'friends_count': 223,
#   'created_at': 'Fri May 31 23:32:29 +0000 2013'},
#  1220337048760016896: {'name': 'Tarım Orman Haber',
#   'screen_name': 'tarim_orman',
#   'verified': False,
#   'followers_count': 772,
#   'friends_count': 988,
#   'created_at': 'Thu Jan 23 13:27:00 +0000 2020'},
#  562137994: {'name': 'Sert',
#   'screen_name': 'oflu_1461',
#   'verified': False,
#   'followers_count': 745,
#   'friends_count': 131,
#   'created_at': 'Tue Apr 24 16:01:10 +0000 2012'},
#  1249384780178714624: {'name': 'Suaraujungnegeri',
#   'screen_name': 'Suaraujungnege2',
#   'verified': False,
#   'followers_count': 15,
#   'friends_count': 102,
#   'created_at': 'Sun Apr 12 17:12:16 +0000 2020'},
#  2850003644: {'name': 'Tosin Falusi',
#   'screen_name': 'FalusiTosin',
#   'verified': False,
#   'followers_count': 870,
#   'friends_count': 826,
#   'created_at': 'Fri Oct 10 09:13:53 +0000 2014'},
#  1040995742448381952: {'name': '👻',
#   'screen_name': 'rejexxion',
#   'verified': False,
#   'followers_count': 94,
#   'friends_count': 179,
#   'created_at': 'Sat Sep 15 16:08:20 +0000 2018'},
#  843112646672969730: {'name': '🇮🇳🚩जय श्री राम 🚩🇮🇳',
#   'screen_name': 'RaviKumar872',
#   'verified': False,
#   'followers_count': 1971,
#   'friends_count': 1698,
#   'created_at': 'Sat Mar 18 14:51:34 +0000 2017'},
#  710684360391921665: {'name': 'IvoJima61',
#   'screen_name': 'IvoJima61',
#   'verified': False,
#   'followers_count': 315,
#   'friends_count': 296,
#   'created_at': 'Fri Mar 18 04:28:50 +0000 2016'},
#  1251962574377062400: {'name': 'Aliandobogor77',
#   'screen_name': 'aliandobogor77',
#   'verified': False,
#   'followers_count': 46,
#   'friends_count': 266,
#   'created_at': 'Sun Apr 19 19:55:36 +0000 2020'},
#  474696583: {'name': 'D.white',
#   'screen_name': 'SirPuffAlot_JLR',
#   'verified': False,
#   'followers_count': 1440,
#   'friends_count': 776,
#   'created_at': 'Thu Jan 26 07:50:47 +0000 2012'},
#  217563613: {'name': 'Lara Mason',
#   'screen_name': 'laceltris',
#   'verified': False,
#   'followers_count': 245,
#   'friends_count': 600,
#   'created_at': 'Fri Nov 19 21:45:07 +0000 2010'},
#  750278508: {'name': 'Don Paco',
#   'screen_name': 'PacoMerteEso',
#   'verified': False,
#   'followers_count': 3047,
#   'friends_count': 464,
#   'created_at': 'Fri Aug 10 23:53:47 +0000 2012'},
#  550082685: {'name': 'Bang Gondrong',
#   'screen_name': 'g_siahaan',
#   'verified': False,
#   'followers_count': 397,
#   'friends_count': 316,
#   'created_at': 'Tue Apr 10 10:39:34 +0000 2012'},
#  1114663173376888838: {'name': 'Big Boy♟',
#   'screen_name': 'smartkayc',
#   'verified': False,
#   'followers_count': 15051,
#   'friends_count': 12891,
#   'created_at': 'Sat Apr 06 22:56:24 +0000 2019'},
#  338209836: {'name': 'Mohit Jain मोहित जैन 🇮🇳',
#   'screen_name': 'INCMohitJain',
#   'verified': False,
#   'followers_count': 11262,
#   'friends_count': 2075,
#   'created_at': 'Tue Jul 19 07:09:01 +0000 2011'},
#  69294011: {'name': 'Ambuj Dixit',
#   'screen_name': 'Ambujspeaks',
#   'verified': False,
#   'followers_count': 115,
#   'friends_count': 250,
#   'created_at': 'Thu Aug 27 13:46:03 +0000 2009'},
#  1226538140770242565: {'name': 'ON na',
#   'screen_name': 'ronna_ov',
#   'verified': False,
#   'followers_count': 16,
#   'friends_count': 20,
#   'created_at': 'Sun Feb 09 16:07:52 +0000 2020'},
#  1071737305: {'name': 'Kimberly Tucker',
#   'screen_name': 'keywestphoenix',
#   'verified': False,
#   'followers_count': 139,
#   'friends_count': 536,
#   'created_at': 'Tue Jan 08 19:07:38 +0000 2013'},
#  942765373031452673: {'name': 'Er.Praveen Yadav अभि.प्रवीण यादव🇮🇳',
#   'screen_name': 'ErPrvn108',
#   'verified': False,
#   'followers_count': 3118,
#   'friends_count': 2076,
#   'created_at': 'Mon Dec 18 14:35:55 +0000 2017'},
#  1249448523608649728: {'name': 'Dursun',
#   'screen_name': 'Dursun17208077',
#   'verified': False,
#   'followers_count': 1,
#   'friends_count': 43,
#   'created_at': 'Sun Apr 12 21:25:36 +0000 2020'},
#  132452025: {'name': 'Prem Yadav',
#   'screen_name': 'pcjnu',
#   'verified': False,
#   'followers_count': 3600,
#   'friends_count': 1524,
#   'created_at': 'Tue Apr 13 08:13:13 +0000 2010'},
#  2423707482: {'name': 'Daddy Cool 🇫🇷🇪🇺 🌍 #FBPE',
#   'screen_name': 'Daddycool59000',
#   'verified': False,
#   'followers_count': 251,
#   'friends_count': 682,
#   'created_at': 'Wed Apr 02 12:14:34 +0000 2014'},
#  300189882: {'name': 'A New Experiment',
# ...
#   'friends_count': 50,
#   'created_at': 'Mon Jun 05 14:34:25 +0000 2017'},
#  1047429276134461440: {'name': '⚡️⚡️⚡️VTMH⚡️⚡️⚡️',
#   'screen_name': 'VTMH2',
#   'verified': False,
#   'followers_count': 3613,
#   'friends_count': 3581,
#   'created_at': 'Wed Oct 03 10:12:54 +0000 2018'},
#  3370214007: {'name': 'Aderopo Michael',
#   'screen_name': 'roppy001',
#   'verified': False,
#   'followers_count': 48,
#   'friends_count': 128,
#   'created_at': 'Sat Jul 11 04:22:16 +0000 2015'},
#  1253775080313835521: {'name': 'Karpuzkafa',
#   'screen_name': 'Karpuzkafa7',
#   'verified': False,
#   'followers_count': 1,
#   'friends_count': 23,
#   'created_at': 'Fri Apr 24 19:57:42 +0000 2020'},
#  955966935178661889: {'name': 'DEC',
#   'screen_name': 'clarkd1951',
#   'verified': False,
#   'followers_count': 62,
#   'friends_count': 197,
#   'created_at': 'Wed Jan 24 00:54:13 +0000 2018'},
#  2548401624: {'name': '#SweetNight♡⁷ nsfr',
#   'screen_name': 'hopeworld_jhs',
#   'verified': False,
#   'followers_count': 339,
#   'friends_count': 308,
#   'created_at': 'Thu Jun 05 16:37:59 +0000 2014'},
#  367192484: {'name': 'BTRZ ✨🦋',
#   'screen_name': 'B_furacao',
#   'verified': False,
#   'followers_count': 445,
#   'friends_count': 440,
#   'created_at': 'Sat Sep 03 15:04:20 +0000 2011'},
#  1225447573806145536: {'name': 'Rick Woods',
#   'screen_name': 'RickWoo34225892',
#   'verified': False,
#   'followers_count': 22,
#   'friends_count': 436,
#   'created_at': 'Thu Feb 06 15:54:24 +0000 2020'},
#  2710408399: {'name': 'Alexandra Zumoberhaus',
#   'screen_name': 'jussitussi1',
#   'verified': False,
#   'followers_count': 1805,
#   'friends_count': 919,
#   'created_at': 'Tue Aug 05 21:32:24 +0000 2014'},
#  227276321: {'name': 'Sarfaraz Mansuri',
#   'screen_name': 'drsafz22',
#   'verified': False,
#   'followers_count': 92,
#   'friends_count': 141,
#   'created_at': 'Thu Dec 16 11:55:44 +0000 2010'},
#  154240448: {'name': 'Alae | \u200fآلاء 𓂀 at home',
#   'screen_name': 'alae089',
#   'verified': False,
#   'followers_count': 1433,
#   'friends_count': 456,
#   'created_at': 'Thu Jun 10 18:55:39 +0000 2010'},
#  3037436317: {'name': 'MedadERP',
#   'screen_name': 'MedadERP',
#   'verified': False,
#   'followers_count': 763,
#   'friends_count': 35,
#   'created_at': 'Mon Feb 23 05:39:10 +0000 2015'},
#  1251322715627302912: {'name': 'Divineloski',
#   'screen_name': 'divineloski',
#   'verified': False,
#   'followers_count': 16,
#   'friends_count': 88,
#   'created_at': 'Sat Apr 18 01:32:49 +0000 2020'},
#  1017118319202177025: {'name': 'The Weeb Sheriff',
#   'screen_name': 'InfiniteRhizome',
#   'verified': False,
#   'followers_count': 373,
#   'friends_count': 388,
#   'created_at': 'Wed Jul 11 18:47:59 +0000 2018'},
#  1707755058: {'name': 'Jürgen Spelthahn',
#   'screen_name': 'JrgenSpelthahn1',
#   'verified': False,
#   'followers_count': 862,
#   'friends_count': 1318,
#   'created_at': 'Wed Aug 28 17:05:36 +0000 2013'},
#  987645579671949313: {'name': 'Harnii',
#   'screen_name': 'Harni46630847',
#   'verified': False,
#   'followers_count': 74,
#   'friends_count': 201,
#   'created_at': 'Sat Apr 21 10:53:50 +0000 2018'},
#  851968571022352385: {'name': 'Irfan Shaikh',
#   'screen_name': 'IrfanSh57966446',
#   'verified': False,
#   'followers_count': 393,
#   'friends_count': 461,
#   'created_at': 'Wed Apr 12 01:21:50 +0000 2017'},
#  1591544858: {'name': 'kakuja',
#   'screen_name': 'itsfuckingsen',
#   'verified': False,
#   'followers_count': 138,
#   'friends_count': 86,
#   'created_at': 'Sat Jul 13 18:07:32 +0000 2013'},
#  3008700857: {'name': 'Rachti',
#   'screen_name': 'Rachti_',
#   'verified': False,
#   'followers_count': 385,
#   'friends_count': 359,
#   'created_at': 'Sat Jan 31 23:01:53 +0000 2015'},
#  891728389182304258: {'name': 'Giacomo Polce',
#   'screen_name': 'GiacomoPolce',
#   'verified': False,
#   'followers_count': 30,
#   'friends_count': 43,
#   'created_at': 'Sun Jul 30 18:33:10 +0000 2017'},
#  892052636719091713: {'name': 'ratnesh tiwari',
#   'screen_name': 'ratnesh19369283',
#   'verified': False,
#   'followers_count': 4,
#   'friends_count': 59,
#   'created_at': 'Mon Jul 31 16:01:36 +0000 2017'},
#  1230713748999983105: {'name': 'Şıho Uçar',
#   'screen_name': 'UcarHo',
#   'verified': False,
#   'followers_count': 51,
#   'friends_count': 345,
#   'created_at': 'Fri Feb 21 04:40:15 +0000 2020'},
#  826284528645730304: {'name': 'AIR News Imphal',
#   'screen_name': 'airnews_imphal',
#   'verified': False,
#   'followers_count': 3018,
#   'friends_count': 50,
#   'created_at': 'Tue Jan 31 04:22:38 +0000 2017'},
#  883345986462117889: {'name': 'Ayşe',
#   'screen_name': 'Aysediebirii',
#   'verified': False,
#   'followers_count': 25,
#   'friends_count': 32,
#   'created_at': 'Fri Jul 07 15:24:29 +0000 2017'},
#  1182501842078449672: {'name': 'Shyam Yadav',
#   'screen_name': 'ShyamYa37472839',
#   'verified': False,
#   'followers_count': 14,
#   'friends_count': 258,
#   'created_at': 'Fri Oct 11 03:43:20 +0000 2019'},
#  970098400858222597: {'name': 'Ian Crowe',
#   'screen_name': 'FrozenCorvid',
#   'verified': False,
#   'followers_count': 11,
#   'friends_count': 90,
#   'created_at': 'Sun Mar 04 00:47:37 +0000 2018'},
#  453501880: {'name': 'BigH♤ aint turnin in 💩',
#   'screen_name': 'gighurl',
#   'verified': False,
#   'followers_count': 486,
#   'friends_count': 924,
#   'created_at': 'Tue Jan 03 00:22:22 +0000 2012'},
#  1222340198974947329: {'name': 'ellis p',
#   'screen_name': 'ellisp46750928',
#   'verified': False,
#   'followers_count': 27,
#   'friends_count': 64,
#   'created_at': 'Wed Jan 29 02:06:49 +0000 2020'},
#  30313286: {'name': 'burcu capulcugil',
#   'screen_name': 'burcuozkol',
#   'verified': False,
#   'followers_count': 182,
#   'friends_count': 215,
#   'created_at': 'Fri Apr 10 21:07:25 +0000 2009'},
#  779801150442860544: {'name': 'Khalid Mazari',
#   'screen_name': 'KhalidMazari3',
#   'verified': False,
#   'followers_count': 13,
#   'friends_count': 49,
#   'created_at': 'Sat Sep 24 21:54:17 +0000 2016'},
#  4830490408: {'name': 'Dinçer YILMAZ 5816 Kaldırılsın',
#   'screen_name': '1rtyapilir',
#   'verified': False,
#   'followers_count': 19109,
#   'friends_count': 16611,
#   'created_at': 'Wed Jan 20 18:24:15 +0000 2016'},
#  3315155226: {'name': 'Dr.Sanjeev Rajpurohit',
#   'screen_name': 'DrSanjeevRajp4',
#   'verified': False,
#   'followers_count': 12545,
#   'friends_count': 339,
#   'created_at': 'Fri Aug 14 16:09:43 +0000 2015'},
#  89390287: {'name': 'Smarth Aggarwal',
#   'screen_name': 'gamer_2080',
#   'verified': False,
#   'followers_count': 131,
#   'friends_count': 1861,
#   'created_at': 'Thu Nov 12 06:35:21 +0000 2009'},
#  948614892: {'name': 'bill w blankenship',
#   'screen_name': 'sloepoketex',
#   'verified': False,
#   'followers_count': 677,
#   'friends_count': 1206,
#   'created_at': 'Wed Nov 14 22:37:31 +0000 2012'},
#  945888243366498304: {'name': 'Clinton St. Clair',
#   'screen_name': 'cdog209',
#   'verified': False,
#   'followers_count': 112,
#   'friends_count': 801,
#   'created_at': 'Wed Dec 27 05:25:05 +0000 2017'},
#  242730608: {'name': 'Yakup BARAN',
#   'screen_name': 'yakupbaran66',
#   'verified': False,
#   'followers_count': 332,
#   'friends_count': 855,
#   'created_at': 'Tue Jan 25 13:22:25 +0000 2011'},
#  774261484641746944: {'name': 'Ogello😷',
#   'screen_name': 'OgelloSays',
#   'verified': False,
#   'followers_count': 2692,
#   'friends_count': 3350,
#   'created_at': 'Fri Sep 09 15:01:38 +0000 2016'},
#  3537440836: {'name': 'hailey',
#   'screen_name': 'williamsnhailey',
#   'verified': False,
#   'followers_count': 573,
#   'friends_count': 355,
#   'created_at': 'Thu Sep 03 20:13:06 +0000 2015'},
#  1183853400284434432: {'name': 'Itsme2019',
#   'screen_name': 'Itsme20196',
#   'verified': False,
#   'followers_count': 97,
#   'friends_count': 217,
#   'created_at': 'Mon Oct 14 21:13:55 +0000 2019'},
#  531481375: {'name': 'kobsalbertjens',
#   'screen_name': 'kobsalbertjens',
#   'verified': False,
#   'followers_count': 166,
#   'friends_count': 630,
#   'created_at': 'Tue Mar 20 17:42:35 +0000 2012'},
#  442235388: {'name': 'Rosanna Dalessandri',
#   'screen_name': 'rossrd',
#   'verified': False,
#   'followers_count': 195,
#   'friends_count': 495,
#   'created_at': 'Tue Dec 20 22:15:02 +0000 2011'},
#  925015039920230400: {'name': 'Die Franzi',
#   'screen_name': 'DGrotzer',
#   'verified': False,
#   'followers_count': 99,
#   'friends_count': 501,
#   'created_at': 'Mon Oct 30 15:02:26 +0000 2017'},
#  1176416597721919488: {'name': '🎀اظھر حسین🎀',
#   'screen_name': 'Hussain23013859',
#   'verified': False,
#   'followers_count': 1807,
#   'friends_count': 1746,
#   'created_at': 'Tue Sep 24 08:43:10 +0000 2019'},
#  4725391649: {'name': 'Oluwatomisin',
#   'screen_name': 'thom_syne',
#   'verified': False,
#   'followers_count': 232,
#   'friends_count': 469,
#   'created_at': 'Wed Jan 06 14:25:37 +0000 2016'},
#  948164944935243782: {'name': 'Physical distancing Hartblogger',
#   'screen_name': 'Hartblogger1',
#   'verified': False,
#   'followers_count': 1341,
#   'friends_count': 2801,
#   'created_at': 'Tue Jan 02 12:11:53 +0000 2018'},
#  541516665: {'name': 'Crowl',
#   'screen_name': 'Cassius201062',
#   'verified': False,
#   'followers_count': 385,
#   'friends_count': 3919,
#   'created_at': 'Sat Mar 31 07:02:34 +0000 2012'},
#  1173551274278772737: {'name': 'KLyn 👑',
#   'screen_name': 'tichaklyn',
#   'verified': False,
#   'followers_count': 247,
#   'friends_count': 309,
#   'created_at': 'Mon Sep 16 10:56:55 +0000 2019'},
#  2865765635: {'name': 'GlaubeandasGute',
#   'screen_name': 'fettmops04',
#   'verified': False,
#   'followers_count': 1265,
#   'friends_count': 905,
#   'created_at': 'Fri Nov 07 15:22:05 +0000 2014'},
#  1126449736133816320: {'name': 'Suhail. Anwer',
#   'screen_name': 'SuhailAnwer18',
#   'verified': False,
#   'followers_count': 68,
#   'friends_count': 85,
#   'created_at': 'Thu May 09 11:32:00 +0000 2019'},
#  897756684805783552: {'name': 'R1fk1',
#   'screen_name': 'rifky120412',
#   'verified': False,
#   'followers_count': 284,
#   'friends_count': 808,
#   'created_at': 'Wed Aug 16 09:47:27 +0000 2017'},
#  901560878914555904: {'name': 'Ad Common',
#   'screen_name': 'AdCommon1',
#   'verified': False,
#   'followers_count': 17,
#   'friends_count': 85,
#   'created_at': 'Sat Aug 26 21:43:58 +0000 2017'},
#  972674136945274880: {'name': '金 魚',
#   'screen_name': 'wtfhk_2019',
#   'verified': False,
#   'followers_count': 2,
#   'friends_count': 7,
#   'created_at': 'Sun Mar 11 03:22:40 +0000 2018'},
#  947238380454150145: {'name': 'Deutsch365',
#   'screen_name': 'deutsch365',
#   'verified': False,
#   'followers_count': 8637,
#   'friends_count': 253,
#   'created_at': 'Sat Dec 30 22:50:03 +0000 2017'},
#  1248968549801979905: {'name': 'Om pndet',
#   'screen_name': 'PndetOm',
#   'verified': False,
#   'followers_count': 116,
#   'friends_count': 434,
#   'created_at': 'Sat Apr 11 13:38:27 +0000 2020'},
#  1074646940099371008: {'name': 'M.Matthew Kaya',
#   'screen_name': 'MMatthewKaya1',
#   'verified': False,
#   'followers_count': 550,
#   'friends_count': 896,
#   'created_at': 'Mon Dec 17 12:46:11 +0000 2018'},
#  309389260: {'name': 'Juan Marroquín',
#   'screen_name': 'Juanfmarroquin',
#   'verified': False,
#   'followers_count': 488,
#   'friends_count': 584,
#   'created_at': 'Thu Jun 02 00:55:02 +0000 2011'},
#  939297516: {'name': 'COST',
#   'screen_name': 'CStolth',
#   'verified': False,
#   'followers_count': 299,
#   'friends_count': 188,
#   'created_at': 'Sat Nov 10 15:34:51 +0000 2012'},
#  1248404481374662656: {'name': 'rabin',
#   'screen_name': 'rabin23299300',
#   'verified': False,
#   'followers_count': 0,
#   'friends_count': 16,
#   'created_at': 'Fri Apr 10 00:16:51 +0000 2020'},
#  1609333987: {'name': 'isaa pokoloco',
#   'screen_name': 'isyaihalilintar',
#   'verified': False,
#   'followers_count': 126,
#   'friends_count': 157,
#   'created_at': 'Sun Jul 21 00:06:39 +0000 2013'},
#  21557502: {'name': 'Eric Masseus 🇪🇺',
#   'screen_name': 'EricMasseus',
#   'verified': False,
#   'followers_count': 354,
#   'friends_count': 355,
#   'created_at': 'Sun Feb 22 10:29:19 +0000 2009'},
#  1073229061147643904: {'name': 'Soni Kamil',
#   'screen_name': 'GunGunG49169853',
#   'verified': False,
#   'followers_count': 1127,
#   'friends_count': 2702,
#   'created_at': 'Thu Dec 13 14:52:02 +0000 2018'},
#  1233859323341803523: {'name': 'Hsimsek006',
#   'screen_name': 'hsimsek006',
#   'verified': False,
#   'followers_count': 2,
#   'friends_count': 31,
#   'created_at': 'Sat Feb 29 20:59:36 +0000 2020'},
#  3308650724: {'name': 'WIN NEWS',
#   'screen_name': 'WINNEWS_IN',
#   'verified': False,
#   'followers_count': 18561,
#   'friends_count': 142,
#   'created_at': 'Fri Aug 07 10:09:29 +0000 2015'},
#  1118014902118047745: {'name': 'FootTurk',
#   'screen_name': 'footturk',
#   'verified': False,
#   'followers_count': 42,
#   'friends_count': 11,
#   'created_at': 'Tue Apr 16 04:54:59 +0000 2019'},
#  1212308664284925952: {'name': 'N a a y',
#   'screen_name': 'naysha_naay',
#   'verified': False,
#   'followers_count': 17,
#   'friends_count': 131,
#   'created_at': 'Wed Jan 01 09:45:34 +0000 2020'},
#  386178038: {'name': 'SPAKELE',
#   'screen_name': 'JamesAGayle',
#   'verified': False,
#   'followers_count': 349,
#   'friends_count': 544,
#   'created_at': 'Thu Oct 06 20:04:19 +0000 2011'},
#  1210681102161063937: {'name': '🇹🇷 CENGİZHAN, RT 🇦🇿',
#   'screen_name': 'ingilizekrem',
#   'verified': False,
#   'followers_count': 909,
#   'friends_count': 809,
#   'created_at': 'Fri Dec 27 21:57:37 +0000 2019'},
#  143048739: {'name': 'Roshan T D',
#   'screen_name': 'roshantd',
#   'verified': False,
#   'followers_count': 139,
#   'friends_count': 367,
#   'created_at': 'Wed May 12 12:57:49 +0000 2010'},
#  1195006797146288128: {'name': '.. ky',
#   'screen_name': 'ArzhKo',
#   'verified': False,
#   'followers_count': 1,
#   'friends_count': 1,
#   'created_at': 'Thu Nov 14 15:53:34 +0000 2019'},
#  1051507619087638529: {'name': 'Himmat Solanki',
#   'screen_name': 'HimmatS87608413',
#   'verified': False,
#   'followers_count': 32,
#   'friends_count': 343,
#   'created_at': 'Sun Oct 14 16:18:47 +0000 2018'},
#  796916807290552320: {'name': 'eddh-airport.de',
#   'screen_name': 'EDDH_airport_de',
#   'verified': False,
#   'followers_count': 75,
#   'friends_count': 17,
#   'created_at': 'Fri Nov 11 03:25:47 +0000 2016'},
#  1125263444993806336: {'name': 'Roy Dodd',
#   'screen_name': 'EverywhereRoyIs',
#   'verified': False,
#   'followers_count': 358,
#   'friends_count': 157,
#   'created_at': 'Mon May 06 04:58:06 +0000 2019'},
#  1620776599: {'name': 'Bharat Suthar - भरत सुथार 🇮🇳',
#   'screen_name': 'BharatSutharINC',
#   'verified': False,
#   'followers_count': 5645,
#   'friends_count': 885,
#   'created_at': 'Thu Jul 25 16:22:12 +0000 2013'},
#  4662926178: {'name': 'Abeeha Fahadian4life',
#   'screen_name': 'AbeehaMuzammil',
#   'verified': False,
#   'followers_count': 624,
#   'friends_count': 184,
#   'created_at': 'Sun Dec 27 19:22:18 +0000 2015'},
#  258412072: {'name': 'Marco Weber',
#   'screen_name': 'mec005',
#   'verified': False,
#   'followers_count': 1808,
#   'friends_count': 2047,
#   'created_at': 'Sun Feb 27 17:30:58 +0000 2011'},
#  1079085103458988033: {'name': 'SuperFounderJan',
#   'screen_name': 'Unfoldingit',
#   'verified': False,
#   'followers_count': 1110,
#   'friends_count': 1347,
#   'created_at': 'Sat Dec 29 18:41:51 +0000 2018'},
#  108852592: {'name': 'Hindustan',
#   'screen_name': 'Live_Hindustan',
#   'verified': True,
#   'followers_count': 332464,
#   'friends_count': 101,
#   'created_at': 'Wed Jan 27 06:01:05 +0000 2010'},
#  310370096: {'name': 'me-linda d',
#   'screen_name': 'chellsdss',
#   'verified': False,
#   'followers_count': 530,
#   'friends_count': 268,
#   'created_at': 'Fri Jun 03 16:44:08 +0000 2011'},
#  806159614026846209: {'name': 'E',
#   'screen_name': 'IreneAdlerCT',
#   'verified': False,
#   'followers_count': 59,
#   'friends_count': 213,
#   'created_at': 'Tue Dec 06 15:33:24 +0000 2016'},
#  99646256: {'name': 'as u wish!',
#   'screen_name': 'diagonalleeeyy',
#   'verified': False,
#   'followers_count': 422,
#   'friends_count': 171,
#   'created_at': 'Sun Dec 27 05:21:00 +0000 2009'},
#  1242838129444151296: {'name': 'Sudiyanto',
#   'screen_name': 'Sudiyan96413479',
#   'verified': False,
#   'followers_count': 9,
#   'friends_count': 54,
#   'created_at': 'Wed Mar 25 15:39:20 +0000 2020'},
#  2472440202: {'name': 'Pramesh Jain 🇮🇳',
#   'screen_name': 'prameshjain12',
#   'verified': False,
#   'followers_count': 2948,
#   'friends_count': 3224,
#   'created_at': 'Thu May 01 12:40:58 +0000 2014'},
#  ...}

# %%
#For testing purposes if needed. Do not run the cell

#Drop DB. May need to adjust the connection accordingly. 
connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3",database="new_database")
cursor = connection1.cursor()
sql= "DROP DATABASE my_database"
cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/miniconda3/lib/python3.10/site-packages/mysql/connector/connection_cext.py:608, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     607         query = query.encode("utf-8")
# --> 608     self._cmysql.query(
#     609         query,
#     610         raw=raw,
#     611         buffered=buffered,
#     612         raw_as_string=raw_as_string,
#     613         query_attrs=self._query_attrs,
#     614     )
#     615 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Can't drop database 'my_database'; database doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[63], line 7
#       5 cursor = connection1.cursor()
#       6 sql= "DROP DATABASE my_database"
# ----> 7 cursor.execute(sql)
#
# File ~/miniconda3/lib/python3.10/site-packages/mysql/connector/cursor_cext.py:330, in CMySQLCursor.execute(self, operation, params, multi)
#     325             raise ProgrammingError(
#     326                 "Not all parameters were used in the SQL statement"
#     327             )
#     329 try:
# --> 330     result = self._cnx.cmd_query(
#     331         stmt,
#     332         raw=self._raw,
#     333         buffered=self._buffered,
#     334         raw_as_string=self._raw_as_string,
#     335     )
#     336 except MySQLInterfaceError as err:
#     337     raise get_mysql_exception(
#     338         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     339     ) from err
#
# File ~/miniconda3/lib/python3.10/site-packages/mysql/connector/connection_cext.py:616, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     608     self._cmysql.query(
#     609         query,
#     610         raw=raw,
#    (...)
#     613         query_attrs=self._query_attrs,
#     614     )
#     615 except MySQLInterfaceError as err:
# --> 616     raise get_mysql_exception(
#     617         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     618     ) from err
#     619 except AttributeError as err:
#     620     addr = (
#     621         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     622     )
#
# DatabaseError: 1008 (HY000): Can't drop database 'my_database'; database doesn't exist

# %%
#Drop Table
connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3",database="new_database")
cursor = connection1.cursor()
sql= "DROP TABLE users"
cursor.execute(sql)

#Test to see if your connection works: 

import mysql.connector
import json

try:
    connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3",database="corona_out_2_db")
    print("Connected to MySQL server and database.")
except mysql.connector.Error as error:
    print("Failed to connect to MySQL server: {}".format(error))

# %%
#Side Notes

#need to keep the Python
#JSON Import Utility
#Primary Key needed
#Database needed and ID
# create a new database. This database is called "new_database"

connection1 = mysql.connector.connect(host="localhost", user="root", password="gXt,:RsU#U-ws:3",database="new_database")
cursor = connection1.cursor()
cursor.execute("DROP TABLE users")
print("Database created successfully!")
# Out:
# Database created successfully!
